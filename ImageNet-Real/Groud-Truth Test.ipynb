# %%
import torch
import torchvision.transforms as transforms              
from torchvision.datasets import ImageFolder
import torchvision.models as models
from torchvision.models import Inception_V3_Weights
from src.imagenet_real import aps_imagenet_real_hist, raps_imagenet_real_hist, saps_imagenet_real_hist

# load pre-trained model InceptionV3 and set mode
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# will not be actually run in the test
model = models.inception_v3(weights=Inception_V3_Weights.IMAGENET1K_V1).to(device)
model.eval()

#  Reprocess: Center Crop and then resize to 299*299
data_transform = transforms.Compose([
    transforms.CenterCrop(299),
    transforms.Resize(299), 
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) 
])

sorted_val_path = "D:\\Download\\ImageNet-1K\\Validation_Set\\sorted_ImageNet_val"
dataset = ImageFolder(root=sorted_val_path, transform=data_transform)

# The number of times the experiment is going to be repeated
num_runs = 10

# %% [markdown]
# # $\alpha$=0.1

# %%
aps_imagenet_real_hist(model, dataset, device, num_runs, alpha=0.1, is_ground_truth=True)
# Out:
# APS Classification on ImageNet Real (alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9848 ± 0.0009
# Final Average Prediction Set Size: 2.74 ± 0.04
# Final Average Coverage: 0.9010 ± 0.0042
# Final Average Real Probability: 0.9849 ± 0.0010
# 75902 (61.03%) samples reached the peak conditional coverage at 0.9950

# %%
raps_imagenet_real_hist(model, dataset, device, lambda_=0.2, k_reg=11, num_runs=10, alpha=0.1, is_ground_truth=True)
# Out:
# RAPS Classification on ImageNet Real (alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9854 ± 0.0008
# Final Average Prediction Set Size: 2.66 ± 0.03
# Final Average Coverage: 0.9009 ± 0.0038
# Final Average Real Probability: 0.9846 ± 0.0008
# 76945 (61.87%) samples reached the peak conditional coverage at 0.9950

# %%
saps_imagenet_real_hist(model, dataset, device, lambda_=0.35, num_runs=10, alpha=0.1, is_ground_truth=True)
# Out:
# SAPS Classification on ImageNet Real (alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.2781 ± 0.0100
# Final Average Prediction Set Size: 2.62 ± 0.03
# Final Average Coverage: 0.9011 ± 0.0043
# Final Average Real Probability: 0.9761 ± 0.0008
# 78500 (63.12%) samples reached the peak conditional coverage at 0.9959

# %% [markdown]
# # $\alpha$=0.2

# %%
aps_imagenet_real_hist(model, dataset, device, num_runs, alpha=0.2, is_ground_truth=True)
# Out:
# APS Classification on ImageNet Real (alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9174 ± 0.0032
# Final Average Prediction Set Size: 1.89 ± 0.02
# Final Average Coverage: 0.8004 ± 0.0057
# Final Average Real Probability: 0.9172 ± 0.0039
# 45707 (36.75%) samples reached the peak conditional coverage at 0.9950

# %%
raps_imagenet_real_hist(model, dataset, device, lambda_=0.1, k_reg=8, num_runs=10, alpha=0.2, is_ground_truth=True)
# Out:
# RAPS Classification on ImageNet Real (alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9183 ± 0.0030
# Final Average Prediction Set Size: 1.86 ± 0.02
# Final Average Coverage: 0.8003 ± 0.0053
# Final Average Real Probability: 0.9174 ± 0.0034
# 45847 (36.87%) samples reached the peak conditional coverage at 0.9950

# %%
saps_imagenet_real_hist(model, dataset, device, lambda_=0.3, num_runs=10, alpha=0.2, is_ground_truth=True)
# Out:
# SAPS Classification on ImageNet Real (alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9324 ± 0.0041
# Final Average Prediction Set Size: 1.78 ± 0.01
# Final Average Coverage: 0.8005 ± 0.0050
# Final Average Real Probability: 0.9233 ± 0.0026
# 51206 (41.18%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# # $\alpha$=0.05

# %%
aps_imagenet_real_hist(model, dataset, device, num_runs, alpha=0.05, is_ground_truth=True)
# Out:
# APS Classification on ImageNet Real (alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9961 ± 0.0003
# Final Average Prediction Set Size: 3.98 ± 0.08
# Final Average Coverage: 0.9501 ± 0.0031
# Final Average Real Probability: 0.9961 ± 0.0003
# 120463 (96.87%) samples reached the peak conditional coverage at 0.9950

# %%
raps_imagenet_real_hist(model, dataset, device, lambda_=0.05, k_reg=11, num_runs=10, alpha=0.05, is_ground_truth=True)
# Out:
# RAPS Classification on ImageNet Real (alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9965 ± 0.0003
# Final Average Prediction Set Size: 3.83 ± 0.07
# Final Average Coverage: 0.9503 ± 0.0029
# Final Average Real Probability: 0.9954 ± 0.0002
# 118567 (95.34%) samples reached the peak conditional coverage at 0.9950

# %%
saps_imagenet_real_hist(model, dataset, device, lambda_=0.3, num_runs=10, alpha=0.05, is_ground_truth=True)
# Out:
# SAPS Classification on ImageNet Real (alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.5341 ± 0.0207
# Final Average Prediction Set Size: 3.75 ± 0.07
# Final Average Coverage: 0.9501 ± 0.0039
# Final Average Real Probability: 0.9898 ± 0.0003
# 98389 (79.12%) samples reached the peak conditional coverage at 0.9963
