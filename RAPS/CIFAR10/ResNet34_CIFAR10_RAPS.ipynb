# %% [markdown]
# # $\alpha$=0.1

# %%
import torch
import numpy as np
import torchvision.transforms as transforms               # include image preprocess tools
from torchvision.datasets import CIFAR10        # for loading images from Pytorch CIFAR
from torch.utils.data import DataLoader
import detectors
import timm
from src.raps import raps_test
from src.temperature_scaling import ModelWithTemperature

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# load fine-tuned model
model = timm.create_model("resnet34_cifar10", pretrained=True)
model = model.to(device)

# reprocess the images from CIFAR
data_transform = transforms.Compose([
    transforms.ToTensor(),          # transfer to tensor
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.2010])  # normalize
])
# load images from CIFAR10
dataset = CIFAR10(root="../../data", train=False, download=True, transform=data_transform)

temp_scal_loader = DataLoader(dataset, batch_size=32, shuffle=True)
model = ModelWithTemperature(model, temperature=5.0).to(device)
model.set_temperature(temp_scal_loader)

model.eval()

raps_test(model, dataset, device, num_runs=10, alpha=0.1, lambda_=0.01, k_reg=1)
# Out:
# Files already downloaded and verified
# Before temperature - NLL: 0.336, ECE: 0.045
# Optimal temperature: 4.904
# After temperature - NLL: 0.885, ECE: 0.467
# RAPS Classification, Start!
#
# Running experiment 1/10...
# t_cal = 0.48799266517162326
# Total set size: 6008
# Total coverage sets: 4493
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 1: 1.2016
# Average Coverage Rate in runs 1: 0.8986
#
# Running experiment 2/10...
# t_cal = 0.48474998474121095
# Total set size: 6005
# Total coverage sets: 4519
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 2: 1.201
# Average Coverage Rate in runs 2: 0.9038
#
# Running experiment 3/10...
# t_cal = 0.47654501199722293
# Total set size: 5770
# Total coverage sets: 4423
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 3: 1.154
# Average Coverage Rate in runs 3: 0.8846
#
# Running experiment 4/10...
# t_cal = 0.4753318250179291
# Total set size: 5758
# ...

# %% [markdown]
# # $\alpha$=0.05

# %%
raps_test(model, dataset, device, num_runs=10, alpha=0.05, lambda_=0.01, k_reg=2)
# Out:
# RAPS Classification, Start!
#
# Running experiment 1/10...
# t_cal = 0.5335195660591127
# Total set size: 7662
# Total coverage sets: 4756
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 1: 1.5324
# Average Coverage Rate in runs 1: 0.9512
#
# Running experiment 2/10...
# t_cal = 0.5328722149133684
# Total set size: 7680
# Total coverage sets: 4763
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 2: 1.536
# Average Coverage Rate in runs 2: 0.9526
#
# Running experiment 3/10...
# t_cal = 0.5265356779098512
# Total set size: 7438
# Total coverage sets: 4714
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 3: 1.4876
# Average Coverage Rate in runs 3: 0.9428
#
# Running experiment 4/10...
# t_cal = 0.5289952516555787
# Total set size: 7488
# Total coverage sets: 4715
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 4: 1.4976
# Average Coverage Rate in runs 4: 0.943
#
# ...

# %% [markdown]
# # Result
# $\alpha$=0.1
# - Final Average **Prediction Set Size： 1.18**
# - Final Average **Coverage: 89.46%**
#
# $\alpha$=0.05
# - Final Average **Prediction Set Size： 1.51**
# - Final Average **Coverage: 94.76%**
