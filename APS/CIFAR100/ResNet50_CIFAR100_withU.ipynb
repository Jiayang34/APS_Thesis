# %% [markdown]
# # $\alpha$=0.1

# %%
import torch
import numpy as np
import torchvision.transforms as transforms               # include image preprocess tools
from torchvision.datasets import CIFAR100        # for loading images from Pytorch CIFAR
from torch.utils.data import DataLoader
import timm
import detectors
from src.temperature_scaling import ModelWithTemperature
from src.aps import split_data_set, aps_scores, aps_classification, eval_aps

# check GPU status
print("Is CUDA available:", torch.cuda.is_available())
print("Device count:", torch.cuda.device_count())
print("Device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# load fine-tuned model
model = timm.create_model("resnet50_cifar100", pretrained=True)
model.to(device)

# reprocess the images from CIFAR
data_transform = transforms.Compose([
    transforms.ToTensor(),          # transfer to tensor
    transforms.Normalize((0.5071, 0.4865, 0.4409), (0.2673, 0.2564, 0.2762))  # normalize
])
# load images from CIFAR10
dataset = CIFAR100(root="../../data", train=False, download=True, transform=data_transform)

# Tempreture Scaling
temp_scal_loader = DataLoader(dataset, batch_size=32, shuffle=True)
model = ModelWithTemperature(model, temperature=4.85).to(device)
model.set_temperature(temp_scal_loader)

model.eval()

# The number of times the experiment is going to be repeated
num_runs = 10

# error rate
alpha = 0.1

# contruct and evaluate repeatedly
all_avg_set_sizes = []
all_avg_coverages = []
print("APS Classification, Start!\n")
for i in range(num_runs):
    print(f"Running experiment {i+1}/{num_runs}...")

    # splite dataset
    calib_dataset, test_dataset = split_data_set(dataset, random_seed=i)

    # load data set respectively
    calib_loader = DataLoader(calib_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    # calculate q_hat
    calib_scores, _ = aps_scores(model, calib_loader, alpha, device)
    q_hat = np.quantile(calib_scores, 1 - 0.1)  # calculate 1-alpha quantile
    print(f"q_hat = {q_hat}")

    # construct APS
    aps, aps_labels, true_labels = aps_classification(model, test_loader, q_hat, device)

    # evaluate APS
    avg_set_size, avg_coverage = eval_aps(aps_labels, true_labels)
    print(f"Average Prediction Set Size After APS in runs {i+1}: {avg_set_size}")
    print(f"Average Coverage Ratein runs {i+1}: {avg_coverage}\n")

    # record current result
    all_avg_set_sizes.append(avg_set_size)
    all_avg_coverages.append(avg_coverage)

# calculate the final average result
final_avg_set_size = np.mean(all_avg_set_sizes)
final_avg_coverage = np.mean(all_avg_coverages)

print(f"Final Average Prediction Set Size: {final_avg_set_size}")
print(f"Final Average Coverage: {final_avg_coverage}")
# Out:
# Is CUDA available: True
# Device count: 1
# Device name: NVIDIA GeForce RTX 3060 Ti
# Files already downloaded and verified
# Before temperature - NLL: 1.067, ECE: 0.086
# Optimal temperature: 4.691
# After temperature - NLL: 2.948, ECE: 0.673
# APS Classification, Start!
#
# Running experiment 1/10...
# q_hat = 0.15436151939298803
# Total set size: 19435
# Total coverage sets: 4541
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 1: 3.887
# Average Coverage Ratein runs 1: 0.9082
#
# Running experiment 2/10...
# q_hat = 0.15162377986564843
# Total set size: 18527
# Total coverage sets: 4507
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 2: 3.7054
# Average Coverage Ratein runs 2: 0.9014
#
# Running experiment 3/10...
# q_hat = 0.1484622369477019
# Total set size: 17929
# Total coverage sets: 4475
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 3: 3.5858
# Average Coverage Ratein runs 3: 0.895
#
# Running experiment 4/10...
# q_hat = 0.1492952031961142
# Total set size: 18073
# Total coverage sets: 4492
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 4: 3.6146
# Average Coverage Ratein runs 4: 0.8984
#
# Running experiment 5/10...
# q_hat = 0.15010551683133416
# Total set size: 18362
# Total coverage sets: 4517
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 5: 3.6724
# Average Coverage Ratein runs 5: 0.9034
#
# Running experiment 6/10...
# q_hat = 0.14793915894293702
# Total set size: 17851
# Total coverage sets: 4445
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 6: 3.5702
# Average Coverage Ratein runs 6: 0.889
#
# Running experiment 7/10...
# q_hat = 0.15162725575186364
# Total set size: 18673
# Total coverage sets: 4520
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 7: 3.7346
# Average Coverage Ratein runs 7: 0.904
#
# Running experiment 8/10...
# q_hat = 0.1483397478380719
# Total set size: 17895
# Total coverage sets: 4467
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 8: 3.579
# Average Coverage Ratein runs 8: 0.8934
#
# Running experiment 9/10...
# q_hat = 0.151557019553792
# Total set size: 18912
# Total coverage sets: 4515
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 9: 3.7824
# Average Coverage Ratein runs 9: 0.903
#
# Running experiment 10/10...
# q_hat = 0.14680651932176306
# Total set size: 17464
# Total coverage sets: 4440
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 10: 3.4928
# Average Coverage Ratein runs 10: 0.888
#
# Final Average Prediction Set Size: 3.66242
# Final Average Coverage: 0.8983800000000001

# %% [markdown]
# # $\alpha$=0.2

# %%
# error rate
alpha = 0.2

# contruct and evaluate repeatedly
all_avg_set_sizes = []
all_avg_coverages = []
print("APS Classification, Start!\n")
for i in range(num_runs):
    print(f"Running experiment {i+1}/{num_runs}...")

    # splite dataset
    calib_dataset, test_dataset = split_data_set(dataset, random_seed=i)

    # load data set respectively
    calib_loader = DataLoader(calib_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    # calculate q_hat
    calib_scores, _ = aps_scores(model, calib_loader, alpha, device)
    q_hat = np.quantile(calib_scores, 1 - alpha)  # calculate 1-alpha quantile
    print(f"q_hat = {q_hat}")

    # construct APS
    aps, aps_labels, true_labels = aps_classification(model, test_loader, q_hat, device)

    # evaluate APS
    avg_set_size, avg_coverage = eval_aps(aps_labels, true_labels)
    print(f"Average Prediction Set Size After APS in runs {i+1}: {avg_set_size}")
    print(f"Average Coverage Ratein runs {i+1}: {avg_coverage}\n")

    # record current result
    all_avg_set_sizes.append(avg_set_size)
    all_avg_coverages.append(avg_coverage)

# calculate the final average result
final_avg_set_size = np.mean(all_avg_set_sizes)
final_avg_coverage = np.mean(all_avg_coverages)

print(f"Final Average Prediction Set Size: {final_avg_set_size}")
print(f"Final Average Coverage: {final_avg_coverage}")
# Out:
# Files already downloaded and verified
# Before temperature - NLL: 1.074, ECE: 0.084
# Optimal temperature: 4.692
# After temperature - NLL: 2.953, ECE: 0.675
# APS Classification, Start!
#
# Running experiment 1/10...
# q_hat = 0.11372084468603134
# Total set size: 10809
# Total coverage sets: 4016
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 1: 2.1618
# Average Coverage Ratein runs 1: 0.8032
#
# Running experiment 2/10...
# q_hat = 0.11222351491451264
# Total set size: 10571
# Total coverage sets: 3978
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 2: 2.1142
# Average Coverage Ratein runs 2: 0.7956
#
# Running experiment 3/10...
# q_hat = 0.11385306864976885
# Total set size: 10841
# Total coverage sets: 4004
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 3: 2.1682
# Average Coverage Ratein runs 3: 0.8008
#
# Running experiment 4/10...
# q_hat = 0.11160065382719046
# Total set size: 10453
# Total coverage sets: 3963
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 4: 2.0906
# Average Coverage Ratein runs 4: 0.7926
#
# Running experiment 5/10...
# q_hat = 0.11355712860822678
# Total set size: 10847
# Total coverage sets: 3995
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 5: 2.1694
# Average Coverage Ratein runs 5: 0.799
#
# Running experiment 6/10...
# q_hat = 0.11286235153675082
# Total set size: 10779
# Total coverage sets: 3967
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 6: 2.1558
# Average Coverage Ratein runs 6: 0.7934
#
# Running experiment 7/10...
# q_hat = 0.11367408931255343
# Total set size: 10826
# Total coverage sets: 3992
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 7: 2.1652
# Average Coverage Ratein runs 7: 0.7984
#
# Running experiment 8/10...
# q_hat = 0.11168064028024674
# Total set size: 10546
# Total coverage sets: 3940
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 8: 2.1092
# Average Coverage Ratein runs 8: 0.788
#
# Running experiment 9/10...
# q_hat = 0.1133309617638588
# Total set size: 10948
# Total coverage sets: 4008
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 9: 2.1896
# Average Coverage Ratein runs 9: 0.8016
#
# Running experiment 10/10...
# q_hat = 0.11279831677675248
# Total set size: 10757
# Total coverage sets: 3991
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 10: 2.1514
# Average Coverage Ratein runs 10: 0.7982
#
# Final Average Prediction Set Size: 2.14754
# Final Average Coverage: 0.7970799999999999

# %%
# error rate
alpha = 0.05

# contruct and evaluate repeatedly
all_avg_set_sizes = []
all_avg_coverages = []
print("APS Classification, Start!\n")
for i in range(num_runs):
    print(f"Running experiment {i+1}/{num_runs}...")

    # splite dataset
    calib_dataset, test_dataset = split_data_set(dataset, random_seed=i)

    # load data set respectively
    calib_loader = DataLoader(calib_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    # calculate q_hat
    calib_scores, _ = aps_scores(model, calib_loader, alpha, device)
    q_hat = np.quantile(calib_scores, 1 - alpha)  # calculate 1-alpha quantile
    print(f"q_hat = {q_hat}")

    # construct APS
    aps, aps_labels, true_labels = aps_classification(model, test_loader, q_hat, device)

    # evaluate APS
    avg_set_size, avg_coverage = eval_aps(aps_labels, true_labels)
    print(f"Average Prediction Set Size After APS in runs {i+1}: {avg_set_size}")
    print(f"Average Coverage Ratein runs {i+1}: {avg_coverage}\n")

    # record current result
    all_avg_set_sizes.append(avg_set_size)
    all_avg_coverages.append(avg_coverage)

# calculate the final average result
final_avg_set_size = np.mean(all_avg_set_sizes)
final_avg_coverage = np.mean(all_avg_coverages)

print(f"Final Average Prediction Set Size: {final_avg_set_size}")
print(f"Final Average Coverage: {final_avg_coverage}")
# Out:
# Files already downloaded and verified
# Before temperature - NLL: 1.067, ECE: 0.086
# Optimal temperature: 4.691
# After temperature - NLL: 2.948, ECE: 0.673
# APS Classification, Start!
#
# Running experiment 1/10...
# q_hat = 0.19990299493074418
# Total set size: 33618
# Total coverage sets: 4770
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 1: 6.7236
# Average Coverage Ratein runs 1: 0.954
#
# Running experiment 2/10...
# q_hat = 0.1939282827079297
# Total set size: 31292
# Total coverage sets: 4738
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 2: 6.2584
# Average Coverage Ratein runs 2: 0.9476
#
# Running experiment 3/10...
# q_hat = 0.1937973700463772
# Total set size: 31513
# Total coverage sets: 4739
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 3: 6.3026
# Average Coverage Ratein runs 3: 0.9478
#
# Running experiment 4/10...
# q_hat = 0.19718252047896395
# Total set size: 32578
# Total coverage sets: 4748
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 4: 6.5156
# Average Coverage Ratein runs 4: 0.9496
#
# Running experiment 5/10...
# q_hat = 0.200347962230444
# Total set size: 33887
# Total coverage sets: 4772
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 5: 6.7774
# Average Coverage Ratein runs 5: 0.9544
#
# Running experiment 6/10...
# q_hat = 0.18690116629004483
# Total set size: 29215
# Total coverage sets: 4692
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 6: 5.843
# Average Coverage Ratein runs 6: 0.9384
#
# Running experiment 7/10...
# q_hat = 0.1959054917097092
# Total set size: 32170
# Total coverage sets: 4751
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 7: 6.434
# Average Coverage Ratein runs 7: 0.9502
#
# Running experiment 8/10...
# q_hat = 0.19435986131429672
# Total set size: 31682
# Total coverage sets: 4723
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 8: 6.3364
# Average Coverage Ratein runs 8: 0.9446
#
# Running experiment 9/10...
# q_hat = 0.19757209643721582
# Total set size: 33174
# Total coverage sets: 4750
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 9: 6.6348
# Average Coverage Ratein runs 9: 0.95
#
# Running experiment 10/10...
# q_hat = 0.1927071660757066
# Total set size: 31068
# Total coverage sets: 4729
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 10: 6.2136
# Average Coverage Ratein runs 10: 0.9458
#
# Final Average Prediction Set Size: 6.40394
# Final Average Coverage: 0.94824

# %% [markdown]
# # Result
#
# $\alpha$=0.1
# - Final Average **Prediction Set Size： 3.66**
# - Final Average **Coverage: 89.83%**
#
# $\alpha$=0.2
# - Final Average **Prediction Set Size： 2.14**
# - Final Average **Coverage: 79.70%**
#
# $\alpha$=0.05
# - Final Average **Prediction Set Size： 6.40**
# - Final Average **Coverage: 94.82%**
