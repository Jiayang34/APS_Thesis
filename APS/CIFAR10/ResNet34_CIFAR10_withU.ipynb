# %% [markdown]
# # $\alpha$=0.1

# %%
import torch
import numpy as np
import torchvision.transforms as transforms               
from torchvision.datasets import CIFAR10       
from torch.utils.data import DataLoader
import detectors
import timm
from src.temperature_scaling import ModelWithTemperature
from src.aps import aps_test

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# load fine-tuned model
model = timm.create_model("resnet34_cifar10", pretrained=True)
model.to(device)

# reprocess the images from CIFAR10
data_transform = transforms.Compose([
    transforms.ToTensor(),          # transfer to tensor
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.2010])  # normalize
])
# load images from CIFAR10
dataset = CIFAR10(root="../../data", train=False, download=True, transform=data_transform)

# Temperature Scaling
temp_scal_loader = DataLoader(dataset, batch_size=32, shuffle=True)
model = ModelWithTemperature(model, temperature=5.0).to(device)
model.set_temperature(temp_scal_loader)

model.eval()

# The number of times the experiment is going to be repeated
num_runs = 10

# error rate
alpha = 0.1

aps_test(model, dataset, device, num_runs=10, alpha=0.1)
# Out:
# Files already downloaded and verified
# Before temperature - NLL: 0.333, ECE: 0.045
# Optimal temperature: 4.904
# After temperature - NLL: 0.880, ECE: 0.466
# APS Classification, Start!
#
# Running experiment 1/10...
# q_hat = 0.47902144193649293
# Total set size: 6183
# Total coverage sets: 4478
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 1: 1.2366
# Average Coverage Rate in runs 1: 0.8956
#
# Running experiment 2/10...
# q_hat = 0.4775484055280686
# Total set size: 6222
# Total coverage sets: 4498
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 2: 1.2444
# Average Coverage Rate in runs 2: 0.8996
#
# Running experiment 3/10...
# q_hat = 0.4752652019262314
# Total set size: 6112
# Total coverage sets: 4446
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 3: 1.2224
# Average Coverage Rate in runs 3: 0.8892
#
# Running experiment 4/10...
# q_hat = 0.47388120591640487
# Total set size: 6086
# Total coverage sets: 4456
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 4: 1.2172
# Average Coverage Rate in runs 4: 0.8912
#
# Running experiment 5/10...
# q_hat = 0.4835995525121689
# Total set size: 6282
# Total coverage sets: 4542
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 5: 1.2564
# Average Coverage Rate in runs 5: 0.9084
#
# Running experiment 6/10...
# q_hat = 0.47565928697586063
# Total set size: 6068
# Total coverage sets: 4451
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 6: 1.2136
# Average Coverage Rate in runs 6: 0.8902
#
# Running experiment 7/10...
# q_hat = 0.48435598611831676
# Total set size: 6353
# Total coverage sets: 4522
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 7: 1.2706
# Average Coverage Rate in runs 7: 0.9044
#
# Running experiment 8/10...
# q_hat = 0.4758247762918473
# Total set size: 6074
# Total coverage sets: 4452
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 8: 1.2148
# Average Coverage Rate in runs 8: 0.8904
#
# Running experiment 9/10...
# q_hat = 0.4761484026908875
# Total set size: 6110
# Total coverage sets: 4476
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 9: 1.222
# Average Coverage Rate in runs 9: 0.8952
#
# Running experiment 10/10...
# q_hat = 0.4769531667232514
# Total set size: 6152
# Total coverage sets: 4452
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 10: 1.2304
# Average Coverage Rate in runs 10: 0.8904
#
# Final Average Prediction Set Size: 1.23 ± 0.02
# Final Average Coverage: 0.8955 ± 0.0063

# %% [markdown]
# # $\alpha$=0.05

# %%
aps_test(model, dataset, device, num_runs=10, alpha=0.05)
# Out:
# APS Classification, Start!
#
# Running experiment 1/10...
# q_hat = 0.5276373624801636
# Total set size: 7757
# Total coverage sets: 4734
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 1: 1.5514
# Average Coverage Rate in runs 1: 0.9468
#
# Running experiment 2/10...
# q_hat = 0.5281344681978226
# Total set size: 7823
# Total coverage sets: 4757
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 2: 1.5646
# Average Coverage Rate in runs 2: 0.9514
#
# Running experiment 3/10...
# q_hat = 0.5246659845113755
# Total set size: 7649
# Total coverage sets: 4739
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 3: 1.5298
# Average Coverage Rate in runs 3: 0.9478
#
# Running experiment 4/10...
# q_hat = 0.5255576133728027
# Total set size: 7630
# Total coverage sets: 4715
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 4: 1.526
# Average Coverage Rate in runs 4: 0.943
#
# Running experiment 5/10...
# q_hat = 0.5298999458551408
# Total set size: 7797
# Total coverage sets: 4763
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 5: 1.5594
# Average Coverage Rate in runs 5: 0.9526
#
# Running experiment 6/10...
# q_hat = 0.5230508863925935
# Total set size: 7602
# Total coverage sets: 4716
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 6: 1.5204
# Average Coverage Rate in runs 6: 0.9432
#
# Running experiment 7/10...
# q_hat = 0.5266918182373047
# Total set size: 7766
# Total coverage sets: 4733
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 7: 1.5532
# Average Coverage Rate in runs 7: 0.9466
#
# Running experiment 8/10...
# q_hat = 0.5296771973371506
# Total set size: 7768
# Total coverage sets: 4736
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 8: 1.5536
# Average Coverage Rate in runs 8: 0.9472
#
# Running experiment 9/10...
# q_hat = 0.5258108377456665
# Total set size: 7681
# Total coverage sets: 4735
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 9: 1.5362
# Average Coverage Rate in runs 9: 0.947
#
# Running experiment 10/10...
# q_hat = 0.5253057986497879
# Total set size: 7702
# Total coverage sets: 4724
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 10: 1.5404
# Average Coverage Rate in runs 10: 0.9448
#
# Final Average Prediction Set Size: 1.54 ± 0.01
# Final Average Coverage: 0.9470 ± 0.0029

# %% [markdown]
# # Result
# $\alpha$=0.1
# - Final Average **Prediction Set Size： 1.23**
# - Final Average **Coverage: 89.55%**
#
# $\alpha$=0.05
# - Final Average **Prediction Set Size： 1.54**
# - Final Average **Coverage: 94.70%**
