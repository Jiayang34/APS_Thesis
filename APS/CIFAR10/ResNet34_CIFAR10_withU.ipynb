# %% [markdown]
# # $\alpha$=0.1

# %%
import torch
import numpy as np
import torchvision.transforms as transforms               
from torchvision.datasets import CIFAR10       
from torch.utils.data import DataLoader
import detectors
import timm
from src.temperature_scaling import ModelWithTemperature
from src.aps import aps_test

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# load fine-tuned model
model = timm.create_model("resnet34_cifar10", pretrained=True)
model.to(device)

# reprocess the images from CIFAR10
data_transform = transforms.Compose([
    transforms.ToTensor(),          # transfer to tensor
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.2010])  # normalize
])
# load images from CIFAR10
dataset = CIFAR10(root="../../data", train=False, download=True, transform=data_transform)

# Temperature Scaling
temp_scal_loader = DataLoader(dataset, batch_size=32, shuffle=True)
model = ModelWithTemperature(model, temperature=5.0).to(device)
model.set_temperature(temp_scal_loader)

model.eval()

# The number of times the experiment is going to be repeated
num_runs = 10

# error rate
alpha = 0.1

aps_test(model, dataset, device, num_runs=10, alpha=0.1)
# Out:
# Files already downloaded and verified
# Before temperature - NLL: 0.331, ECE: 0.044
# Optimal temperature: 4.904
# After temperature - NLL: 0.882, ECE: 0.469
# APS Classification, Start!
#
# Running experiment 1/10...
# q_hat = 0.4819197863340378
# Total set size: 6259
# Total coverage sets: 4470
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 1: 1.2518
# Average Coverage Rate in runs 1: 0.894
#
# Running experiment 2/10...
# q_hat = 0.4808537185192109
# Total set size: 6303
# Total coverage sets: 4492
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 2: 1.2606
# Average Coverage Rate in runs 2: 0.8984
#
# Running experiment 3/10...
# q_hat = 0.4787407666444779
# Total set size: 6202
# Total coverage sets: 4445
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 3: 1.2404
# Average Coverage Rate in runs 3: 0.889
#
# Running experiment 4/10...
# q_hat = 0.4764268398284912
# Total set size: 6129
# Total coverage sets: 4441
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 4: 1.2258
# Average Coverage Rate in runs 4: 0.8882
#
# Running experiment 5/10...
# q_hat = 0.4860221147537232
# Total set size: 6295
# Total coverage sets: 4513
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 5: 1.259
# Average Coverage Rate in runs 5: 0.9026
#
# Running experiment 6/10...
# q_hat = 0.48000046610832214
# Total set size: 6167
# Total coverage sets: 4455
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 6: 1.2334
# Average Coverage Rate in runs 6: 0.891
#
# Running experiment 7/10...
# q_hat = 0.4853296697139742
# Total set size: 6404
# Total coverage sets: 4524
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 7: 1.2808
# Average Coverage Rate in runs 7: 0.9048
#
# Running experiment 8/10...
# q_hat = 0.48128813207149507
# Total set size: 6201
# Total coverage sets: 4459
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 8: 1.2402
# Average Coverage Rate in runs 8: 0.8918
#
# Running experiment 9/10...
# q_hat = 0.4800584018230438
# Total set size: 6215
# Total coverage sets: 4470
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 9: 1.243
# Average Coverage Rate in runs 9: 0.894
#
# Running experiment 10/10...
# q_hat = 0.4797062069177628
# Total set size: 6227
# Total coverage sets: 4448
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 10: 1.2454
# Average Coverage Rate in runs 10: 0.8896
#
# Final Average Prediction Set Size: 1.25 ± 0.01
# Final Average Coverage: 0.8943 ± 0.0055

# %% [markdown]
# # $\alpha$=0.05

# %%
aps_test(model, dataset, device, num_runs=10, alpha=0.05)
# Out:
# APS Classification, Start!
#
# Running experiment 1/10...
# q_hat = 0.5322149515151979
# Total set size: 7894
# Total coverage sets: 4722
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 1: 1.5788
# Average Coverage Rate in runs 1: 0.9444
#
# Running experiment 2/10...
# q_hat = 0.5284454137086868
# Total set size: 7804
# Total coverage sets: 4740
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 2: 1.5608
# Average Coverage Rate in runs 2: 0.948
#
# Running experiment 3/10...
# q_hat = 0.5294828057289125
# Total set size: 7838
# Total coverage sets: 4736
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 3: 1.5676
# Average Coverage Rate in runs 3: 0.9472
#
# Running experiment 4/10...
# q_hat = 0.5287661701440812
# Total set size: 7728
# Total coverage sets: 4701
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 4: 1.5456
# Average Coverage Rate in runs 4: 0.9402
#
# Running experiment 5/10...
# q_hat = 0.5365400612354279
# Total set size: 8050
# Total coverage sets: 4773
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 5: 1.61
# Average Coverage Rate in runs 5: 0.9546
#
# Running experiment 6/10...
# q_hat = 0.5276842534542086
# Total set size: 7715
# Total coverage sets: 4709
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 6: 1.543
# Average Coverage Rate in runs 6: 0.9418
#
# Running experiment 7/10...
# q_hat = 0.5311040610074997
# Total set size: 7915
# Total coverage sets: 4735
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 7: 1.583
# Average Coverage Rate in runs 7: 0.947
#
# Running experiment 8/10...
# q_hat = 0.5350858598947525
# Total set size: 7947
# Total coverage sets: 4737
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 8: 1.5894
# Average Coverage Rate in runs 8: 0.9474
#
# Running experiment 9/10...
# q_hat = 0.5283643424510956
# Total set size: 7736
# Total coverage sets: 4732
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 9: 1.5472
# Average Coverage Rate in runs 9: 0.9464
#
# Running experiment 10/10...
# q_hat = 0.5262140691280366
# Total set size: 7729
# Total coverage sets: 4725
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 10: 1.5458
# Average Coverage Rate in runs 10: 0.945
#
# Final Average Prediction Set Size: 1.57 ± 0.02
# Final Average Coverage: 0.9462 ± 0.0037

# %% [markdown]
# # Result
# $\alpha$=0.1
# - Final Average **Prediction Set Size： 1.25**
# - Final Average **Coverage: 89.43%**
#
# $\alpha$=0.05
# - Final Average **Prediction Set Size： 1.57**
# - Final Average **Coverage: 94.62%**
