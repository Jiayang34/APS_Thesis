# %% [markdown]
# # $\alpha$=0.1

# %%
import torch
import numpy as np
import torchvision.transforms as transforms               
from torchvision.datasets import CIFAR10       
from torch.utils.data import DataLoader
import detectors
import timm
from src.temperature_scaling import ModelWithTemperature
from src.aps import aps_test

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# load fine-tuned model
model = timm.create_model("vgg16_bn_cifar10", pretrained=True)
model.to(device)

# reprocess the images from CIFAR10
data_transform = transforms.Compose([
    transforms.ToTensor(),          # transfer to tensor
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.2010])  # normalize
])
# load images from CIFAR10
dataset = CIFAR10(root="../../data", train=False, download=True, transform=data_transform)


# Temperature Scaling
temp_scal_loader = DataLoader(dataset, batch_size=32, shuffle=True)
model = ModelWithTemperature(model, temperature=5.0).to(device)
model.set_temperature(temp_scal_loader)
model.eval()

aps_test(model, dataset, device, num_runs=10, alpha=0.1)
# Out:
# Files already downloaded and verified
# Before temperature - NLL: 0.407, ECE: 0.061
# Optimal temperature: 4.903
# After temperature - NLL: 0.913, ECE: 0.471
# APS Classification, Start!
#
# Running experiment 1/10...
# q_hat = 0.4569305330514909
# Total set size: 5711
# Total coverage sets: 4511
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 1: 1.1422
# Average Coverage Rate in runs 1: 0.9022
#
# Running experiment 2/10...
# q_hat = 0.4497526526451111
# Total set size: 5539
# Total coverage sets: 4469
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 2: 1.1078
# Average Coverage Rate in runs 2: 0.8938
#
# Running experiment 3/10...
# q_hat = 0.45087565481662756
# Total set size: 5583
# Total coverage sets: 4445
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 3: 1.1166
# Average Coverage Rate in runs 3: 0.889
#
# Running experiment 4/10...
# q_hat = 0.44959688782691953
# Total set size: 5560
# Total coverage sets: 4452
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 4: 1.112
# Average Coverage Rate in runs 4: 0.8904
#
# Running experiment 5/10...
# q_hat = 0.4518537223339081
# Total set size: 5620
# Total coverage sets: 4491
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 5: 1.124
# Average Coverage Rate in runs 5: 0.8982
#
# Running experiment 6/10...
# q_hat = 0.4553586572408676
# Total set size: 5643
# Total coverage sets: 4506
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 6: 1.1286
# Average Coverage Rate in runs 6: 0.9012
#
# Running experiment 7/10...
# q_hat = 0.4560088723897934
# Total set size: 5736
# Total coverage sets: 4522
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 7: 1.1472
# Average Coverage Rate in runs 7: 0.9044
#
# Running experiment 8/10...
# q_hat = 0.45557986795902256
# Total set size: 5676
# Total coverage sets: 4526
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 8: 1.1352
# Average Coverage Rate in runs 8: 0.9052
#
# Running experiment 9/10...
# q_hat = 0.4536337733268739
# Total set size: 5644
# Total coverage sets: 4513
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 9: 1.1288
# Average Coverage Rate in runs 9: 0.9026
#
# Running experiment 10/10...
# q_hat = 0.4500947445631027
# Total set size: 5591
# Total coverage sets: 4467
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 10: 1.1182
# Average Coverage Rate in runs 10: 0.8934
#
# Final Average Prediction Set Size: 1.13 ± 0.01
# Final Average Coverage: 0.8980 ± 0.0057

# %% [markdown]
# # $\alpha$=0.05

# %%
aps_test(model, dataset, device, num_runs=10, alpha=0.05)
# Out:
# APS Classification, Start!
#
# Running experiment 1/10...
# q_hat = 0.5029392689466476
# Total set size: 7271
# Total coverage sets: 4765
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 1: 1.4542
# Average Coverage Rate in runs 1: 0.953
#
# Running experiment 2/10...
# q_hat = 0.4896896943449977
# Total set size: 6722
# Total coverage sets: 4701
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 2: 1.3444
# Average Coverage Rate in runs 2: 0.9402
#
# Running experiment 3/10...
# q_hat = 0.4949464187026024
# Total set size: 6908
# Total coverage sets: 4727
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 3: 1.3816
# Average Coverage Rate in runs 3: 0.9454
#
# Running experiment 4/10...
# q_hat = 0.4924726352095604
# Total set size: 6827
# Total coverage sets: 4730
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 4: 1.3654
# Average Coverage Rate in runs 4: 0.946
#
# Running experiment 5/10...
# q_hat = 0.4970670700073242
# Total set size: 7025
# Total coverage sets: 4752
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 5: 1.405
# Average Coverage Rate in runs 5: 0.9504
#
# Running experiment 6/10...
# q_hat = 0.49709274917840957
# Total set size: 6973
# Total coverage sets: 4758
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 6: 1.3946
# Average Coverage Rate in runs 6: 0.9516
#
# Running experiment 7/10...
# q_hat = 0.49773461818695075
# Total set size: 7060
# Total coverage sets: 4755
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 7: 1.412
# Average Coverage Rate in runs 7: 0.951
#
# Running experiment 8/10...
# q_hat = 0.49999251216650015
# Total set size: 7083
# Total coverage sets: 4779
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 8: 1.4166
# Average Coverage Rate in runs 8: 0.9558
#
# Running experiment 9/10...
# q_hat = 0.49489029347896585
# Total set size: 6914
# Total coverage sets: 4740
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 9: 1.3828
# Average Coverage Rate in runs 9: 0.948
#
# Running experiment 10/10...
# q_hat = 0.4943179294466972
# Total set size: 6936
# Total coverage sets: 4733
# Total samples amount: 5000
# Average Prediction Set Size After APS in runs 10: 1.3872
# Average Coverage Rate in runs 10: 0.9466
#
# Final Average Prediction Set Size: 1.39 ± 0.03
# Final Average Coverage: 0.9488 ± 0.0043

# %% [markdown]
# # Result
# $\alpha$=0.1
# - Final Average **Prediction Set Size： 1.13**
# - Final Average **Coverage: 89.80%**
#
# $\alpha$=0.05
# - Final Average **Prediction Set Size： 1.39**
# - Final Average **Coverage: 94.88%**
