# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, saps_synthetic_data
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=3)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_3class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_3class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

saps_synthetic_data(model,dataset,device, lambda_=2.0, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average Prediction Set Size: 1.01 ± 0.00
# Final Average Coverage: 0.9484 ± 0.0045
# Final Average Real Probability: 0.9070 ± 0.0035
#  28653( 57.31%) Samples Reached the Peak of Real Probability at 0.9900

# %%
saps_synthetic_data(model,dataset,device, lambda_=2.0, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average Prediction Set Size: 0.96 ± 0.00
# Final Average Coverage: 0.8981 ± 0.0052
# Final Average Real Probability: 0.8568 ± 0.0042
#  26589( 53.18%) Samples Reached the Peak of Real Probability at 0.9900

# %%
saps_synthetic_data(model,dataset,device, lambda_=2.0, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average Prediction Set Size: 0.84 ± 0.01
# Final Average Coverage: 0.7959 ± 0.0093
# Final Average Real Probability: 0.7572 ± 0.0078
#  23052( 46.10%) Samples Reached the Peak of Real Probability at 0.9900
