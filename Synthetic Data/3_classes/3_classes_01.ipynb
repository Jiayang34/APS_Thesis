# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_hist, raps_synthetic_data_scatter, saps_synthetic_data_scatter, saps_synthetic_data_hist
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=3)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_3class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_3class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9004 ± 0.0040
# Final Average Prediction Set Size: 1.44 ± 0.02
# Final Average Coverage: 0.8970 ± 0.0067
# Final Average Real Probability: 0.8995 ± 0.0042
# 11499 (23.00%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.01, k_reg=1, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9076 ± 0.0038
# Final Average Prediction Set Size: 1.43 ± 0.02
# Final Average Coverage: 0.8976 ± 0.0067
# Final Average Real Probability: 0.9000 ± 0.0043
# 10976 (21.95%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.4, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9429 ± 0.0040
# Final Average Prediction Set Size: 1.38 ± 0.01
# Final Average Coverage: 0.9011 ± 0.0049
# Final Average Real Probability: 0.9031 ± 0.0032
# 10315 (20.63%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8950 ± 0.0041
# Final Average Prediction Set Size: 1.31 ± 0.01
# Final Average Coverage: 0.8996 ± 0.0062
# Final Average Real Probability: 0.8552 ± 0.0049
# 9296 (18.59%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8950 ± 0.0041
# Final Average Prediction Set Size: 1.31 ± 0.01
# Final Average Coverage: 0.8996 ± 0.0062
# Final Average Real Probability: 0.8552 ± 0.0049
# Peak Conditional Coverage = 0.997, with 8239 samples
#
# === Count Regions Summary ===
# 38822 (77.6%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 32 (0.1%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 8811 (17.6%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.73715']
#   Real Probability Set      : ['0.88203']
# Sample 2:
#   Predictive Probability Set: ['0.96619']
#   Real Probability Set      : ['0.88942']
# Sample 3:
#   Predictive Probability Set: ['0.91623']
#   Real Probability Set      : ['0.95578']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.62195']
#   Real Probability Set      : ['0.16708']
# Sample 2:
#   Predictive Probability Set: ['0.49601']
#   Real Probability Set      : ['0.08202']
# Sample 3:
#   Predictive Probability Set: ['0.59425']
#   Real Probability Set      : ['0.09999']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.85008', '0.08522']
#   Real Probability Set      : ['0.46293', '0.29808']
# Sample 2:
#   Predictive Probability Set: ['0.66323', '0.21080']
#   Real Probability Set      : ['0.24212', '0.40629']
# Sample 3:
#   Predictive Probability Set: ['0.66622', '0.19060']
#   Real Probability Set      : ['0.23855', '0.42267']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.82152', '0.14107']
#   Real Probability Set      : ['0.21225', '0.66327']
# Sample 2:
#   Predictive Probability Set: ['0.83699', '0.09116']
#   Real Probability Set      : ['0.31060', '0.66369']
# Sample 3:
#   Predictive Probability Set: ['0.84810', '0.14437']
#   Real Probability Set      : ['0.17309', '0.82352']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.50297']
#   Real Probability Set      : ['0.15213']
# Sample 2:
#   Predictive Probability Set: ['0.49701']
#   Real Probability Set      : ['0.13635']
# Sample 3:
#   Predictive Probability Set: ['0.51655']
#   Real Probability Set      : ['0.17442']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.01, k_reg=1, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9012 ± 0.0042
# Final Average Prediction Set Size: 1.30 ± 0.01
# Final Average Coverage: 0.9001 ± 0.0056
# Final Average Real Probability: 0.8546 ± 0.0044
# 8912 (17.82%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.01, k_reg=1, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9012 ± 0.0042
# Final Average Prediction Set Size: 1.30 ± 0.01
# Final Average Coverage: 0.9001 ± 0.0056
# Final Average Real Probability: 0.8546 ± 0.0044
# Peak Conditional Coverage = 0.997, with 7861 samples
#
# === Count Regions Summary ===
# 38639 (77.3%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 29 (0.1%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 9272 (18.5%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99243']
#   Real Probability Set      : ['0.99219']
# Sample 2:
#   Predictive Probability Set: ['0.85394']
#   Real Probability Set      : ['0.83011']
# Sample 3:
#   Predictive Probability Set: ['0.95572']
#   Real Probability Set      : ['0.84128']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.59425']
#   Real Probability Set      : ['0.09999']
# Sample 2:
#   Predictive Probability Set: ['0.60247']
#   Real Probability Set      : ['0.11477']
# Sample 3:
#   Predictive Probability Set: ['0.84810']
#   Real Probability Set      : ['0.17309']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.82615', '0.08925']
#   Real Probability Set      : ['0.41637', '0.28966']
# Sample 2:
#   Predictive Probability Set: ['0.70257', '0.16378']
#   Real Probability Set      : ['0.26598', '0.51529']
# Sample 3:
#   Predictive Probability Set: ['0.73451', '0.14243']
#   Real Probability Set      : ['0.33666', '0.35857']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.83715', '0.13970']
#   Real Probability Set      : ['0.26764', '0.72782']
# Sample 2:
#   Predictive Probability Set: ['0.82152', '0.14107']
#   Real Probability Set      : ['0.21225', '0.66327']
# Sample 3:
#   Predictive Probability Set: ['0.84285', '0.07874']
#   Real Probability Set      : ['0.32073', '0.57191']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.50297']
#   Real Probability Set      : ['0.15213']
# Sample 2:
#   Predictive Probability Set: ['0.49701']
#   Real Probability Set      : ['0.13635']
# Sample 3:
#   Predictive Probability Set: ['0.50297']
#   Real Probability Set      : ['0.15213']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.4, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9231 ± 0.0047
# Final Average Prediction Set Size: 1.23 ± 0.01
# Final Average Coverage: 0.9001 ± 0.0062
# Final Average Real Probability: 0.8465 ± 0.0055
# 8205 (16.41%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.4, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9231 ± 0.0047
# Final Average Prediction Set Size: 1.23 ± 0.01
# Final Average Coverage: 0.9001 ± 0.0062
# Final Average Real Probability: 0.8465 ± 0.0055
# Peak Conditional Coverage = 0.995, with 7906 samples
#
# === Count Regions Summary ===
# 36727 (73.5%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 21 (0.0%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 12042 (24.1%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.51584', '0.26469']
#   Real Probability Set      : ['0.55262', '0.30459']
# Sample 2:
#   Predictive Probability Set: ['0.97207']
#   Real Probability Set      : ['0.95798']
# Sample 3:
#   Predictive Probability Set: ['0.60908', '0.31395']
#   Real Probability Set      : ['0.56501', '0.37157']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.56668']
#   Real Probability Set      : ['0.16308']
# Sample 2:
#   Predictive Probability Set: ['0.67399']
#   Real Probability Set      : ['0.15346']
# Sample 3:
#   Predictive Probability Set: ['0.62570']
#   Real Probability Set      : ['0.14970']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.47524', '0.27510']
#   Real Probability Set      : ['0.15303', '0.58048']
# Sample 2:
#   Predictive Probability Set: ['0.68103', '0.20363']
#   Real Probability Set      : ['0.19848', '0.38989']
# Sample 3:
#   Predictive Probability Set: ['0.56668', '0.25401']
#   Real Probability Set      : ['0.16308', '0.62832']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.71375', '0.21878']
#   Real Probability Set      : ['0.18129', '0.72743']
# Sample 2:
#   Predictive Probability Set: ['0.83780', '0.15822']
#   Real Probability Set      : ['0.27056', '0.72515']
# Sample 3:
#   Predictive Probability Set: ['0.84285', '0.07874']
#   Real Probability Set      : ['0.32073', '0.57191']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.55290']
#   Real Probability Set      : ['0.19058']
# Sample 2:
#   Predictive Probability Set: ['0.58095']
#   Real Probability Set      : ['0.18533']
