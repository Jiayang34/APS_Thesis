# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_hist, raps_synthetic_data_scatter, saps_synthetic_data_scatter, saps_synthetic_data_hist
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=3)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_3class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_3class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9507 ± 0.0023
# Final Average Prediction Set Size: 1.70 ± 0.02
# Final Average Coverage: 0.9494 ± 0.0033
# Final Average Real Probability: 0.9510 ± 0.0021
# 18489 (36.98%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.01, k_reg=2, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9532 ± 0.0030
# Final Average Prediction Set Size: 1.69 ± 0.02
# Final Average Coverage: 0.9500 ± 0.0040
# Final Average Real Probability: 0.9512 ± 0.0027
# 17894 (35.79%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.3, num_runs=10, alpha=0.05)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9987 ± 0.0056
# Final Average Prediction Set Size: 1.66 ± 0.02
# Final Average Coverage: 0.9508 ± 0.0030
# Final Average Real Probability: 0.9523 ± 0.0018
# 18342 (36.68%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9449 ± 0.0018
# Final Average Prediction Set Size: 1.55 ± 0.01
# Final Average Coverage: 0.9486 ± 0.0033
# Final Average Real Probability: 0.9202 ± 0.0032
# 14624 (29.25%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9449 ± 0.0018
# Final Average Prediction Set Size: 1.55 ± 0.01
# Final Average Coverage: 0.9486 ± 0.0033
# Final Average Real Probability: 0.9202 ± 0.0032
# Peak Conditional Coverage = 0.995, with 10743 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.95507']
#   Real Probability Set      : ['0.88100']
# Sample 2:
#   Predictive Probability Set: ['0.67859', '0.31774']
#   Real Probability Set      : ['0.72428', '0.26850']
# Sample 3:
#   Predictive Probability Set: ['0.90740', '0.05437']
#   Real Probability Set      : ['0.89890', '0.08277']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.62570']
#   Real Probability Set      : ['0.14970']
# Sample 2:
#   Predictive Probability Set: ['0.59425']
#   Real Probability Set      : ['0.09999']
# Sample 3:
#   Predictive Probability Set: ['0.84810']
#   Real Probability Set      : ['0.17309']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.58712', '0.21905']
#   Real Probability Set      : ['0.16300', '0.43079']
# Sample 2:
#   Predictive Probability Set: ['0.86731', '0.09227']
#   Real Probability Set      : ['0.41946', '0.36450']
# Sample 3:
#   Predictive Probability Set: ['0.78469', '0.12696']
#   Real Probability Set      : ['0.27894', '0.28738']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.82152', '0.14107']
#   Real Probability Set      : ['0.21225', '0.66327']
# Sample 2:
#   Predictive Probability Set: ['0.83780', '0.15822']
#   Real Probability Set      : ['0.27056', '0.72515']
# Sample 3:
#   Predictive Probability Set: ['0.83715', '0.13970']
#   Real Probability Set      : ['0.26764', '0.72782']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.05, k_reg=2, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9526 ± 0.0022
# Final Average Prediction Set Size: 1.54 ± 0.01
# Final Average Coverage: 0.9499 ± 0.0034
# Final Average Real Probability: 0.9215 ± 0.0034
# 12910 (25.82%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.05, k_reg=2, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9526 ± 0.0022
# Final Average Prediction Set Size: 1.54 ± 0.01
# Final Average Coverage: 0.9499 ± 0.0034
# Final Average Real Probability: 0.9215 ± 0.0034
# Peak Conditional Coverage = 0.995, with 11441 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99065']
#   Real Probability Set      : ['0.99753']
# Sample 2:
#   Predictive Probability Set: ['0.91392', '0.04426']
#   Real Probability Set      : ['0.95397', '0.01873']
# Sample 3:
#   Predictive Probability Set: ['0.77210', '0.19388']
#   Real Probability Set      : ['0.70806', '0.26598']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.84810']
#   Real Probability Set      : ['0.17309']
# Sample 2:
#   Predictive Probability Set: ['0.62570']
#   Real Probability Set      : ['0.14970']
# Sample 3:
#   Predictive Probability Set: ['0.59425']
#   Real Probability Set      : ['0.09999']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.85008', '0.08522']
#   Real Probability Set      : ['0.46293', '0.29808']
# Sample 2:
#   Predictive Probability Set: ['0.56706', '0.21847']
#   Real Probability Set      : ['0.14503', '0.65322']
# Sample 3:
#   Predictive Probability Set: ['0.86731', '0.09227']
#   Real Probability Set      : ['0.41946', '0.36450']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.71257', '0.23757']
#   Real Probability Set      : ['0.21251', '0.76166']
# Sample 2:
#   Predictive Probability Set: ['0.79877', '0.19846']
#   Real Probability Set      : ['0.26882', '0.73106']
# Sample 3:
#   Predictive Probability Set: ['0.82379', '0.11772']
#   Real Probability Set      : ['0.29498', '0.61421']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.27, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9797 ± 0.0032
# Final Average Prediction Set Size: 1.51 ± 0.01
# Final Average Coverage: 0.9530 ± 0.0031
# Final Average Real Probability: 0.9170 ± 0.0028
# 14510 (29.02%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.27, num_runs=10, alpha=0.05)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9797 ± 0.0032
# Final Average Prediction Set Size: 1.51 ± 0.01
# Final Average Coverage: 0.9530 ± 0.0031
# Final Average Real Probability: 0.9170 ± 0.0028
# Peak Conditional Coverage = 0.998, with 12542 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.94611', '0.04421']
#   Real Probability Set      : ['0.96608', '0.02652']
# Sample 2:
#   Predictive Probability Set: ['0.93268']
#   Real Probability Set      : ['0.95825']
# Sample 3:
#   Predictive Probability Set: ['0.95865']
#   Real Probability Set      : ['0.83930']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.84810']
#   Real Probability Set      : ['0.17309']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.78469', '0.12696']
#   Real Probability Set      : ['0.27894', '0.28738']
# Sample 2:
#   Predictive Probability Set: ['0.73451', '0.14243']
#   Real Probability Set      : ['0.33666', '0.35857']
# Sample 3:
#   Predictive Probability Set: ['0.65874', '0.24499']
#   Real Probability Set      : ['0.27849', '0.48494']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.71257', '0.23757']
#   Real Probability Set      : ['0.21251', '0.76166']
# Sample 2:
#   Predictive Probability Set: ['0.71257', '0.23757']
#   Real Probability Set      : ['0.21251', '0.76166']
# Sample 3:
#   Predictive Probability Set: ['0.83780', '0.15822']
#   Real Probability Set      : ['0.27056', '0.72515']
