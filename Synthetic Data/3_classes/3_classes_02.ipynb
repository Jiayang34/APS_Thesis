# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_hist, raps_synthetic_data_scatter, saps_synthetic_data_scatter, saps_synthetic_data_hist
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=3)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_3class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_3class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7996 ± 0.0050
# Final Average Prediction Set Size: 1.15 ± 0.01
# Final Average Coverage: 0.7968 ± 0.0065
# Final Average Real Probability: 0.7987 ± 0.0033
# 6413 (12.83%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.01, k_reg=1, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8046 ± 0.0050
# Final Average Prediction Set Size: 1.14 ± 0.01
# Final Average Coverage: 0.7963 ± 0.0066
# Final Average Real Probability: 0.7984 ± 0.0037
# 6259 (12.52%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.5, num_runs=10, alpha=0.2)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8301 ± 0.0048
# Final Average Prediction Set Size: 1.12 ± 0.01
# Final Average Coverage: 0.7982 ± 0.0063
# Final Average Real Probability: 0.8022 ± 0.0053
# 6265 (12.53%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7931 ± 0.0048
# Final Average Prediction Set Size: 1.05 ± 0.01
# Final Average Coverage: 0.7995 ± 0.0075
# Final Average Real Probability: 0.7409 ± 0.0056
# 5692 (11.38%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7931 ± 0.0048
# Final Average Prediction Set Size: 1.05 ± 0.01
# Final Average Coverage: 0.7995 ± 0.0075
# Final Average Real Probability: 0.7409 ± 0.0056
# Peak Conditional Coverage = 0.997, with 4943 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.96906']
#   Real Probability Set      : ['0.95759']
# Sample 2:
#   Predictive Probability Set: ['0.94546']
#   Real Probability Set      : ['0.84294']
# Sample 3:
#   Predictive Probability Set: ['0.96113']
#   Real Probability Set      : ['0.84337']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.59839']
#   Real Probability Set      : ['0.18353']
# Sample 2:
#   Predictive Probability Set: ['0.58712']
#   Real Probability Set      : ['0.16300']
# Sample 3:
#   Predictive Probability Set: ['0.49601']
#   Real Probability Set      : ['0.08202']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.78469', '0.12696']
#   Real Probability Set      : ['0.27894', '0.28738']
# Sample 2:
#   Predictive Probability Set: ['0.47524', '0.27510']
#   Real Probability Set      : ['0.15303', '0.58048']
# Sample 3:
#   Predictive Probability Set: ['0.68103', '0.20363']
#   Real Probability Set      : ['0.19848', '0.38989']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.71375', '0.21878']
#   Real Probability Set      : ['0.18129', '0.72743']
# Sample 2:
#   Predictive Probability Set: ['0.71257', '0.23757']
#   Real Probability Set      : ['0.21251', '0.76166']
# Sample 3:
#   Predictive Probability Set: ['0.71375', '0.21878']
#   Real Probability Set      : ['0.18129', '0.72743']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.01, k_reg=1, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7963 ± 0.0047
# Final Average Prediction Set Size: 1.04 ± 0.01
# Final Average Coverage: 0.7998 ± 0.0075
# Final Average Real Probability: 0.7403 ± 0.0055
# 5569 (11.14%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.01, k_reg=1, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7963 ± 0.0047
# Final Average Prediction Set Size: 1.04 ± 0.01
# Final Average Coverage: 0.7998 ± 0.0075
# Final Average Real Probability: 0.7403 ± 0.0055
# Peak Conditional Coverage = 0.997, with 4831 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.57178', '0.31600']
#   Real Probability Set      : ['0.58970', '0.31630']
# Sample 2:
#   Predictive Probability Set: ['0.94983']
#   Real Probability Set      : ['0.92597']
# Sample 3:
#   Predictive Probability Set: ['0.99366']
#   Real Probability Set      : ['0.98433']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.66545']
#   Real Probability Set      : ['0.14238']
# Sample 2:
#   Predictive Probability Set: ['0.55064']
#   Real Probability Set      : ['0.13845']
# Sample 3:
#   Predictive Probability Set: ['0.67399']
#   Real Probability Set      : ['0.15346']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.66690', '0.20716']
#   Real Probability Set      : ['0.25537', '0.43862']
# Sample 2:
#   Predictive Probability Set: ['0.66622', '0.19060']
#   Real Probability Set      : ['0.23855', '0.42267']
# Sample 3:
#   Predictive Probability Set: ['0.58712', '0.21905']
#   Real Probability Set      : ['0.16300', '0.43079']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.71375', '0.21878']
#   Real Probability Set      : ['0.18129', '0.72743']
# Sample 2:
#   Predictive Probability Set: ['0.71375', '0.21878']
#   Real Probability Set      : ['0.18129', '0.72743']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.9, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8691 ± 0.0065
# Final Average Prediction Set Size: 1.03 ± 0.01
# Final Average Coverage: 0.8281 ± 0.0081
# Final Average Real Probability: 0.7628 ± 0.0064
# 5640 (11.28%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.9, num_runs=10, alpha=0.2)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8691 ± 0.0065
# Final Average Prediction Set Size: 1.03 ± 0.01
# Final Average Coverage: 0.8281 ± 0.0081
# Final Average Real Probability: 0.7628 ± 0.0064
# Peak Conditional Coverage = 0.997, with 4858 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.55927', '0.39935']
#   Real Probability Set      : ['0.64428', '0.32798']
# Sample 2:
#   Predictive Probability Set: ['0.98571']
#   Real Probability Set      : ['0.96303']
# Sample 3:
#   Predictive Probability Set: ['0.94994']
#   Real Probability Set      : ['0.95592']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.66545']
#   Real Probability Set      : ['0.14238']
# Sample 2:
#   Predictive Probability Set: ['0.60943']
#   Real Probability Set      : ['0.15914']
# Sample 3:
#   Predictive Probability Set: ['0.56706']
#   Real Probability Set      : ['0.14503']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.78469', '0.12696']
#   Real Probability Set      : ['0.27894', '0.28738']
# Sample 2:
#   Predictive Probability Set: ['0.68103', '0.20363']
#   Real Probability Set      : ['0.19848', '0.38989']
# Sample 3:
#   Predictive Probability Set: ['0.66622', '0.19060']
#   Real Probability Set      : ['0.23855', '0.42267']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.79877', '0.19846']
#   Real Probability Set      : ['0.26882', '0.73106']
# Sample 2:
#   Predictive Probability Set: ['0.71375', '0.21878']
#   Real Probability Set      : ['0.18129', '0.72743']
# Sample 3:
#   Predictive Probability Set: ['0.78622', '0.19865']
#   Real Probability Set      : ['0.28038', '0.70845']
