# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_hist, raps_synthetic_data_scatter, saps_synthetic_data_scatter, saps_synthetic_data_hist
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=3)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_3class_NoTemp_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_3class_NoTemp_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7978 ± 0.0054
# Final Average Prediction Set Size: 0.91 ± 0.01
# Final Average Coverage: 0.7983 ± 0.0074
# Final Average Real Probability: 0.7991 ± 0.0071
# 24621 (49.24%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.01, k_reg=1, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7992 ± 0.0053
# Final Average Prediction Set Size: 0.90 ± 0.01
# Final Average Coverage: 0.7983 ± 0.0073
# Final Average Real Probability: 0.7990 ± 0.0069
# 24512 (49.02%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.5, num_runs=10, alpha=0.2)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8029 ± 0.0053
# Final Average Prediction Set Size: 0.89 ± 0.01
# Final Average Coverage: 0.7967 ± 0.0085
# Final Average Real Probability: 0.7973 ± 0.0078
# 24370 (48.74%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# # Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7920 ± 0.0070
# Final Average Prediction Set Size: 0.84 ± 0.01
# Final Average Coverage: 0.7990 ± 0.0094
# Final Average Real Probability: 0.7454 ± 0.0075
# 23314 (46.63%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7920 ± 0.0070
# Final Average Prediction Set Size: 0.84 ± 0.01
# Final Average Coverage: 0.7990 ± 0.0094
# Final Average Real Probability: 0.7454 ± 0.0075
# Peak Conditional Coverage = 0.996, with 22943 samples
#
# === Count Regions Summary ===
# 34446 (68.9%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 69 (0.1%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 6357 (12.7%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.98609']
#   Real Probability Set      : ['0.80270']
# ...

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=1, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7956 ± 0.0070
# Final Average Prediction Set Size: 0.83 ± 0.01
# Final Average Coverage: 0.7986 ± 0.0096
# Final Average Real Probability: 0.7430 ± 0.0070
# 23013 (46.03%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.1, k_reg=1, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7956 ± 0.0070
# Final Average Prediction Set Size: 0.83 ± 0.01
# Final Average Coverage: 0.7986 ± 0.0096
# Final Average Real Probability: 0.7430 ± 0.0070
# Peak Conditional Coverage = 0.996, with 22646 samples
#
# === Count Regions Summary ===
# 34195 (68.4%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 13 (0.0%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 6846 (13.7%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99999']
#   Real Probability Set      : ['1.00000']
# ...

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=2.0, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7969 ± 0.0073
# Final Average Prediction Set Size: 0.83 ± 0.01
# Final Average Coverage: 0.7983 ± 0.0107
# Final Average Real Probability: 0.7423 ± 0.0083
# 22969 (45.94%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=2.0, num_runs=10, alpha=0.2)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7969 ± 0.0073
# Final Average Prediction Set Size: 0.83 ± 0.01
# Final Average Coverage: 0.7983 ± 0.0107
# Final Average Real Probability: 0.7423 ± 0.0083
# Peak Conditional Coverage = 0.996, with 22591 samples
#
# === Count Regions Summary ===
# 34124 (68.2%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 11 (0.0%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 6994 (14.0%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['1.00000']
# ...
