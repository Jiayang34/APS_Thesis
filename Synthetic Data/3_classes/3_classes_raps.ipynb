# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, raps_synthetic_data
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=3)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_3class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_3class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

raps_synthetic_data(model,dataset,device, lambda_=1e-4, k_reg=1, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9495 ± 0.0030
# Final Average Prediction Set Size: 2.27 ± 0.03
# Final Average Coverage: 0.9570 ± 0.0034
# Final Average Real Probability: 0.9304 ± 0.0037
# 2387 (4.77%) samples reached the real probability at 1-alpha = 0.9500

# %%
raps_synthetic_data(model,dataset,device, lambda_=0.01, k_reg=2, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9034 ± 0.0038
# Final Average Prediction Set Size: 1.91 ± 0.02
# Final Average Coverage: 0.9125 ± 0.0051
# Final Average Real Probability: 0.8678 ± 0.0045
# 2086 (4.17%) samples reached the real probability at 1-alpha = 0.9000

# %%
raps_synthetic_data(model,dataset,device, lambda_=0.1, k_reg=1, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8103 ± 0.0059
# Final Average Prediction Set Size: 0.86 ± 0.01
# Final Average Coverage: 0.8115 ± 0.0071
# Final Average Real Probability: 0.7667 ± 0.0079
#  23616( 47.23%) Samples Reached the Peak of Real Probability at 0.9900
# C:\Users\jiayang\anaconda3\envs\pytorch2\lib\site-packages\numpy\_core\fromnumeric.py:4008: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\jiayang\anaconda3\envs\pytorch2\lib\site-packages\numpy\_core\_methods.py:175: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# C:\Users\jiayang\anaconda3\envs\pytorch2\lib\site-packages\numpy\_core\_methods.py:210: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
