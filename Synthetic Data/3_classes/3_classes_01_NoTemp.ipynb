# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_hist, raps_synthetic_data_scatter, saps_synthetic_data_scatter, saps_synthetic_data_hist
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=3)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_3class_NoTemp_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_3class_NoTemp_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8970 ± 0.0041
# Final Average Prediction Set Size: 1.06 ± 0.01
# Final Average Coverage: 0.8966 ± 0.0065
# Final Average Real Probability: 0.8968 ± 0.0059
# 29989 (59.98%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.01, k_reg=1, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8997 ± 0.0043
# Final Average Prediction Set Size: 1.05 ± 0.01
# Final Average Coverage: 0.8967 ± 0.0069
# Final Average Real Probability: 0.8971 ± 0.0063
# 29746 (59.49%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.4, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9053 ± 0.0025
# Final Average Prediction Set Size: 1.04 ± 0.01
# Final Average Coverage: 0.8976 ± 0.0040
# Final Average Real Probability: 0.8979 ± 0.0032
# 29312 (58.62%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8928 ± 0.0046
# Final Average Prediction Set Size: 0.97 ± 0.01
# Final Average Coverage: 0.8985 ± 0.0076
# Final Average Real Probability: 0.8469 ± 0.0061
# 27199 (54.40%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8928 ± 0.0046
# Final Average Prediction Set Size: 0.97 ± 0.01
# Final Average Coverage: 0.8985 ± 0.0076
# Final Average Real Probability: 0.8469 ± 0.0061
# Peak Conditional Coverage = 0.996, with 26762 samples
#
# === Count Regions Summary ===
# 39537 (79.1%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 258 (0.5%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 5768 (11.5%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.77965', '0.22034']
#   Real Probability Set      : ['0.69056', '0.30944']
# Sample 2:
#   Predictive Probability Set: ['0.99999']
#   Real Probability Set      : ['0.99999']
# Sample 3:
#   Predictive Probability Set: ['0.99772']
#   Real Probability Set      : ['0.99286']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.89879']
#   Real Probability Set      : ['0.17259']
# Sample 2:
#   Predictive Probability Set: ['0.55100', '0.27316']
#   Real Probability Set      : ['0.11581', '0.03493']
# Sample 3:
#   Predictive Probability Set: ['0.70051']
#   Real Probability Set      : ['0.05090']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.81267', '0.09961']
#   Real Probability Set      : ['0.33883', '0.36327']
# Sample 2:
#   Predictive Probability Set: ['0.77838', '0.16002']
#   Real Probability Set      : ['0.15802', '0.32090']
# Sample 3:
#   Predictive Probability Set: ['0.72190', '0.20411']
#   Real Probability Set      : ['0.20240', '0.51789']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.66377', '0.33623']
#   Real Probability Set      : ['0.09195', '0.90805']
# Sample 2:
#   Predictive Probability Set: ['0.80926', '0.13644']
#   Real Probability Set      : ['0.11657', '0.79352']
# Sample 3:
#   Predictive Probability Set: ['0.67942', '0.31808']
#   Real Probability Set      : ['0.02014', '0.97983']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.57223']
#   Real Probability Set      : ['0.19470']
# Sample 2:
#   Predictive Probability Set: ['0.54083']
#   Real Probability Set      : ['0.18501']
# Sample 3:
#   Predictive Probability Set: ['0.57223']
#   Real Probability Set      : ['0.19470']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.05, k_reg=1, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8956 ± 0.0051
# Final Average Prediction Set Size: 0.95 ± 0.01
# Final Average Coverage: 0.8975 ± 0.0084
# Final Average Real Probability: 0.8413 ± 0.0064
# 26611 (53.22%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.05, k_reg=1, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8956 ± 0.0051
# Final Average Prediction Set Size: 0.95 ± 0.01
# Final Average Coverage: 0.8975 ± 0.0084
# Final Average Real Probability: 0.8413 ± 0.0064
# Peak Conditional Coverage = 0.996, with 26185 samples
#
# === Count Regions Summary ===
# 39113 (78.2%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 143 (0.3%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 6461 (12.9%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99776']
#   Real Probability Set      : ['0.99451']
# Sample 2:
#   Predictive Probability Set: ['0.98685']
#   Real Probability Set      : ['0.93002']
# Sample 3:
#   Predictive Probability Set: ['0.99978']
#   Real Probability Set      : ['0.99935']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.57499']
#   Real Probability Set      : ['0.03060']
# Sample 2:
#   Predictive Probability Set: ['0.75586']
#   Real Probability Set      : ['0.16050']
# Sample 3:
#   Predictive Probability Set: ['0.93847']
#   Real Probability Set      : ['0.19962']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.81267', '0.09961']
#   Real Probability Set      : ['0.33883', '0.36327']
# Sample 2:
#   Predictive Probability Set: ['0.72190', '0.20411']
#   Real Probability Set      : ['0.20240', '0.51789']
# Sample 3:
#   Predictive Probability Set: ['0.77838', '0.16002']
#   Real Probability Set      : ['0.15802', '0.32090']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.61087', '0.37510']
#   Real Probability Set      : ['0.08064', '0.89917']
# Sample 2:
#   Predictive Probability Set: ['0.64836', '0.28035']
#   Real Probability Set      : ['0.11360', '0.84828']
# Sample 3:
#   Predictive Probability Set: ['0.60625', '0.34718']
#   Real Probability Set      : ['0.05209', '0.93825']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.54413']
#   Real Probability Set      : ['0.19051']
# Sample 2:
#   Predictive Probability Set: ['0.57223']
#   Real Probability Set      : ['0.19470']
# Sample 3:
#   Predictive Probability Set: ['0.56409']
#   Real Probability Set      : ['0.19742']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.8, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9012 ± 0.0035
# Final Average Prediction Set Size: 0.94 ± 0.01
# Final Average Coverage: 0.8985 ± 0.0056
# Final Average Real Probability: 0.8398 ± 0.0050
# 26422 (52.84%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.8, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9012 ± 0.0035
# Final Average Prediction Set Size: 0.94 ± 0.01
# Final Average Coverage: 0.8985 ± 0.0056
# Final Average Real Probability: 0.8398 ± 0.0050
# Peak Conditional Coverage = 0.996, with 25983 samples
#
# === Count Regions Summary ===
# 38890 (77.8%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 78 (0.2%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 7025 (14.1%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99810']
#   Real Probability Set      : ['0.99991']
# Sample 2:
#   Predictive Probability Set: ['0.99603']
#   Real Probability Set      : ['0.99478']
# Sample 3:
#   Predictive Probability Set: ['0.97994']
#   Real Probability Set      : ['0.90429']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.75861']
#   Real Probability Set      : ['0.04236']
# Sample 2:
#   Predictive Probability Set: ['0.74034']
#   Real Probability Set      : ['0.08858']
# Sample 3:
#   Predictive Probability Set: ['0.90438']
#   Real Probability Set      : ['0.15169']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.72190', '0.20411']
#   Real Probability Set      : ['0.20240', '0.51789']
# Sample 2:
#   Predictive Probability Set: ['0.81267', '0.09961']
#   Real Probability Set      : ['0.33883', '0.36327']
# Sample 3:
#   Predictive Probability Set: ['0.84775', '0.08993']
#   Real Probability Set      : ['0.42022', '0.26344']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.81540', '0.18359']
#   Real Probability Set      : ['0.15103', '0.84878']
# Sample 2:
#   Predictive Probability Set: ['0.60625', '0.34718']
#   Real Probability Set      : ['0.05209', '0.93825']
# Sample 3:
#   Predictive Probability Set: ['0.72573', '0.27427']
#   Real Probability Set      : ['0.10707', '0.89293']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.46661']
#   Real Probability Set      : ['0.16632']
# Sample 2:
#   Predictive Probability Set: ['0.48631']
#   Real Probability Set      : ['0.11083']
# Sample 3:
#   Predictive Probability Set: ['0.55045']
#   Real Probability Set      : ['0.17219']
