# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_hist, raps_synthetic_data_scatter, saps_synthetic_data_scatter, saps_synthetic_data_hist
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=3)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_3class_NoTemp_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_3class_NoTemp_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9487 ± 0.0020
# Final Average Prediction Set Size: 1.18 ± 0.01
# Final Average Coverage: 0.9489 ± 0.0035
# Final Average Real Probability: 0.9488 ± 0.0038
# 34695 (69.39%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.01, k_reg=2, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9489 ± 0.0021
# Final Average Prediction Set Size: 1.18 ± 0.01
# Final Average Coverage: 0.9489 ± 0.0034
# Final Average Real Probability: 0.9486 ± 0.0038
# 34586 (69.17%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.3, num_runs=10, alpha=0.05)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9550 ± 0.0028
# Final Average Prediction Set Size: 1.15 ± 0.01
# Final Average Coverage: 0.9490 ± 0.0052
# Final Average Real Probability: 0.9493 ± 0.0048
# 33384 (66.77%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9449 ± 0.0021
# Final Average Prediction Set Size: 1.06 ± 0.01
# Final Average Coverage: 0.9496 ± 0.0040
# Final Average Real Probability: 0.9071 ± 0.0040
# 30276 (60.55%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9449 ± 0.0021
# Final Average Prediction Set Size: 1.06 ± 0.01
# Final Average Coverage: 0.9496 ± 0.0040
# Final Average Real Probability: 0.9071 ± 0.0040
# Peak Conditional Coverage = 0.996, with 29785 samples
#
# === Count Regions Summary ===
# 42841 (85.7%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 530 (1.1%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 4408 (8.8%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99651']
#   Real Probability Set      : ['0.95976']
# Sample 2:
#   Predictive Probability Set: ['0.99909']
#   Real Probability Set      : ['0.99996']
# Sample 3:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99990']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.90418']
#   Real Probability Set      : ['0.18689']
# Sample 2:
#   Predictive Probability Set: ['0.82414']
#   Real Probability Set      : ['0.06180']
# Sample 3:
#   Predictive Probability Set: ['0.93665']
#   Real Probability Set      : ['0.18986']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.84785', '0.09195']
#   Real Probability Set      : ['0.10608', '0.30384']
# Sample 2:
#   Predictive Probability Set: ['0.84759', '0.10274']
#   Real Probability Set      : ['0.33898', '0.40954']
# Sample 3:
#   Predictive Probability Set: ['0.79903', '0.11170']
#   Real Probability Set      : ['0.39511', '0.39288']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.82414', '0.17586']
#   Real Probability Set      : ['0.06180', '0.93820']
# Sample 2:
#   Predictive Probability Set: ['0.90200', '0.09582']
#   Real Probability Set      : ['0.33347', '0.65184']
# Sample 3:
#   Predictive Probability Set: ['0.72912', '0.26668']
#   Real Probability Set      : ['0.20396', '0.79576']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.54083']
#   Real Probability Set      : ['0.18501']
# Sample 2:
#   Predictive Probability Set: ['0.57223']
#   Real Probability Set      : ['0.19470']
# Sample 3:
#   Predictive Probability Set: ['0.50111']
#   Real Probability Set      : ['0.18633']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=2, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9456 ± 0.0021
# Final Average Prediction Set Size: 1.06 ± 0.01
# Final Average Coverage: 0.9497 ± 0.0040
# Final Average Real Probability: 0.9072 ± 0.0036
# 30153 (60.31%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.1, k_reg=2, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9456 ± 0.0021
# Final Average Prediction Set Size: 1.06 ± 0.01
# Final Average Coverage: 0.9497 ± 0.0040
# Final Average Real Probability: 0.9072 ± 0.0036
# Peak Conditional Coverage = 0.996, with 29661 samples
#
# === Count Regions Summary ===
# 42894 (85.8%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 538 (1.1%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 4451 (8.9%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.91337', '0.08633']
#   Real Probability Set      : ['0.90076', '0.09921']
# Sample 2:
#   Predictive Probability Set: ['0.99996']
#   Real Probability Set      : ['0.99970']
# Sample 3:
#   Predictive Probability Set: ['0.99990']
#   Real Probability Set      : ['1.00000']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.70125']
#   Real Probability Set      : ['0.16618']
# Sample 2:
#   Predictive Probability Set: ['0.57499']
#   Real Probability Set      : ['0.03060']
# Sample 3:
#   Predictive Probability Set: ['0.85762']
#   Real Probability Set      : ['0.18980']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.81267', '0.09961']
#   Real Probability Set      : ['0.33883', '0.36327']
# Sample 2:
#   Predictive Probability Set: ['0.72190', '0.20411']
#   Real Probability Set      : ['0.20240', '0.51789']
# Sample 3:
#   Predictive Probability Set: ['0.72190', '0.20411']
#   Real Probability Set      : ['0.20240', '0.51789']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.89262', '0.10684']
#   Real Probability Set      : ['0.18655', '0.81345']
# Sample 2:
#   Predictive Probability Set: ['0.65504', '0.23997']
#   Real Probability Set      : ['0.14900', '0.76913']
# Sample 3:
#   Predictive Probability Set: ['0.79583', '0.20280']
#   Real Probability Set      : ['0.21323', '0.78675']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.56409']
#   Real Probability Set      : ['0.19742']
# Sample 2:
#   Predictive Probability Set: ['0.50111']
#   Real Probability Set      : ['0.18633']
# Sample 3:
#   Predictive Probability Set: ['0.55045']
#   Real Probability Set      : ['0.17219']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.7, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9564 ± 0.0037
# Final Average Prediction Set Size: 1.00 ± 0.00
# Final Average Coverage: 0.9493 ± 0.0050
# Final Average Real Probability: 0.8917 ± 0.0033
# 28488 (56.98%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.7, num_runs=10, alpha=0.05)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9564 ± 0.0037
# Final Average Prediction Set Size: 1.00 ± 0.00
# Final Average Coverage: 0.9493 ± 0.0050
# Final Average Real Probability: 0.8917 ± 0.0033
# Peak Conditional Coverage = 0.996, with 28027 samples
#
# === Count Regions Summary ===
# 41568 (83.1%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 149 (0.3%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 6696 (13.4%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99713']
#   Real Probability Set      : ['0.99750']
# Sample 2:
#   Predictive Probability Set: ['0.99298']
#   Real Probability Set      : ['0.99336']
# Sample 3:
#   Predictive Probability Set: ['0.99965']
#   Real Probability Set      : ['0.99908']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.94369']
#   Real Probability Set      : ['0.18640']
# Sample 2:
#   Predictive Probability Set: ['0.64009']
#   Real Probability Set      : ['0.16261']
# Sample 3:
#   Predictive Probability Set: ['0.90019']
#   Real Probability Set      : ['0.13615']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.92264', '0.06029']
#   Real Probability Set      : ['0.40127', '0.22482']
# Sample 2:
#   Predictive Probability Set: ['0.81267', '0.09961']
#   Real Probability Set      : ['0.33883', '0.36327']
# Sample 3:
#   Predictive Probability Set: ['0.72190', '0.20411']
#   Real Probability Set      : ['0.20240', '0.51789']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.91368', '0.06292']
#   Real Probability Set      : ['0.37101', '0.61650']
# Sample 2:
#   Predictive Probability Set: ['0.89467', '0.09746']
#   Real Probability Set      : ['0.34664', '0.65155']
# Sample 3:
#   Predictive Probability Set: ['0.79583', '0.20280']
#   Real Probability Set      : ['0.21323', '0.78675']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.50479']
#   Real Probability Set      : ['0.13653']
# Sample 2:
#   Predictive Probability Set: ['0.50111']
#   Real Probability Set      : ['0.18633']
# Sample 3:
#   Predictive Probability Set: ['0.54083']
#   Real Probability Set      : ['0.18501']
