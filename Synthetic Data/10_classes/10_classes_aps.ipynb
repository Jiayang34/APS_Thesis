# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=10)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_10class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_10class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

aps_synthetic_data(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average Prediction Set Size: 1.68 ± 0.03
# Final Average Coverage: 0.9477 ± 0.0049
# Final Average Real Probability: 0.9020 ± 0.0059
#  22591( 45.18%) Samples Reached the Peak of Real Probability at 0.9900

# %%
aps_synthetic_data(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average Prediction Set Size: 1.34 ± 0.02
# Final Average Coverage: 0.8976 ± 0.0056
# Final Average Real Probability: 0.8346 ± 0.0056
#  17791( 35.58%) Samples Reached the Peak of Real Probability at 0.9900

# %%
aps_synthetic_data(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average Prediction Set Size: 1.02 ± 0.01
# Final Average Coverage: 0.7936 ± 0.0065
# Final Average Real Probability: 0.7175 ± 0.0059
#  13645( 27.29%) Samples Reached the Peak of Real Probability at 0.9900
