# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=10)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_10class_NoTemp_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_10class_NoTemp_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9003 ± 0.0048
# Final Average Prediction Set Size: 1.31 ± 0.02
# Final Average Coverage: 0.8972 ± 0.0081
# Final Average Real Probability: 0.8986 ± 0.0063
# 18812 (37.62%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.03, k_reg=1, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9166 ± 0.0048
# Final Average Prediction Set Size: 1.26 ± 0.01
# Final Average Coverage: 0.8987 ± 0.0079
# Final Average Real Probability: 0.9005 ± 0.0061
# 18469 (36.94%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.5, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9474 ± 0.0036
# Final Average Prediction Set Size: 1.19 ± 0.01
# Final Average Coverage: 0.9009 ± 0.0044
# Final Average Real Probability: 0.9024 ± 0.0028
# 18724 (37.45%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9049 ± 0.0032
# Final Average Prediction Set Size: 1.18 ± 0.02
# Final Average Coverage: 0.8957 ± 0.0061
# Final Average Real Probability: 0.7882 ± 0.0051
# 16694 (33.39%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9049 ± 0.0032
# Final Average Prediction Set Size: 1.18 ± 0.02
# Final Average Coverage: 0.8957 ± 0.0061
# Final Average Real Probability: 0.7882 ± 0.0051
# Peak Conditional Coverage = 0.999, with 14373 samples
#
# === Count Regions Summary ===
# 33966 (67.9%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 769 (1.5%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 11303 (22.6%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99929']
#   Real Probability Set      : ['0.99592']
# Sample 2:
#   Predictive Probability Set: ['0.99967']
#   Real Probability Set      : ['0.97688']
# Sample 3:
#   Predictive Probability Set: ['0.99994']
#   Real Probability Set      : ['0.95474']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.96499']
#   Real Probability Set      : ['0.11616']
# Sample 2:
#   Predictive Probability Set: ['0.86893', '0.03779']
#   Real Probability Set      : ['0.13201', '0.03522']
# Sample 3:
#   Predictive Probability Set: ['0.95730']
#   Real Probability Set      : ['0.19715']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.40342', '0.10637', '0.09565', '0.08320', '0.07288', '0.07031', '0.04814']
#   Real Probability Set      : ['0.09217', '0.19599', '0.00010', '0.00000', '0.13033', '0.26146', '0.09542']
# Sample 2:
#   Predictive Probability Set: ['0.55040', '0.09106', '0.06517', '0.06396', '0.05496', '0.04162', '0.03687']
#   Real Probability Set      : ['0.10401', '0.48440', '0.01467', '0.08820', '0.07352', '0.02943', '0.00315']
# Sample 3:
#   Predictive Probability Set: ['0.75051', '0.10764', '0.03352']
#   Real Probability Set      : ['0.26001', '0.11989', '0.30434']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.80941', '0.15350']
#   Real Probability Set      : ['0.02267', '0.96187']
# Sample 2:
#   Predictive Probability Set: ['0.82701', '0.17189']
#   Real Probability Set      : ['0.18409', '0.81519']
# Sample 3:
#   Predictive Probability Set: ['0.50690', '0.25561', '0.13877']
#   Real Probability Set      : ['0.01764', '0.08888', '0.86974']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.52667']
#   Real Probability Set      : ['0.15931']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.03, k_reg=1, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9091 ± 0.0032
# Final Average Prediction Set Size: 1.08 ± 0.01
# Final Average Coverage: 0.8951 ± 0.0067
# Final Average Real Probability: 0.7823 ± 0.0052
# 16209 (32.42%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.03, k_reg=1, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9091 ± 0.0032
# Final Average Prediction Set Size: 1.08 ± 0.01
# Final Average Coverage: 0.8951 ± 0.0067
# Final Average Real Probability: 0.7823 ± 0.0052
# Peak Conditional Coverage = 0.999, with 13948 samples
#
# === Count Regions Summary ===
# 33633 (67.3%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 463 (0.9%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 12146 (24.3%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99983']
# Sample 2:
#   Predictive Probability Set: ['0.99994']
#   Real Probability Set      : ['0.82116']
# Sample 3:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99890']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.88835']
#   Real Probability Set      : ['0.16956']
# Sample 2:
#   Predictive Probability Set: ['0.95802']
#   Real Probability Set      : ['0.10479']
# Sample 3:
#   Predictive Probability Set: ['0.85057']
#   Real Probability Set      : ['0.09487']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.68395', '0.13993']
#   Real Probability Set      : ['0.21827', '0.36150']
# Sample 2:
#   Predictive Probability Set: ['0.76264', '0.08699']
#   Real Probability Set      : ['0.22069', '0.29176']
# Sample 3:
#   Predictive Probability Set: ['0.38656', '0.14436', '0.10119', '0.09994']
#   Real Probability Set      : ['0.20651', '0.00040', '0.00168', '0.28118']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.25605', '0.15758', '0.15645', '0.12797', '0.08649']
#   Real Probability Set      : ['0.00649', '0.00000', '0.00096', '0.86604', '0.12038']
# Sample 2:
#   Predictive Probability Set: ['0.63622', '0.27662']
#   Real Probability Set      : ['0.12040', '0.86822']
# Sample 3:
#   Predictive Probability Set: ['0.40092', '0.34958', '0.21835']
#   Real Probability Set      : ['0.93698', '0.05818', '0.00400']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.53066']
#   Real Probability Set      : ['0.14741']
# Sample 2:
#   Predictive Probability Set: ['0.52667']
#   Real Probability Set      : ['0.15931']
# Sample 3:
#   Predictive Probability Set: ['0.53066']
#   Real Probability Set      : ['0.14741']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.3, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9143 ± 0.0041
# Final Average Prediction Set Size: 1.04 ± 0.01
# Final Average Coverage: 0.8985 ± 0.0053
# Final Average Real Probability: 0.7822 ± 0.0033
# 16409 (32.82%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.3, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9143 ± 0.0041
# Final Average Prediction Set Size: 1.04 ± 0.01
# Final Average Coverage: 0.8985 ± 0.0053
# Final Average Real Probability: 0.7822 ± 0.0033
# Peak Conditional Coverage = 0.999, with 14143 samples
#
# === Count Regions Summary ===
# 33599 (67.2%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 294 (0.6%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 12661 (25.3%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99961']
#   Real Probability Set      : ['0.97754']
# Sample 2:
#   Predictive Probability Set: ['0.99995']
#   Real Probability Set      : ['0.93904']
# Sample 3:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99965']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.95844']
#   Real Probability Set      : ['0.19107']
# Sample 2:
#   Predictive Probability Set: ['0.87241']
#   Real Probability Set      : ['0.18429']
# Sample 3:
#   Predictive Probability Set: ['0.71146']
#   Real Probability Set      : ['0.17498']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.76264', '0.08699']
#   Real Probability Set      : ['0.22069', '0.29176']
# Sample 2:
#   Predictive Probability Set: ['0.91026', '0.05975']
#   Real Probability Set      : ['0.30991', '0.42575']
# Sample 3:
#   Predictive Probability Set: ['0.73050', '0.15768']
#   Real Probability Set      : ['0.30560', '0.41739']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.56042', '0.19539', '0.17963']
#   Real Probability Set      : ['0.21786', '0.00265', '0.70301']
# Sample 2:
#   Predictive Probability Set: ['0.58446', '0.41524']
#   Real Probability Set      : ['0.04835', '0.95139']
# Sample 3:
#   Predictive Probability Set: ['0.64861', '0.32205']
#   Real Probability Set      : ['0.04656', '0.75929']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.18872', '0.13942', '0.11792']
#   Real Probability Set      : ['0.02928', '0.01554', '0.06246']
# Sample 2:
#   Predictive Probability Set: ['0.31311', '0.13592']
#   Real Probability Set      : ['0.05960', '0.05502']
# Sample 3:
#   Predictive Probability Set: ['0.18872', '0.13942', '0.11792']
#   Real Probability Set      : ['0.02928', '0.01554', '0.06246']
