# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, raps_synthetic_data
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=10)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_10class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_10class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
raps_synthetic_data(model,dataset,device, lambda_= 0.1, k_reg=8, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9444 ± 0.0026
# Final Average Prediction Set Size: 4.39 ± 0.07
# Final Average Coverage: 0.9454 ± 0.0057
# Final Average Real Probability: 0.8289 ± 0.0046
# 2290 (4.58%) samples reached the real probability at 1-alpha = 0.9500

# %%
raps_synthetic_data(model,dataset,device, lambda_=0.5, k_reg=6, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8978 ± 0.0055
# Final Average Prediction Set Size: 3.33 ± 0.07
# Final Average Coverage: 0.9005 ± 0.0087
# Final Average Real Probability: 0.7510 ± 0.0074
# 1592 (3.18%) samples reached the real probability at 1-alpha = 0.9000

# %%
raps_synthetic_data(model,dataset,device, lambda_=0.5, k_reg=3, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8497 ± 0.0121
# Final Average Prediction Set Size: 2.12 ± 0.05
# Final Average Coverage: 0.8133 ± 0.0116
# Final Average Real Probability: 0.6352 ± 0.0091
# 896 (1.79%) samples reached the real probability at 1-alpha = 0.8000
