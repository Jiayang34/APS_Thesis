# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=10)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_10class_NoTemp_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_10class_NoTemp_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9502 ± 0.0029
# Final Average Prediction Set Size: 1.53 ± 0.02
# Final Average Coverage: 0.9490 ± 0.0061
# Final Average Real Probability: 0.9498 ± 0.0048
# 22823 (45.65%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_= 0.01, k_reg=1, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9580 ± 0.0026
# Final Average Prediction Set Size: 1.49 ± 0.01
# Final Average Coverage: 0.9492 ± 0.0062
# Final Average Real Probability: 0.9504 ± 0.0044
# 22332 (44.66%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.3, num_runs=10, alpha=0.05)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9811 ± 0.0047
# Final Average Prediction Set Size: 1.41 ± 0.01
# Final Average Coverage: 0.9498 ± 0.0043
# Final Average Real Probability: 0.9516 ± 0.0027
# 22588 (45.18%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9588 ± 0.0024
# Final Average Prediction Set Size: 1.43 ± 0.02
# Final Average Coverage: 0.9479 ± 0.0046
# Final Average Real Probability: 0.8513 ± 0.0045
# 19132 (38.26%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9588 ± 0.0024
# Final Average Prediction Set Size: 1.43 ± 0.02
# Final Average Coverage: 0.9479 ± 0.0046
# Final Average Real Probability: 0.8513 ± 0.0045
# Peak Conditional Coverage = 0.999, with 16439 samples
#
# === Count Regions Summary ===
# 36974 (73.9%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 1527 (3.1%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 9773 (19.5%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99998']
#   Real Probability Set      : ['0.95431']
# Sample 2:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99786']
# Sample 3:
#   Predictive Probability Set: ['0.99454']
#   Real Probability Set      : ['0.92591']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.96524']
#   Real Probability Set      : ['0.03656']
# Sample 2:
#   Predictive Probability Set: ['0.89646', '0.03709', '0.02450']
#   Real Probability Set      : ['0.08038', '0.00053', '0.08462']
# Sample 3:
#   Predictive Probability Set: ['0.99709']
#   Real Probability Set      : ['0.14727']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.94077', '0.05832']
#   Real Probability Set      : ['0.31685', '0.32419']
# Sample 2:
#   Predictive Probability Set: ['0.89500', '0.03772', '0.02319', '0.01842']
#   Real Probability Set      : ['0.42508', '0.14963', '0.00028', '0.00546']
# Sample 3:
#   Predictive Probability Set: ['0.85612', '0.04390', '0.03297', '0.01625']
#   Real Probability Set      : ['0.36931', '0.00473', '0.27723', '0.00144']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.89455', '0.08478']
#   Real Probability Set      : ['0.21675', '0.63442']
# Sample 2:
#   Predictive Probability Set: ['0.72678', '0.09873', '0.04283', '0.03220', '0.03179', '0.02685', '0.01175']
#   Real Probability Set      : ['0.13145', '0.03646', '0.00035', '0.08283', '0.00512', '0.00012', '0.73207']
# Sample 3:
#   Predictive Probability Set: ['0.72003', '0.27330']
#   Real Probability Set      : ['0.06860', '0.90624']
#
# --- Region 5: low TVD, low Coverage ---
# No points are found in this region.

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_= 0.03, k_reg=2, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9611 ± 0.0024
# Final Average Prediction Set Size: 1.27 ± 0.01
# Final Average Coverage: 0.9478 ± 0.0046
# Final Average Real Probability: 0.8457 ± 0.0042
# 18158 (36.32%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_= 0.03, k_reg=2, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9611 ± 0.0024
# Final Average Prediction Set Size: 1.27 ± 0.01
# Final Average Coverage: 0.9478 ± 0.0046
# Final Average Real Probability: 0.8457 ± 0.0042
# Peak Conditional Coverage = 0.999, with 15502 samples
#
# === Count Regions Summary ===
# 36721 (73.4%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 1158 (2.3%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 10508 (21.0%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99903']
#   Real Probability Set      : ['0.94025']
# Sample 2:
#   Predictive Probability Set: ['0.99982']
#   Real Probability Set      : ['0.98305']
# Sample 3:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99926']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99912']
#   Real Probability Set      : ['0.06111']
# Sample 2:
#   Predictive Probability Set: ['0.96912']
#   Real Probability Set      : ['0.19417']
# Sample 3:
#   Predictive Probability Set: ['0.99247']
#   Real Probability Set      : ['0.15053']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.93336', '0.05464']
#   Real Probability Set      : ['0.32079', '0.17380']
# Sample 2:
#   Predictive Probability Set: ['0.68490', '0.26698']
#   Real Probability Set      : ['0.11139', '0.60573']
# Sample 3:
#   Predictive Probability Set: ['0.91001', '0.02572']
#   Real Probability Set      : ['0.47662', '0.27542']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.88999', '0.08285']
#   Real Probability Set      : ['0.27754', '0.64184']
# Sample 2:
#   Predictive Probability Set: ['0.36735', '0.24239', '0.07430', '0.06379', '0.06141', '0.06111']
#   Real Probability Set      : ['0.03663', '0.60724', '0.00458', '0.00000', '0.00000', '0.29293']
# Sample 3:
#   Predictive Probability Set: ['0.95953', '0.01257']
#   Real Probability Set      : ['0.26036', '0.70706']
#
# --- Region 5: low TVD, low Coverage ---
# No points are found in this region.

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.25, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9686 ± 0.0023
# Final Average Prediction Set Size: 1.14 ± 0.01
# Final Average Coverage: 0.9483 ± 0.0034
# Final Average Real Probability: 0.8339 ± 0.0021
# 17796 (35.59%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.25, num_runs=10, alpha=0.05)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9686 ± 0.0023
# Final Average Prediction Set Size: 1.14 ± 0.01
# Final Average Coverage: 0.9483 ± 0.0034
# Final Average Real Probability: 0.8339 ± 0.0021
# Peak Conditional Coverage = 0.999, with 15298 samples
#
# === Count Regions Summary ===
# 36035 (72.1%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 619 (1.2%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 12123 (24.2%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.91250']
#   Real Probability Set      : ['0.80709']
# Sample 2:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99996']
# Sample 3:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.97432']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.98094']
#   Real Probability Set      : ['0.01205']
# Sample 2:
#   Predictive Probability Set: ['0.99950']
#   Real Probability Set      : ['0.11120']
# Sample 3:
#   Predictive Probability Set: ['0.84009']
#   Real Probability Set      : ['0.11764']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.76943', '0.20511']
#   Real Probability Set      : ['0.15493', '0.56343']
# Sample 2:
#   Predictive Probability Set: ['0.76264', '0.08699']
#   Real Probability Set      : ['0.22069', '0.29176']
# Sample 3:
#   Predictive Probability Set: ['0.68395', '0.13993', '0.06199']
#   Real Probability Set      : ['0.21827', '0.36150', '0.00543']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.66072', '0.09100', '0.08763']
#   Real Probability Set      : ['0.08127', '0.27801', '0.56643']
# Sample 2:
#   Predictive Probability Set: ['0.73818', '0.26084']
#   Real Probability Set      : ['0.06594', '0.91682']
# Sample 3:
#   Predictive Probability Set: ['0.61577', '0.37662']
#   Real Probability Set      : ['0.06822', '0.93042']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.17151', '0.13001', '0.12874', '0.11116']
#   Real Probability Set      : ['0.00119', '0.03392', '0.00029', '0.10621']
# Sample 2:
#   Predictive Probability Set: ['0.17151', '0.13001', '0.12874', '0.11116']
#   Real Probability Set      : ['0.00119', '0.03392', '0.00029', '0.10621']
# Sample 3:
#   Predictive Probability Set: ['0.17151', '0.13001', '0.12874', '0.11116']
#   Real Probability Set      : ['0.00119', '0.03392', '0.00029', '0.10621']
