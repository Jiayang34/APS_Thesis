# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, raps_synthetic_data_scatter, aps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=10)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_10class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_10class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7991 ± 0.0060
# Final Average Prediction Set Size: 2.63 ± 0.06
# Final Average Coverage: 0.8010 ± 0.0137
# Final Average Real Probability: 0.7995 ± 0.0069
# 4061 (8.12%) samples reached the peak conditional coverage at 0.8134

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.5, k_reg=4, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8049 ± 0.0064
# Final Average Prediction Set Size: 2.60 ± 0.05
# Final Average Coverage: 0.8009 ± 0.0132
# Final Average Real Probability: 0.7984 ± 0.0065
# 3883 (7.77%) samples reached the peak conditional coverage at 0.8134

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.18, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7979 ± 0.0088
# Final Average Prediction Set Size: 2.55 ± 0.05
# Final Average Coverage: 0.7994 ± 0.0124
# Final Average Real Probability: 0.7975 ± 0.0067
# 2332 (4.66%) samples reached the peak conditional coverage at 0.7935

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7645 ± 0.0062
# Final Average Prediction Set Size: 2.24 ± 0.05
# Final Average Coverage: 0.7990 ± 0.0104
# Final Average Real Probability: 0.6174 ± 0.0063
# 1068 (2.14%) samples reached the peak conditional coverage at 0.7835

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7645 ± 0.0062
# Final Average Prediction Set Size: 2.24 ± 0.05
# Final Average Coverage: 0.7990 ± 0.0104
# Final Average Real Probability: 0.6174 ± 0.0063
# Peak Conditional Coverage = 0.783, with 1076 samples
#
# === Count Regions Summary ===
# 12350 (24.7%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 92 (0.2%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 34607 (69.2%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.92472']
#   Real Probability Set      : ['0.82412']
# Sample 2:
#   Predictive Probability Set: ['0.99709']
#   Real Probability Set      : ['0.80689']
# Sample 3:
#   Predictive Probability Set: ['0.99989']
#   Real Probability Set      : ['0.95515']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.70033']
#   Real Probability Set      : ['0.17075']
# Sample 2:
#   Predictive Probability Set: ['0.68014']
#   Real Probability Set      : ['0.16998']
# Sample 3:
#   Predictive Probability Set: ['0.76720']
#   Real Probability Set      : ['0.09922']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.43196', '0.19099', '0.12176', '0.09943']
#   Real Probability Set      : ['0.19504', '0.02313', '0.24844', '0.02887']
# Sample 2:
#   Predictive Probability Set: ['0.22295', '0.18246', '0.13298', '0.10694', '0.08951']
#   Real Probability Set      : ['0.08312', '0.47757', '0.16977', '0.02060', '0.03875']
# Sample 3:
#   Predictive Probability Set: ['0.41722', '0.32175']
#   Real Probability Set      : ['0.10102', '0.68486']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.50240', '0.19153', '0.13157']
#   Real Probability Set      : ['0.11416', '0.04999', '0.71540']
# Sample 2:
#   Predictive Probability Set: ['0.45372', '0.16836', '0.07914', '0.07687']
#   Real Probability Set      : ['0.07770', '0.03969', '0.41726', '0.34477']
# Sample 3:
#   Predictive Probability Set: ['0.54736', '0.20833']
#   Real Probability Set      : ['0.07605', '0.76206']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.45618']
#   Real Probability Set      : ['0.07174']
# Sample 2:
#   Predictive Probability Set: ['0.47510']
#   Real Probability Set      : ['0.15515']
# Sample 3:
#   Predictive Probability Set: ['0.48297']
#   Real Probability Set      : ['0.16848']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.01, k_reg=4, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7658 ± 0.0062
# Final Average Prediction Set Size: 2.22 ± 0.05
# Final Average Coverage: 0.7991 ± 0.0104
# Final Average Real Probability: 0.6165 ± 0.0059
# 1062 (2.12%) samples reached the peak conditional coverage at 0.7835

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.01, k_reg=4, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7658 ± 0.0062
# Final Average Prediction Set Size: 2.22 ± 0.05
# Final Average Coverage: 0.7991 ± 0.0104
# Final Average Real Probability: 0.6165 ± 0.0059
# Peak Conditional Coverage = 0.783, with 1069 samples
#
# === Count Regions Summary ===
# 12098 (24.2%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 84 (0.2%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 34893 (69.8%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99312']
#   Real Probability Set      : ['0.90117']
# Sample 2:
#   Predictive Probability Set: ['0.96580']
#   Real Probability Set      : ['0.84196']
# Sample 3:
#   Predictive Probability Set: ['0.98668']
#   Real Probability Set      : ['0.93654']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.75490']
#   Real Probability Set      : ['0.14801']
# Sample 2:
#   Predictive Probability Set: ['0.71268']
#   Real Probability Set      : ['0.12555']
# Sample 3:
#   Predictive Probability Set: ['0.66955']
#   Real Probability Set      : ['0.14851']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.31888', '0.23364', '0.21504']
#   Real Probability Set      : ['0.09118', '0.46612', '0.04978']
# Sample 2:
#   Predictive Probability Set: ['0.63917', '0.15322']
#   Real Probability Set      : ['0.13903', '0.29681']
# Sample 3:
#   Predictive Probability Set: ['0.38512', '0.17504', '0.11992', '0.10932']
#   Real Probability Set      : ['0.16595', '0.58221', '0.03973', '0.00726']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.21304', '0.20177', '0.17863', '0.10028']
#   Real Probability Set      : ['0.05906', '0.00969', '0.81162', '0.00423']
# Sample 2:
#   Predictive Probability Set: ['0.21304', '0.20177', '0.17863', '0.10028', '0.09252']
#   Real Probability Set      : ['0.05906', '0.00969', '0.81162', '0.00423', '0.01899']
# Sample 3:
#   Predictive Probability Set: ['0.45372', '0.16836', '0.07914', '0.07687']
#   Real Probability Set      : ['0.07770', '0.03969', '0.41726', '0.34477']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.50369']
#   Real Probability Set      : ['0.17153']
# Sample 2:
#   Predictive Probability Set: ['0.53056']
#   Real Probability Set      : ['0.17595']
# Sample 3:
#   Predictive Probability Set: ['0.52256']
#   Real Probability Set      : ['0.14866']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.2, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7978 ± 0.0094
# Final Average Prediction Set Size: 2.02 ± 0.04
# Final Average Coverage: 0.8001 ± 0.0121
# Final Average Real Probability: 0.6131 ± 0.0061
# 1089 (2.18%) samples reached the peak conditional coverage at 0.7136

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.2, num_runs=10, alpha=0.2)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7978 ± 0.0094
# Final Average Prediction Set Size: 2.02 ± 0.04
# Final Average Coverage: 0.8001 ± 0.0121
# Final Average Real Probability: 0.6131 ± 0.0061
# Peak Conditional Coverage = 0.713, with 1070 samples
#
# === Count Regions Summary ===
# 11118 (22.2%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 76 (0.2%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 36524 (73.0%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.96899']
#   Real Probability Set      : ['0.84814']
# Sample 2:
#   Predictive Probability Set: ['0.99580']
#   Real Probability Set      : ['0.90722']
# Sample 3:
#   Predictive Probability Set: ['0.94720']
#   Real Probability Set      : ['0.88100']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.72546']
#   Real Probability Set      : ['0.17433']
# Sample 2:
#   Predictive Probability Set: ['0.48034', '0.11454']
#   Real Probability Set      : ['0.14817', '0.04499']
# Sample 3:
#   Predictive Probability Set: ['0.67475']
#   Real Probability Set      : ['0.16742']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.39780', '0.14873', '0.14354']
#   Real Probability Set      : ['0.08148', '0.04196', '0.38660']
# Sample 2:
#   Predictive Probability Set: ['0.74499', '0.08933']
#   Real Probability Set      : ['0.20378', '0.30601']
# Sample 3:
#   Predictive Probability Set: ['0.36795', '0.30021', '0.14965']
#   Real Probability Set      : ['0.66360', '0.07898', '0.02559']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.45835', '0.28619', '0.12112']
#   Real Probability Set      : ['0.11359', '0.13297', '0.65795']
# Sample 2:
#   Predictive Probability Set: ['0.35952', '0.22697', '0.14566']
#   Real Probability Set      : ['0.12686', '0.01025', '0.75618']
# Sample 3:
#   Predictive Probability Set: ['0.21304', '0.20177', '0.17863', '0.10028']
#   Real Probability Set      : ['0.05906', '0.00969', '0.81162', '0.00423']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.25145', '0.14862', '0.12805']
#   Real Probability Set      : ['0.09520', '0.04575', '0.02644']
# Sample 2:
#   Predictive Probability Set: ['0.43151', '0.11787']
#   Real Probability Set      : ['0.15655', '0.00625']
# Sample 3:
#   Predictive Probability Set: ['0.28274', '0.14934', '0.12679']
#   Real Probability Set      : ['0.06633', '0.04891', '0.06307']
