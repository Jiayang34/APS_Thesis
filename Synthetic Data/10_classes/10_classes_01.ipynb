# %% [markdown]
# ## Ground-Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=10)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_10class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_10class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8971 ± 0.0054
# Final Average Prediction Set Size: 3.75 ± 0.10
# Final Average Coverage: 0.9004 ± 0.0108
# Final Average Real Probability: 0.8973 ± 0.0054
# 7764 (15.53%) samples reached the peak conditional coverage at 0.9032

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=6, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8978 ± 0.0055
# Final Average Prediction Set Size: 3.74 ± 0.09
# Final Average Coverage: 0.9003 ± 0.0107
# Final Average Real Probability: 0.8967 ± 0.0053
# 7701 (15.40%) samples reached the peak conditional coverage at 0.9032

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.15, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9347 ± 0.0131
# Final Average Prediction Set Size: 3.72 ± 0.09
# Final Average Coverage: 0.9003 ± 0.0106
# Final Average Real Probability: 0.8953 ± 0.0052
# 3627 (7.25%) samples reached the peak conditional coverage at 0.9234

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8810 ± 0.0055
# Final Average Prediction Set Size: 3.36 ± 0.08
# Final Average Coverage: 0.8986 ± 0.0096
# Final Average Real Probability: 0.7448 ± 0.0076
# 1730 (3.46%) samples reached the peak conditional coverage at 0.8833

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8810 ± 0.0055
# Final Average Prediction Set Size: 3.36 ± 0.08
# Final Average Coverage: 0.8986 ± 0.0096
# Final Average Real Probability: 0.7448 ± 0.0076
# Peak Conditional Coverage = 0.937, with 13 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.97972']
#   Real Probability Set      : ['0.82915']
# Sample 2:
#   Predictive Probability Set: ['0.99872']
#   Real Probability Set      : ['0.95582']
# Sample 3:
#   Predictive Probability Set: ['0.97467']
#   Real Probability Set      : ['0.85007']
#
# --- Region 2: high tvd, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.88822']
#   Real Probability Set      : ['0.05277']
# Sample 2:
#   Predictive Probability Set: ['0.71090']
#   Real Probability Set      : ['0.14655']
# Sample 3:
#   Predictive Probability Set: ['0.84902']
#   Real Probability Set      : ['0.17981']
#
# --- Region 3: medium tvd, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.79293', '0.07509']
#   Real Probability Set      : ['0.24127', '0.25843']
# Sample 2:
#   Predictive Probability Set: ['0.64379', '0.13440', '0.11040']
#   Real Probability Set      : ['0.15386', '0.57328', '0.05033']
# Sample 3:
#   Predictive Probability Set: ['0.55880', '0.17469', '0.12218']
#   Real Probability Set      : ['0.31412', '0.04686', '0.36030']
#
# --- Region 4: high tvd, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.45372', '0.16836', '0.07914', '0.07687', '0.05898', '0.05488']
#   Real Probability Set      : ['0.07770', '0.03969', '0.41726', '0.34477', '0.00878', '0.00990']
# Sample 2:
#   Predictive Probability Set: ['0.86688', '0.13083']
#   Real Probability Set      : ['0.19197', '0.69883']
# Sample 3:
#   Predictive Probability Set: ['0.83137', '0.15278']
#   Real Probability Set      : ['0.08637', '0.78075']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=5, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8972 ± 0.0062
# Final Average Prediction Set Size: 3.23 ± 0.07
# Final Average Coverage: 0.8996 ± 0.0089
# Final Average Real Probability: 0.7443 ± 0.0069
# 1715 (3.43%) samples reached the peak conditional coverage at 0.8833

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.1, k_reg=5, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8972 ± 0.0062
# Final Average Prediction Set Size: 3.23 ± 0.07
# Final Average Coverage: 0.8996 ± 0.0089
# Final Average Real Probability: 0.7443 ± 0.0069
# Peak Conditional Coverage = 0.937, with 13 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.96895']
#   Real Probability Set      : ['0.97038']
# Sample 2:
#   Predictive Probability Set: ['0.99459']
#   Real Probability Set      : ['0.87950']
# Sample 3:
#   Predictive Probability Set: ['0.94287']
#   Real Probability Set      : ['0.87304']
#
# --- Region 2: high tvd, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.96836']
#   Real Probability Set      : ['0.14583']
# Sample 2:
#   Predictive Probability Set: ['0.91803']
#   Real Probability Set      : ['0.14115']
# Sample 3:
#   Predictive Probability Set: ['0.78823']
#   Real Probability Set      : ['0.17945']
#
# --- Region 3: medium tvd, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.45567', '0.11853', '0.10854', '0.10424', '0.08434']
#   Real Probability Set      : ['0.19248', '0.24093', '0.01619', '0.03955', '0.01825']
# Sample 2:
#   Predictive Probability Set: ['0.53663', '0.19691', '0.15319', '0.04186']
#   Real Probability Set      : ['0.06530', '0.11084', '0.48202', '0.06897']
# Sample 3:
#   Predictive Probability Set: ['0.38266', '0.26128', '0.17004', '0.07038']
#   Real Probability Set      : ['0.13377', '0.47372', '0.04531', '0.01216']
#
# --- Region 4: high tvd, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.74491', '0.21472']
#   Real Probability Set      : ['0.05290', '0.85604']
# Sample 2:
#   Predictive Probability Set: ['0.72112', '0.13272', '0.11827']
#   Real Probability Set      : ['0.09150', '0.05442', '0.65723']
# Sample 3:
#   Predictive Probability Set: ['0.85334', '0.14011']
#   Real Probability Set      : ['0.15424', '0.68465']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.13, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8843 ± 0.0107
# Final Average Prediction Set Size: 3.09 ± 0.07
# Final Average Coverage: 0.8934 ± 0.0090
# Final Average Real Probability: 0.7293 ± 0.0080
# 1515 (3.03%) samples reached the peak conditional coverage at 0.8833

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.13, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8843 ± 0.0107
# Final Average Prediction Set Size: 3.09 ± 0.07
# Final Average Coverage: 0.8934 ± 0.0090
# Final Average Real Probability: 0.7293 ± 0.0080
# Peak Conditional Coverage = 0.937, with 13 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99953']
#   Real Probability Set      : ['0.94205']
# Sample 2:
#   Predictive Probability Set: ['0.33468', '0.27508', '0.19220', '0.05413', '0.04055', '0.02746']
#   Real Probability Set      : ['0.31856', '0.30171', '0.15736', '0.10299', '0.00118', '0.00793']
# Sample 3:
#   Predictive Probability Set: ['0.99956']
#   Real Probability Set      : ['0.89044']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.78837']
#   Real Probability Set      : ['0.07889']
# Sample 2:
#   Predictive Probability Set: ['0.81255']
#   Real Probability Set      : ['0.19205']
# Sample 3:
#   Predictive Probability Set: ['0.96836']
#   Real Probability Set      : ['0.14583']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.27292', '0.12687', '0.10663', '0.10178', '0.09986', '0.07759']
#   Real Probability Set      : ['0.12849', '0.01850', '0.02177', '0.34915', '0.05057', '0.04646']
# Sample 2:
#   Predictive Probability Set: ['0.71268', '0.20524']
#   Real Probability Set      : ['0.12555', '0.39532']
# Sample 3:
#   Predictive Probability Set: ['0.65079', '0.13824', '0.05583']
#   Real Probability Set      : ['0.17127', '0.10268', '0.17732']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.21304', '0.20177', '0.17863', '0.10028', '0.09252', '0.05362']
#   Real Probability Set      : ['0.05906', '0.00969', '0.81162', '0.00423', '0.01899', '0.00055']
# Sample 2:
#   Predictive Probability Set: ['0.81255', '0.10027']
#   Real Probability Set      : ['0.19205', '0.68494']
# Sample 3:
#   Predictive Probability Set: ['0.74491', '0.21472', '0.01647']
#   Real Probability Set      : ['0.05290', '0.85604', '0.00453']
