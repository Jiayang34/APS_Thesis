# %% [markdown]
# ## Ground-Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=10)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_10class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_10class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8971 ± 0.0054
# Final Average Prediction Set Size: 3.75 ± 0.10
# Final Average Coverage: 0.9004 ± 0.0108
# Final Average Real Probability: 0.8973 ± 0.0054
# 7764 (15.53%) samples reached the peak conditional coverage at 0.9032

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=6, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8978 ± 0.0055
# Final Average Prediction Set Size: 3.74 ± 0.09
# Final Average Coverage: 0.9003 ± 0.0107
# Final Average Real Probability: 0.8967 ± 0.0053
# 7701 (15.40%) samples reached the peak conditional coverage at 0.9032

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.15, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9347 ± 0.0131
# Final Average Prediction Set Size: 3.72 ± 0.09
# Final Average Coverage: 0.9003 ± 0.0106
# Final Average Real Probability: 0.8953 ± 0.0052
# 3627 (7.25%) samples reached the peak conditional coverage at 0.9234

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8810 ± 0.0055
# Final Average Prediction Set Size: 3.36 ± 0.08
# Final Average Coverage: 0.8986 ± 0.0096
# Final Average Real Probability: 0.7448 ± 0.0076
# 1730 (3.46%) samples reached the peak conditional coverage at 0.8833

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8810 ± 0.0055
# Final Average Prediction Set Size: 3.36 ± 0.08
# Final Average Coverage: 0.8986 ± 0.0096
# Final Average Real Probability: 0.7448 ± 0.0076
# Peak Conditional Coverage = 0.883, with 1743 samples
#
# === Count Regions Summary ===
# 24409 (48.8%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 460 (0.9%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 24061 (48.1%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.87167']
#   Real Probability Set      : ['0.84174']
# Sample 2:
#   Predictive Probability Set: ['0.29066', '0.26970', '0.14242', '0.13781', '0.08453']
#   Real Probability Set      : ['0.28360', '0.29184', '0.13316', '0.07901', '0.04465']
# Sample 3:
#   Predictive Probability Set: ['0.96095']
#   Real Probability Set      : ['0.80070']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.60217']
#   Real Probability Set      : ['0.08710']
# Sample 2:
#   Predictive Probability Set: ['0.86688']
#   Real Probability Set      : ['0.19197']
# Sample 3:
#   Predictive Probability Set: ['0.88521']
#   Real Probability Set      : ['0.14046']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.58067', '0.17407', '0.09262', '0.03839']
#   Real Probability Set      : ['0.06224', '0.20071', '0.08748', '0.35864']
# Sample 2:
#   Predictive Probability Set: ['0.74297', '0.09833', '0.08632']
#   Real Probability Set      : ['0.34688', '0.32265', '0.09254']
# Sample 3:
#   Predictive Probability Set: ['0.73742', '0.14047']
#   Real Probability Set      : ['0.31966', '0.37023']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.52311', '0.27106', '0.05542', '0.02925']
#   Real Probability Set      : ['0.21714', '0.05219', '0.02645', '0.56912']
# Sample 2:
#   Predictive Probability Set: ['0.75204', '0.12463']
#   Real Probability Set      : ['0.11691', '0.79212']
# Sample 3:
#   Predictive Probability Set: ['0.35952', '0.22697', '0.14566', '0.09478', '0.05815']
#   Real Probability Set      : ['0.12686', '0.01025', '0.75618', '0.03825', '0.01463']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.47510']
#   Real Probability Set      : ['0.15515']
# Sample 2:
#   Predictive Probability Set: ['0.45618']
#   Real Probability Set      : ['0.07174']
# Sample 3:
#   Predictive Probability Set: ['0.50369']
#   Real Probability Set      : ['0.17153']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=5, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8972 ± 0.0062
# Final Average Prediction Set Size: 3.23 ± 0.07
# Final Average Coverage: 0.8996 ± 0.0089
# Final Average Real Probability: 0.7443 ± 0.0069
# 1715 (3.43%) samples reached the peak conditional coverage at 0.8833

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.1, k_reg=5, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8972 ± 0.0062
# Final Average Prediction Set Size: 3.23 ± 0.07
# Final Average Coverage: 0.8996 ± 0.0089
# Final Average Real Probability: 0.7443 ± 0.0069
# Peak Conditional Coverage = 0.883, with 1723 samples
#
# === Count Regions Summary ===
# 23381 (46.8%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 491 (1.0%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 25209 (50.4%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99572']
#   Real Probability Set      : ['0.94729']
# Sample 2:
#   Predictive Probability Set: ['0.62463', '0.33959']
#   Real Probability Set      : ['0.63794', '0.19089']
# Sample 3:
#   Predictive Probability Set: ['0.87318']
#   Real Probability Set      : ['0.83601']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.96315']
#   Real Probability Set      : ['0.19358']
# Sample 2:
#   Predictive Probability Set: ['0.97071']
#   Real Probability Set      : ['0.06443']
# Sample 3:
#   Predictive Probability Set: ['0.88521', '0.03308']
#   Real Probability Set      : ['0.14046', '0.02085']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.45600', '0.15582', '0.09041', '0.08414', '0.06400']
#   Real Probability Set      : ['0.10741', '0.47706', '0.04443', '0.03821', '0.01044']
# Sample 2:
#   Predictive Probability Set: ['0.52376', '0.17584', '0.10261', '0.05830', '0.05584']
#   Real Probability Set      : ['0.19745', '0.02517', '0.11663', '0.00061', '0.35519']
# Sample 3:
#   Predictive Probability Set: ['0.72360', '0.15465', '0.04829']
#   Real Probability Set      : ['0.19144', '0.24609', '0.32480']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.73304', '0.07947', '0.04711', '0.03346']
#   Real Probability Set      : ['0.18725', '0.05770', '0.60676', '0.01280']
# Sample 2:
#   Predictive Probability Set: ['0.35236', '0.19757', '0.11407', '0.09764', '0.07185']
#   Real Probability Set      : ['0.13287', '0.73353', '0.01613', '0.01050', '0.00450']
# Sample 3:
#   Predictive Probability Set: ['0.53224', '0.16267', '0.10077', '0.09812']
#   Real Probability Set      : ['0.01701', '0.70836', '0.06051', '0.07679']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.50369']
#   Real Probability Set      : ['0.17153']
# Sample 2:
#   Predictive Probability Set: ['0.55949']
#   Real Probability Set      : ['0.18486']
# Sample 3:
#   Predictive Probability Set: ['0.55658']
#   Real Probability Set      : ['0.19004']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.13, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8991 ± 0.0086
# Final Average Prediction Set Size: 3.18 ± 0.06
# Final Average Coverage: 0.9006 ± 0.0076
# Final Average Real Probability: 0.7392 ± 0.0054
# 1561 (3.12%) samples reached the peak conditional coverage at 0.8933

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.13, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8991 ± 0.0086
# Final Average Prediction Set Size: 3.18 ± 0.06
# Final Average Coverage: 0.9006 ± 0.0076
# Final Average Real Probability: 0.7392 ± 0.0054
# Peak Conditional Coverage = 0.898, with 1644 samples
#
# === Count Regions Summary ===
# 23055 (46.1%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 462 (0.9%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 25661 (51.3%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99944']
#   Real Probability Set      : ['0.97017']
# Sample 2:
#   Predictive Probability Set: ['0.99832']
#   Real Probability Set      : ['0.96064']
# Sample 3:
#   Predictive Probability Set: ['0.75416', '0.23536']
#   Real Probability Set      : ['0.73717', '0.19512']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.96315']
#   Real Probability Set      : ['0.19358']
# Sample 2:
#   Predictive Probability Set: ['0.59452', '0.20497', '0.05677']
#   Real Probability Set      : ['0.05914', '0.02945', '0.04410']
# Sample 3:
#   Predictive Probability Set: ['0.91803']
#   Real Probability Set      : ['0.14115']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.30831', '0.16745', '0.12930', '0.08840', '0.08534']
#   Real Probability Set      : ['0.20851', '0.09310', '0.03798', '0.00349', '0.43801']
# Sample 2:
#   Predictive Probability Set: ['0.53267', '0.24092', '0.07748']
#   Real Probability Set      : ['0.19736', '0.09455', '0.34480']
# Sample 3:
#   Predictive Probability Set: ['0.70192', '0.11436', '0.06369']
#   Real Probability Set      : ['0.28878', '0.29001', '0.19449']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.80820', '0.11585']
#   Real Probability Set      : ['0.23023', '0.60154']
# Sample 2:
#   Predictive Probability Set: ['0.55053', '0.19849', '0.08893', '0.08038']
#   Real Probability Set      : ['0.17671', '0.09944', '0.61314', '0.06594']
# Sample 3:
#   Predictive Probability Set: ['0.77217', '0.09901', '0.05225']
#   Real Probability Set      : ['0.14990', '0.36933', '0.38271']
#
# --- Region 5: low TVD, low Coverage ---
# No points are found in this region.
