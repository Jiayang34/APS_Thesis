# %% [markdown]
# ## Ground-Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=10)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_10class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_10class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8971 ± 0.0054
# Final Average Prediction Set Size: 3.75 ± 0.10
# Final Average Coverage: 0.9004 ± 0.0108
# Final Average Real Probability: 0.8973 ± 0.0054
# 7764 (15.53%) samples reached the peak conditional coverage at 0.9032

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=6, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8978 ± 0.0055
# Final Average Prediction Set Size: 3.74 ± 0.09
# Final Average Coverage: 0.9003 ± 0.0107
# Final Average Real Probability: 0.8967 ± 0.0053
# 7701 (15.40%) samples reached the peak conditional coverage at 0.9032

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.15, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9347 ± 0.0131
# Final Average Prediction Set Size: 3.72 ± 0.09
# Final Average Coverage: 0.9003 ± 0.0106
# Final Average Real Probability: 0.8953 ± 0.0052
# 3627 (7.25%) samples reached the peak conditional coverage at 0.9234

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8810 ± 0.0055
# Final Average Prediction Set Size: 3.36 ± 0.08
# Final Average Coverage: 0.8986 ± 0.0096
# Final Average Real Probability: 0.7448 ± 0.0076
# 1730 (3.46%) samples reached the peak conditional coverage at 0.8833

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8810 ± 0.0055
# Final Average Prediction Set Size: 3.36 ± 0.08
# Final Average Coverage: 0.8986 ± 0.0096
# Final Average Real Probability: 0.7448 ± 0.0076
# Peak Conditional Coverage = 0.883, with 1743 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.45606', '0.29257', '0.05805', '0.05653', '0.05076']
#   Real Probability Set      : ['0.48992', '0.27544', '0.01067', '0.09754', '0.02284']
# Sample 2:
#   Predictive Probability Set: ['0.74707', '0.19127']
#   Real Probability Set      : ['0.63118', '0.19706']
# Sample 3:
#   Predictive Probability Set: ['0.99879']
#   Real Probability Set      : ['0.90892']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.80440']
#   Real Probability Set      : ['0.15993']
# Sample 2:
#   Predictive Probability Set: ['0.90911']
#   Real Probability Set      : ['0.08680']
# Sample 3:
#   Predictive Probability Set: ['0.67909', '0.20651']
#   Real Probability Set      : ['0.05965', '0.02419']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.56475', '0.16779', '0.08687', '0.04643', '0.04332']
#   Real Probability Set      : ['0.15534', '0.03649', '0.05275', '0.26544', '0.00243']
# Sample 2:
#   Predictive Probability Set: ['0.49436', '0.23391', '0.07532', '0.06679']
#   Real Probability Set      : ['0.35020', '0.00130', '0.40310', '0.00891']
# Sample 3:
#   Predictive Probability Set: ['0.65734', '0.08640', '0.08437', '0.05698']
#   Real Probability Set      : ['0.23697', '0.24897', '0.01186', '0.05161']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.57632', '0.15160', '0.09961', '0.04039']
#   Real Probability Set      : ['0.08699', '0.78084', '0.06058', '0.00243']
# Sample 2:
#   Predictive Probability Set: ['0.71102', '0.07269', '0.05535', '0.04988']
#   Real Probability Set      : ['0.23384', '0.00389', '0.15507', '0.50286']
# Sample 3:
#   Predictive Probability Set: ['0.50240', '0.19153', '0.13157']
#   Real Probability Set      : ['0.11416', '0.04999', '0.71540']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=5, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8972 ± 0.0062
# Final Average Prediction Set Size: 3.23 ± 0.07
# Final Average Coverage: 0.8996 ± 0.0089
# Final Average Real Probability: 0.7443 ± 0.0069
# 1715 (3.43%) samples reached the peak conditional coverage at 0.8833

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.1, k_reg=5, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8972 ± 0.0062
# Final Average Prediction Set Size: 3.23 ± 0.07
# Final Average Coverage: 0.8996 ± 0.0089
# Final Average Real Probability: 0.7443 ± 0.0069
# Peak Conditional Coverage = 0.883, with 1723 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.79250', '0.13590']
#   Real Probability Set      : ['0.67994', '0.16575']
# Sample 2:
#   Predictive Probability Set: ['0.99956']
#   Real Probability Set      : ['0.89044']
# Sample 3:
#   Predictive Probability Set: ['0.99939']
#   Real Probability Set      : ['0.93026']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.86688']
#   Real Probability Set      : ['0.19197']
# Sample 2:
#   Predictive Probability Set: ['0.90550']
#   Real Probability Set      : ['0.10513']
# Sample 3:
#   Predictive Probability Set: ['0.88521']
#   Real Probability Set      : ['0.14046']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.82625', '0.04659']
#   Real Probability Set      : ['0.24461', '0.16090']
# Sample 2:
#   Predictive Probability Set: ['0.67936', '0.10870', '0.06932', '0.06015']
#   Real Probability Set      : ['0.13280', '0.26828', '0.01818', '0.00446']
# Sample 3:
#   Predictive Probability Set: ['0.72835', '0.05317', '0.05075', '0.04680', '0.03541']
#   Real Probability Set      : ['0.14158', '0.21539', '0.13117', '0.16135', '0.04296']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.81617', '0.06987', '0.06397']
#   Real Probability Set      : ['0.28566', '0.02052', '0.65887']
# Sample 2:
#   Predictive Probability Set: ['0.81664', '0.12498']
#   Real Probability Set      : ['0.21718', '0.65783']
# Sample 3:
#   Predictive Probability Set: ['0.68327', '0.15920', '0.04781']
#   Real Probability Set      : ['0.15209', '0.72246', '0.04683']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.13, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8843 ± 0.0107
# Final Average Prediction Set Size: 3.09 ± 0.07
# Final Average Coverage: 0.8934 ± 0.0090
# Final Average Real Probability: 0.7293 ± 0.0080
# 1515 (3.03%) samples reached the peak conditional coverage at 0.8833

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.13, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8843 ± 0.0107
# Final Average Prediction Set Size: 3.09 ± 0.07
# Final Average Coverage: 0.8934 ± 0.0090
# Final Average Real Probability: 0.7293 ± 0.0080
# Peak Conditional Coverage = 0.913, with 1513 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99998']
#   Real Probability Set      : ['0.97857']
# Sample 2:
#   Predictive Probability Set: ['0.99904']
#   Real Probability Set      : ['0.96192']
# Sample 3:
#   Predictive Probability Set: ['0.74779', '0.15655']
#   Real Probability Set      : ['0.73053', '0.09628']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.84240']
#   Real Probability Set      : ['0.12604']
# Sample 2:
#   Predictive Probability Set: ['0.76140']
#   Real Probability Set      : ['0.13050']
# Sample 3:
#   Predictive Probability Set: ['0.84240']
#   Real Probability Set      : ['0.12604']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.86892', '0.04896']
#   Real Probability Set      : ['0.34790', '0.44048']
# Sample 2:
#   Predictive Probability Set: ['0.41409', '0.26299', '0.14199', '0.04785']
#   Real Probability Set      : ['0.07041', '0.07661', '0.15417', '0.12306']
# Sample 3:
#   Predictive Probability Set: ['0.72003', '0.07745', '0.05065']
#   Real Probability Set      : ['0.29057', '0.17751', '0.20977']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.39532', '0.17539', '0.13188', '0.07355', '0.07019']
#   Real Probability Set      : ['0.09213', '0.06999', '0.66900', '0.05005', '0.02091']
# Sample 2:
#   Predictive Probability Set: ['0.31929', '0.31447', '0.21302', '0.09144', '0.02323']
#   Real Probability Set      : ['0.12124', '0.00858', '0.84875', '0.00008', '0.00060']
# Sample 3:
#   Predictive Probability Set: ['0.28850', '0.19385', '0.13682', '0.11649', '0.09847', '0.03997']
#   Real Probability Set      : ['0.05427', '0.00687', '0.74480', '0.04388', '0.00668', '0.00665']
