# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=10)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_10class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_10class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9443 ± 0.0026
# Final Average Prediction Set Size: 4.77 ± 0.08
# Final Average Coverage: 0.9491 ± 0.0048
# Final Average Real Probability: 0.9443 ± 0.0027
# 12919 (25.84%) samples reached the peak conditional coverage at 0.9432

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_= 0.05, k_reg=7, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9450 ± 0.0027
# Final Average Prediction Set Size: 4.76 ± 0.08
# Final Average Coverage: 0.9494 ± 0.0047
# Final Average Real Probability: 0.9439 ± 0.0026
# 12721 (25.44%) samples reached the peak conditional coverage at 0.9432

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.15, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.1213 ± 0.0155
# Final Average Prediction Set Size: 4.96 ± 0.11
# Final Average Coverage: 0.9503 ± 0.0057
# Final Average Real Probability: 0.9458 ± 0.0030
# 1724 (3.45%) samples reached the peak conditional coverage at 0.9651

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9441 ± 0.0024
# Final Average Prediction Set Size: 4.56 ± 0.07
# Final Average Coverage: 0.9487 ± 0.0037
# Final Average Real Probability: 0.8329 ± 0.0049
# 2194 (4.39%) samples reached the peak conditional coverage at 0.9508

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9441 ± 0.0024
# Final Average Prediction Set Size: 4.56 ± 0.07
# Final Average Coverage: 0.9487 ± 0.0037
# Final Average Real Probability: 0.8329 ± 0.0049
# Peak Conditional Coverage = 0.953, with 2473 samples
#
# === Count Regions Summary ===
# 34057 (68.1%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 1170 (2.3%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 14231 (28.5%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.77661', '0.05240', '0.04273', '0.04070']
#   Real Probability Set      : ['0.73194', '0.02663', '0.10028', '0.00327']
# Sample 2:
#   Predictive Probability Set: ['0.82800', '0.05667', '0.02563', '0.01993', '0.01785']
#   Real Probability Set      : ['0.79227', '0.08242', '0.01437', '0.05336', '0.02226']
# Sample 3:
#   Predictive Probability Set: ['0.75849', '0.04961', '0.04751', '0.03647', '0.03553']
#   Real Probability Set      : ['0.72860', '0.03214', '0.11075', '0.06031', '0.00371']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.86688']
#   Real Probability Set      : ['0.19197']
# Sample 2:
#   Predictive Probability Set: ['0.93277']
#   Real Probability Set      : ['0.11058']
# Sample 3:
#   Predictive Probability Set: ['0.90550']
#   Real Probability Set      : ['0.10513']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.79103', '0.10833', '0.05404']
#   Real Probability Set      : ['0.33361', '0.25161', '0.21345']
# Sample 2:
#   Predictive Probability Set: ['0.63872', '0.13314', '0.09558', '0.05238', '0.02763']
#   Real Probability Set      : ['0.13051', '0.03671', '0.12293', '0.35882', '0.01027']
# Sample 3:
#   Predictive Probability Set: ['0.53993', '0.14858', '0.06661', '0.06007', '0.05796', '0.05010']
#   Real Probability Set      : ['0.22146', '0.07450', '0.10486', '0.03178', '0.06347', '0.20614']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.61547', '0.08734', '0.08420', '0.06194', '0.03861', '0.03247', '0.02557']
#   Real Probability Set      : ['0.07847', '0.05988', '0.16410', '0.07178', '0.00099', '0.41053', '0.05457']
# Sample 2:
#   Predictive Probability Set: ['0.21386', '0.20336', '0.12455', '0.10437', '0.09592', '0.07545', '0.05785', '0.04647']
#   Real Probability Set      : ['0.04793', '0.01824', '0.69725', '0.06310', '0.00754', '0.11076', '0.00239', '0.01330']
# Sample 3:
#   Predictive Probability Set: ['0.38127', '0.30784', '0.13125', '0.03483', '0.03446', '0.03185', '0.02901']
#   Real Probability Set      : ['0.06604', '0.14587', '0.49827', '0.00270', '0.06509', '0.00626', '0.12087']
#
# --- Region 5: low TVD, low Coverage ---
# No points are found in this region.

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_= 0.01, k_reg=5, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9523 ± 0.0032
# Final Average Prediction Set Size: 4.50 ± 0.08
# Final Average Coverage: 0.9491 ± 0.0042
# Final Average Real Probability: 0.8343 ± 0.0051
# 2503 (5.01%) samples reached the peak conditional coverage at 0.9547

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_= 0.01, k_reg=5, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9523 ± 0.0032
# Final Average Prediction Set Size: 4.50 ± 0.08
# Final Average Coverage: 0.9491 ± 0.0042
# Final Average Real Probability: 0.8343 ± 0.0051
# Peak Conditional Coverage = 0.943, with 2480 samples
#
# === Count Regions Summary ===
# 34336 (68.7%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 1225 (2.5%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 13969 (27.9%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.83168', '0.14221']
#   Real Probability Set      : ['0.73346', '0.18009']
# Sample 2:
#   Predictive Probability Set: ['0.70188', '0.10299', '0.09771', '0.02430', '0.02328']
#   Real Probability Set      : ['0.67735', '0.05242', '0.14384', '0.00723', '0.01524']
# Sample 3:
#   Predictive Probability Set: ['0.99882']
#   Real Probability Set      : ['0.91190']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.92451']
#   Real Probability Set      : ['0.12849']
# Sample 2:
#   Predictive Probability Set: ['0.81349']
#   Real Probability Set      : ['0.13913']
# Sample 3:
#   Predictive Probability Set: ['0.86212']
#   Real Probability Set      : ['0.06919']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.83045', '0.05947', '0.05115', '0.01803']
#   Real Probability Set      : ['0.35866', '0.15444', '0.00655', '0.16210']
# Sample 2:
#   Predictive Probability Set: ['0.81653', '0.11333', '0.01524']
#   Real Probability Set      : ['0.41482', '0.01749', '0.21202']
# Sample 3:
#   Predictive Probability Set: ['0.35138', '0.18382', '0.11126', '0.07755', '0.06902', '0.06606', '0.05276']
#   Real Probability Set      : ['0.15121', '0.03389', '0.02854', '0.01330', '0.16050', '0.00754', '0.17859']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.75519', '0.09842', '0.08449', '0.03588']
#   Real Probability Set      : ['0.20496', '0.40163', '0.25416', '0.09047']
# Sample 2:
#   Predictive Probability Set: ['0.59304', '0.19662', '0.08170', '0.05363', '0.04281']
#   Real Probability Set      : ['0.16717', '0.10429', '0.63235', '0.01596', '0.02336']
# Sample 3:
#   Predictive Probability Set: ['0.88401', '0.06933']
#   Real Probability Set      : ['0.27782', '0.65411']
#
# --- Region 5: low TVD, low Coverage ---
# No points are found in this region.

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.13, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.0724 ± 0.0148
# Final Average Prediction Set Size: 4.42 ± 0.12
# Final Average Coverage: 0.9502 ± 0.0044
# Final Average Real Probability: 0.8349 ± 0.0061
# 2206 (4.41%) samples reached the peak conditional coverage at 0.9478

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.13, num_runs=10, alpha=0.05)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.0724 ± 0.0148
# Final Average Prediction Set Size: 4.42 ± 0.12
# Final Average Coverage: 0.9502 ± 0.0044
# Final Average Real Probability: 0.8349 ± 0.0061
# Peak Conditional Coverage = 0.949, with 2385 samples
#
# === Count Regions Summary ===
# 33522 (67.0%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 1237 (2.5%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 14985 (30.0%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.98421', '0.01064']
#   Real Probability Set      : ['0.87828', '0.02387']
# Sample 2:
#   Predictive Probability Set: ['0.99887', '0.00035']
#   Real Probability Set      : ['0.96208', '0.01606']
# Sample 3:
#   Predictive Probability Set: ['0.84938', '0.04737', '0.02448']
#   Real Probability Set      : ['0.94245', '0.00176', '0.00054']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.90911', '0.01841']
#   Real Probability Set      : ['0.08680', '0.01070']
# Sample 2:
#   Predictive Probability Set: ['0.90911', '0.01841']
#   Real Probability Set      : ['0.08680', '0.01070']
# Sample 3:
#   Predictive Probability Set: ['0.96836']
#   Real Probability Set      : ['0.14583']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.81300', '0.08100', '0.03069']
#   Real Probability Set      : ['0.22176', '0.15769', '0.06923']
# Sample 2:
#   Predictive Probability Set: ['0.83323', '0.04152', '0.03468']
#   Real Probability Set      : ['0.38866', '0.32007', '0.07552']
# Sample 3:
#   Predictive Probability Set: ['0.79103', '0.10833', '0.05404']
#   Real Probability Set      : ['0.33361', '0.25161', '0.21345']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.96315', '0.02875']
#   Real Probability Set      : ['0.19358', '0.70855']
# Sample 2:
#   Predictive Probability Set: ['0.48754', '0.20876', '0.19126', '0.05946', '0.01790', '0.01760']
#   Real Probability Set      : ['0.13108', '0.63349', '0.03171', '0.10245', '0.05442', '0.02714']
# Sample 3:
#   Predictive Probability Set: ['0.46044', '0.31252', '0.13575', '0.04598', '0.01115', '0.00900']
#   Real Probability Set      : ['0.12192', '0.04358', '0.33835', '0.45866', '0.00187', '0.00707']
#
# --- Region 5: low TVD, low Coverage ---
# No points are found in this region.
