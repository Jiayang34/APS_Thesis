# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=10)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_10class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_10class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9443 ± 0.0026
# Final Average Prediction Set Size: 4.77 ± 0.08
# Final Average Coverage: 0.9491 ± 0.0048
# Final Average Real Probability: 0.9443 ± 0.0027
# 12919 (25.84%) samples reached the peak conditional coverage at 0.9432

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_= 0.05, k_reg=7, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9450 ± 0.0027
# Final Average Prediction Set Size: 4.76 ± 0.08
# Final Average Coverage: 0.9494 ± 0.0047
# Final Average Real Probability: 0.9439 ± 0.0026
# 12721 (25.44%) samples reached the peak conditional coverage at 0.9432

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.15, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.1213 ± 0.0155
# Final Average Prediction Set Size: 4.96 ± 0.11
# Final Average Coverage: 0.9503 ± 0.0057
# Final Average Real Probability: 0.9458 ± 0.0030
# 1724 (3.45%) samples reached the peak conditional coverage at 0.9651

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9441 ± 0.0024
# Final Average Prediction Set Size: 4.56 ± 0.07
# Final Average Coverage: 0.9487 ± 0.0037
# Final Average Real Probability: 0.8329 ± 0.0049
# 2194 (4.39%) samples reached the peak conditional coverage at 0.9508

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9441 ± 0.0024
# Final Average Prediction Set Size: 4.56 ± 0.07
# Final Average Coverage: 0.9487 ± 0.0037
# Final Average Real Probability: 0.8329 ± 0.0049
# Peak Conditional Coverage = 0.953, with 2473 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.97065']
#   Real Probability Set      : ['0.94635']
# Sample 2:
#   Predictive Probability Set: ['0.93477']
#   Real Probability Set      : ['0.80951']
# Sample 3:
#   Predictive Probability Set: ['0.98771']
#   Real Probability Set      : ['0.89163']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.93318']
#   Real Probability Set      : ['0.07289']
# Sample 2:
#   Predictive Probability Set: ['0.90550']
#   Real Probability Set      : ['0.10513']
# Sample 3:
#   Predictive Probability Set: ['0.92451']
#   Real Probability Set      : ['0.12849']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.66382', '0.26915']
#   Real Probability Set      : ['0.28034', '0.49731']
# Sample 2:
#   Predictive Probability Set: ['0.74517', '0.04479', '0.03977', '0.03921', '0.03888', '0.03298']
#   Real Probability Set      : ['0.29379', '0.03963', '0.19128', '0.10843', '0.03215', '0.03119']
# Sample 3:
#   Predictive Probability Set: ['0.83285', '0.07720', '0.04154']
#   Real Probability Set      : ['0.29330', '0.05826', '0.37419']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.21304', '0.20177', '0.17863', '0.10028', '0.09252', '0.05362', '0.04843', '0.04616']
#   Real Probability Set      : ['0.05906', '0.00969', '0.81162', '0.00423', '0.01899', '0.00055', '0.00722', '0.00666']
# Sample 2:
#   Predictive Probability Set: ['0.55774', '0.13381', '0.13348', '0.04982', '0.03727', '0.02088']
#   Real Probability Set      : ['0.16544', '0.08172', '0.04821', '0.53850', '0.01048', '0.01465']
# Sample 3:
#   Predictive Probability Set: ['0.59764', '0.17502', '0.15308']
#   Real Probability Set      : ['0.11385', '0.72400', '0.07570']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_= 0.01, k_reg=5, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9523 ± 0.0032
# Final Average Prediction Set Size: 4.50 ± 0.08
# Final Average Coverage: 0.9491 ± 0.0042
# Final Average Real Probability: 0.8343 ± 0.0051
# 2503 (5.01%) samples reached the peak conditional coverage at 0.9547

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_= 0.01, k_reg=5, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9523 ± 0.0032
# Final Average Prediction Set Size: 4.50 ± 0.08
# Final Average Coverage: 0.9491 ± 0.0042
# Final Average Real Probability: 0.8343 ± 0.0051
# Peak Conditional Coverage = 0.943, with 2480 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.81393', '0.05614', '0.02911', '0.02444', '0.01932']
#   Real Probability Set      : ['0.75686', '0.01233', '0.03702', '0.03278', '0.03033']
# Sample 2:
#   Predictive Probability Set: ['0.78716', '0.08866', '0.04016', '0.03127', '0.01739']
#   Real Probability Set      : ['0.73145', '0.07244', '0.03892', '0.00319', '0.09675']
# Sample 3:
#   Predictive Probability Set: ['0.43949', '0.26019', '0.06164', '0.05035', '0.04841', '0.04509', '0.04053']
#   Real Probability Set      : ['0.44713', '0.20272', '0.03963', '0.03630', '0.00412', '0.04144', '0.05421']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.91294', '0.03527']
#   Real Probability Set      : ['0.17460', '0.00803']
# Sample 2:
#   Predictive Probability Set: ['0.88822']
#   Real Probability Set      : ['0.05277']
# Sample 3:
#   Predictive Probability Set: ['0.96315']
#   Real Probability Set      : ['0.19358']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.75960', '0.05113', '0.04474', '0.03970', '0.03207', '0.02475']
#   Real Probability Set      : ['0.37365', '0.34467', '0.01093', '0.00619', '0.00296', '0.01633']
# Sample 2:
#   Predictive Probability Set: ['0.58913', '0.12294', '0.07361', '0.04723', '0.04277', '0.03809']
#   Real Probability Set      : ['0.15579', '0.02011', '0.09617', '0.02575', '0.00334', '0.37521']
# Sample 3:
#   Predictive Probability Set: ['0.80973', '0.04638', '0.03950', '0.03631']
#   Real Probability Set      : ['0.39779', '0.19680', '0.07989', '0.01185']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.31929', '0.31447', '0.21302', '0.09144', '0.02323']
#   Real Probability Set      : ['0.12124', '0.00858', '0.84875', '0.00008', '0.00060']
# Sample 2:
#   Predictive Probability Set: ['0.18796', '0.13585', '0.12357', '0.11981', '0.11565', '0.07590', '0.07381', '0.06538']
#   Real Probability Set      : ['0.01713', '0.23766', '0.60664', '0.03937', '0.01550', '0.01267', '0.00119', '0.03864']
# Sample 3:
#   Predictive Probability Set: ['0.66053', '0.09126', '0.06682', '0.03960', '0.03959', '0.03223', '0.02892']
#   Real Probability Set      : ['0.12465', '0.01464', '0.03522', '0.41424', '0.20680', '0.18326', '0.00509']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.1, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.0439 ± 0.0128
# Final Average Prediction Set Size: 4.20 ± 0.10
# Final Average Coverage: 0.9452 ± 0.0038
# Final Average Real Probability: 0.8221 ± 0.0059
# 2071 (4.14%) samples reached the peak conditional coverage at 0.9474

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.1, num_runs=10, alpha=0.05)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9373 ± 0.0124
# Final Average Prediction Set Size: 4.15 ± 0.11
# Final Average Coverage: 0.9371 ± 0.0062
# Final Average Real Probability: 0.8024 ± 0.0083
# Peak Conditional Coverage = 0.958, with 2126 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.88046', '0.06498']
#   Real Probability Set      : ['0.92334', '0.05043']
# Sample 2:
#   Predictive Probability Set: ['0.85311', '0.05509']
#   Real Probability Set      : ['0.88093', '0.06670']
# Sample 3:
#   Predictive Probability Set: ['0.51826', '0.26388', '0.20413', '0.01196', '0.00073']
#   Real Probability Set      : ['0.45985', '0.23305', '0.26361', '0.00653', '0.00258']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.88822']
#   Real Probability Set      : ['0.05277']
# Sample 2:
#   Predictive Probability Set: ['0.76180', '0.08114']
#   Real Probability Set      : ['0.07110', '0.01574']
# Sample 3:
#   Predictive Probability Set: ['0.87068', '0.05540']
#   Real Probability Set      : ['0.10728', '0.04946']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.46947', '0.23950', '0.07004', '0.06873', '0.05470']
#   Real Probability Set      : ['0.09296', '0.35436', '0.03979', '0.00823', '0.08301']
# Sample 2:
#   Predictive Probability Set: ['0.74009', '0.06970', '0.04572']
#   Real Probability Set      : ['0.21332', '0.38885', '0.00259']
# Sample 3:
#   Predictive Probability Set: ['0.80064', '0.04125']
#   Real Probability Set      : ['0.32444', '0.20960']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.80820', '0.11585']
#   Real Probability Set      : ['0.23023', '0.60154']
# Sample 2:
#   Predictive Probability Set: ['0.55774', '0.13381', '0.13348', '0.04982', '0.03727']
#   Real Probability Set      : ['0.16544', '0.08172', '0.04821', '0.53850', '0.01048']
# Sample 3:
#   Predictive Probability Set: ['0.57856', '0.15845', '0.09870', '0.04669', '0.03947']
#   Real Probability Set      : ['0.09095', '0.47560', '0.04814', '0.09083', '0.17737']
