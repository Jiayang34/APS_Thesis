# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, raps_synthetic_data_scatter, aps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=10)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_10class_NoTemp_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_10class_NoTemp_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7992 ± 0.0046
# Final Average Prediction Set Size: 1.06 ± 0.01
# Final Average Coverage: 0.7952 ± 0.0066
# Final Average Real Probability: 0.7962 ± 0.0063
# 14850 (29.70%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.05, k_reg=1, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8138 ± 0.0052
# Final Average Prediction Set Size: 1.02 ± 0.01
# Final Average Coverage: 0.7947 ± 0.0063
# Final Average Real Probability: 0.7960 ± 0.0060
# 14726 (29.45%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=20.0, num_runs=10, alpha=0.2)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8722 ± 0.0075
# Final Average Prediction Set Size: 0.94 ± 0.01
# Final Average Coverage: 0.7973 ± 0.0065
# Final Average Real Probability: 0.7975 ± 0.0045
# 14984 (29.97%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8006 ± 0.0055
# Final Average Prediction Set Size: 0.95 ± 0.01
# Final Average Coverage: 0.7924 ± 0.0077
# Final Average Real Probability: 0.6869 ± 0.0056
# 13655 (27.31%) samples reached the peak conditional coverage at 0.9955

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8006 ± 0.0055
# Final Average Prediction Set Size: 0.95 ± 0.01
# Final Average Coverage: 0.7924 ± 0.0077
# Final Average Real Probability: 0.6869 ± 0.0056
# Peak Conditional Coverage = 0.999, with 12056 samples
#
# === Count Regions Summary ===
# 29275 (58.6%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 271 (0.5%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 11745 (23.5%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99986']
# Sample 2:
#   Predictive Probability Set: ['0.99998']
#   Real Probability Set      : ['0.99705']
# Sample 3:
#   Predictive Probability Set: ['0.99999']
#   Real Probability Set      : ['0.98433']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.89892']
#   Real Probability Set      : ['0.18269']
# Sample 2:
#   Predictive Probability Set: ['0.97777']
#   Real Probability Set      : ['0.09920']
# Sample 3:
#   Predictive Probability Set: ['0.76943']
#   Real Probability Set      : ['0.15493']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.38656', '0.14436', '0.10119', '0.09994', '0.06171']
#   Real Probability Set      : ['0.20651', '0.00040', '0.00168', '0.28118', '0.00000']
# Sample 2:
#   Predictive Probability Set: ['0.67934', '0.06061', '0.05840']
#   Real Probability Set      : ['0.31769', '0.00004', '0.25795']
# Sample 3:
#   Predictive Probability Set: ['0.44188', '0.14818', '0.14349', '0.05799']
#   Real Probability Set      : ['0.16221', '0.06675', '0.34702', '0.00195']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.72003', '0.27330']
#   Real Probability Set      : ['0.06860', '0.90624']
# Sample 2:
#   Predictive Probability Set: ['0.44559', '0.24182', '0.15661']
#   Real Probability Set      : ['0.08128', '0.14101', '0.77652']
# Sample 3:
#   Predictive Probability Set: ['0.26782', '0.14487', '0.09103', '0.08637', '0.08548', '0.07699', '0.07288']
#   Real Probability Set      : ['0.03591', '0.00584', '0.48529', '0.20468', '0.09487', '0.00001', '0.16558']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.51530']
#   Real Probability Set      : ['0.13391']
# Sample 2:
#   Predictive Probability Set: ['0.51530']
#   Real Probability Set      : ['0.13391']
# Sample 3:
#   Predictive Probability Set: ['0.52667']
#   Real Probability Set      : ['0.15931']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.05, k_reg=1, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8058 ± 0.0055
# Final Average Prediction Set Size: 0.90 ± 0.01
# Final Average Coverage: 0.7929 ± 0.0072
# Final Average Real Probability: 0.6848 ± 0.0049
# 13536 (27.07%) samples reached the peak conditional coverage at 0.9955

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.05, k_reg=1, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8058 ± 0.0055
# Final Average Prediction Set Size: 0.90 ± 0.01
# Final Average Coverage: 0.7929 ± 0.0072
# Final Average Real Probability: 0.6848 ± 0.0049
# Peak Conditional Coverage = 0.999, with 12003 samples
#
# === Count Regions Summary ===
# 29099 (58.2%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 115 (0.2%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 12361 (24.7%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99995']
#   Real Probability Set      : ['0.99484']
# Sample 2:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99511']
# Sample 3:
#   Predictive Probability Set: ['0.99995']
#   Real Probability Set      : ['0.97522']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.91287']
#   Real Probability Set      : ['0.08801']
# Sample 2:
#   Predictive Probability Set: ['0.93180']
#   Real Probability Set      : ['0.17080']
# Sample 3:
#   Predictive Probability Set: ['0.98190']
#   Real Probability Set      : ['0.17955']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.54694', '0.33627']
#   Real Probability Set      : ['0.05167', '0.62548']
# Sample 2:
#   Predictive Probability Set: ['0.65769', '0.08487']
#   Real Probability Set      : ['0.14955', '0.45455']
# Sample 3:
#   Predictive Probability Set: ['0.26782', '0.14487', '0.09103', '0.08637']
#   Real Probability Set      : ['0.03591', '0.00584', '0.48529', '0.20468']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.52114', '0.46278']
#   Real Probability Set      : ['0.02061', '0.97514']
# Sample 2:
#   Predictive Probability Set: ['0.61838', '0.29750']
#   Real Probability Set      : ['0.00371', '0.99075']
# Sample 3:
#   Predictive Probability Set: ['0.18872', '0.13942', '0.11792', '0.10140']
#   Real Probability Set      : ['0.02928', '0.01554', '0.06246', '0.85178']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.54722']
#   Real Probability Set      : ['0.19575']
# Sample 2:
#   Predictive Probability Set: ['0.53584']
#   Real Probability Set      : ['0.15556']
# Sample 3:
#   Predictive Probability Set: ['0.54722']
#   Real Probability Set      : ['0.19575']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=5.0, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8219 ± 0.0043
# Final Average Prediction Set Size: 0.85 ± 0.01
# Final Average Coverage: 0.7977 ± 0.0067
# Final Average Real Probability: 0.6842 ± 0.0048
# 14066 (28.13%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=2.0, num_runs=10, alpha=0.2)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8205 ± 0.0043
# Final Average Prediction Set Size: 0.86 ± 0.01
# Final Average Coverage: 0.7977 ± 0.0063
# Final Average Real Probability: 0.6845 ± 0.0046
# Peak Conditional Coverage = 0.996, with 13596 samples
#
# === Count Regions Summary ===
# 28882 (57.8%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 11 (0.0%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 13471 (26.9%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99700']
# Sample 2:
#   Predictive Probability Set: ['0.99962']
#   Real Probability Set      : ['0.97810']
# Sample 3:
#   Predictive Probability Set: ['0.99804']
#   Real Probability Set      : ['0.95716']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.72515']
#   Real Probability Set      : ['0.16654']
# Sample 2:
#   Predictive Probability Set: ['0.73818']
#   Real Probability Set      : ['0.06594']
# Sample 3:
#   Predictive Probability Set: ['0.97219']
#   Real Probability Set      : ['0.16933']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.64100', '0.12580']
#   Real Probability Set      : ['0.18814', '0.43730']
# Sample 2:
#   Predictive Probability Set: ['0.30141', '0.24726']
#   Real Probability Set      : ['0.07922', '0.69952']
# Sample 3:
#   Predictive Probability Set: ['0.25033', '0.23478']
#   Real Probability Set      : ['0.74309', '0.02426']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.58446', '0.41524']
#   Real Probability Set      : ['0.04835', '0.95139']
# Sample 2:
#   Predictive Probability Set: ['0.52323', '0.25633']
#   Real Probability Set      : ['0.12369', '0.85828']
# Sample 3:
#   Predictive Probability Set: ['0.45561', '0.29198']
#   Real Probability Set      : ['0.03636', '0.90561']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.21705']
#   Real Probability Set      : ['0.11878']
# Sample 2:
#   Predictive Probability Set: ['0.36735']
#   Real Probability Set      : ['0.03663']
# Sample 3:
#   Predictive Probability Set: ['0.41911']
#   Real Probability Set      : ['0.04512']
