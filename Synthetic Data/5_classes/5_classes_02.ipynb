# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=5)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_5class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_5class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7968 ± 0.0039
# Final Average Prediction Set Size: 1.92 ± 0.03
# Final Average Coverage: 0.7966 ± 0.0060
# Final Average Real Probability: 0.7963 ± 0.0047
# 2543 (5.09%) samples reached the peak conditional coverage at 0.8324

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=1, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9258 ± 0.0045
# Final Average Prediction Set Size: 1.85 ± 0.02
# Final Average Coverage: 0.7971 ± 0.0051
# Final Average Real Probability: 0.7964 ± 0.0028
# 2320 (4.64%) samples reached the peak conditional coverage at 0.8424

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.35, num_runs=10, alpha=0.2)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8800 ± 0.0039
# Final Average Prediction Set Size: 1.84 ± 0.01
# Final Average Coverage: 0.7962 ± 0.0036
# Final Average Real Probability: 0.7964 ± 0.0025
# 1954 (3.91%) samples reached the peak conditional coverage at 0.7841

# %% [markdown]
# ## Model Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=5)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_5class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_5class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.2,is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7759 ± 0.0030
# Final Average Prediction Set Size: 1.57 ± 0.02
# Final Average Coverage: 0.7969 ± 0.0065
# Final Average Real Probability: 0.6469 ± 0.0046
# 1178 (2.36%) samples reached the peak conditional coverage at 0.8424

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7759 ± 0.0030
# Final Average Prediction Set Size: 1.57 ± 0.02
# Final Average Coverage: 0.7969 ± 0.0065
# Final Average Real Probability: 0.6469 ± 0.0046
# Peak Conditional Coverage = 0.841, with 1167 samples
#
# === Count Regions Summary ===
# 15139 (30.3%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 49 (0.1%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 31858 (63.7%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.52606', '0.29762']
#   Real Probability Set      : ['0.65449', '0.25187']
# Sample 2:
#   Predictive Probability Set: ['0.99858']
#   Real Probability Set      : ['0.92236']
# Sample 3:
#   Predictive Probability Set: ['0.91595']
#   Real Probability Set      : ['0.86734']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.66833']
#   Real Probability Set      : ['0.11262']
# Sample 2:
#   Predictive Probability Set: ['0.81006']
#   Real Probability Set      : ['0.14675']
# Sample 3:
#   Predictive Probability Set: ['0.76592']
#   Real Probability Set      : ['0.12370']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.65534', '0.15432']
#   Real Probability Set      : ['0.13062', '0.40743']
# Sample 2:
#   Predictive Probability Set: ['0.67208', '0.13773']
#   Real Probability Set      : ['0.24366', '0.44305']
# Sample 3:
#   Predictive Probability Set: ['0.47537', '0.17603', '0.12559']
#   Real Probability Set      : ['0.12382', '0.20518', '0.45138']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.48409', '0.17880', '0.13801']
#   Real Probability Set      : ['0.07346', '0.06827', '0.67509']
# Sample 2:
#   Predictive Probability Set: ['0.61755', '0.13339']
#   Real Probability Set      : ['0.15243', '0.71932']
# Sample 3:
#   Predictive Probability Set: ['0.61755', '0.13339']
#   Real Probability Set      : ['0.15243', '0.71932']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.51876']
#   Real Probability Set      : ['0.13545']
# Sample 2:
#   Predictive Probability Set: ['0.51427']
#   Real Probability Set      : ['0.19686']
# Sample 3:
#   Predictive Probability Set: ['0.44778']
#   Real Probability Set      : ['0.08703']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.01, k_reg=1, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7841 ± 0.0030
# Final Average Prediction Set Size: 1.54 ± 0.02
# Final Average Coverage: 0.7961 ± 0.0061
# Final Average Real Probability: 0.6446 ± 0.0044
# 1145 (2.29%) samples reached the peak conditional coverage at 0.8424

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.01, k_reg=1, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7841 ± 0.0030
# Final Average Prediction Set Size: 1.54 ± 0.02
# Final Average Coverage: 0.7961 ± 0.0061
# Final Average Real Probability: 0.6446 ± 0.0044
# Peak Conditional Coverage = 0.840, with 1168 samples
#
# === Count Regions Summary ===
# 14572 (29.1%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 40 (0.1%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 32622 (65.2%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.95452']
#   Real Probability Set      : ['0.87245']
# Sample 2:
#   Predictive Probability Set: ['0.43777', '0.38779']
#   Real Probability Set      : ['0.49084', '0.37805']
# Sample 3:
#   Predictive Probability Set: ['0.48240', '0.28803']
#   Real Probability Set      : ['0.55370', '0.32834']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.56294']
#   Real Probability Set      : ['0.14489']
# Sample 2:
#   Predictive Probability Set: ['0.58885']
#   Real Probability Set      : ['0.18340']
# Sample 3:
#   Predictive Probability Set: ['0.53964']
#   Real Probability Set      : ['0.10181']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.63554', '0.13034']
#   Real Probability Set      : ['0.24344', '0.37307']
# Sample 2:
#   Predictive Probability Set: ['0.48337', '0.22333', '0.10851']
#   Real Probability Set      : ['0.16139', '0.47407', '0.15688']
# Sample 3:
#   Predictive Probability Set: ['0.53964', '0.25697']
#   Real Probability Set      : ['0.10181', '0.51141']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.59937', '0.33243']
#   Real Probability Set      : ['0.08781', '0.82348']
# Sample 2:
#   Predictive Probability Set: ['0.48409', '0.17880', '0.13801']
#   Real Probability Set      : ['0.07346', '0.06827', '0.67509']
# Sample 3:
#   Predictive Probability Set: ['0.61755', '0.13339']
#   Real Probability Set      : ['0.15243', '0.71932']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.55532']
#   Real Probability Set      : ['0.15761']
# Sample 2:
#   Predictive Probability Set: ['0.55821']
#   Real Probability Set      : ['0.18658']
# Sample 3:
#   Predictive Probability Set: ['0.51282']
#   Real Probability Set      : ['0.18810']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.27, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7895 ± 0.0036
# Final Average Prediction Set Size: 1.48 ± 0.01
# Final Average Coverage: 0.7948 ± 0.0092
# Final Average Real Probability: 0.6395 ± 0.0046
# 1075 (2.15%) samples reached the peak conditional coverage at 0.8424

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.27, num_runs=10, alpha=0.2)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7895 ± 0.0036
# Final Average Prediction Set Size: 1.48 ± 0.01
# Final Average Coverage: 0.7948 ± 0.0092
# Final Average Real Probability: 0.6395 ± 0.0046
# Peak Conditional Coverage = 0.721, with 1077 samples
#
# === Count Regions Summary ===
# 14023 (28.0%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 33 (0.1%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 33339 (66.7%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.97081']
#   Real Probability Set      : ['0.83898']
# Sample 2:
#   Predictive Probability Set: ['0.90917']
#   Real Probability Set      : ['0.82638']
# Sample 3:
#   Predictive Probability Set: ['0.92524']
#   Real Probability Set      : ['0.88018']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.55353']
#   Real Probability Set      : ['0.14062']
# Sample 2:
#   Predictive Probability Set: ['0.61922']
#   Real Probability Set      : ['0.14144']
# Sample 3:
#   Predictive Probability Set: ['0.65534']
#   Real Probability Set      : ['0.13062']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.52974', '0.34225']
#   Real Probability Set      : ['0.14801', '0.63833']
# Sample 2:
#   Predictive Probability Set: ['0.54117', '0.17085']
#   Real Probability Set      : ['0.10479', '0.59268']
# Sample 3:
#   Predictive Probability Set: ['0.44749', '0.26133']
#   Real Probability Set      : ['0.15172', '0.63302']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.64463', '0.14494']
#   Real Probability Set      : ['0.16577', '0.68139']
# Sample 2:
#   Predictive Probability Set: ['0.36388', '0.34094', '0.25050']
#   Real Probability Set      : ['0.02669', '0.12184', '0.81319']
# Sample 3:
#   Predictive Probability Set: ['0.59937', '0.33243']
#   Real Probability Set      : ['0.08781', '0.82348']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.57544']
#   Real Probability Set      : ['0.18338']
# Sample 2:
#   Predictive Probability Set: ['0.55219']
#   Real Probability Set      : ['0.15815']
# Sample 3:
#   Predictive Probability Set: ['0.53757']
#   Real Probability Set      : ['0.18973']
