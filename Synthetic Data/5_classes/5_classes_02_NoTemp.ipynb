# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=5)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_5class_NoTemp_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_5class_NoTemp_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.7988 ± 0.0041
# Final Average Prediction Set Size: 0.96 ± 0.01
# Final Average Coverage: 0.7961 ± 0.0067
# Final Average Real Probability: 0.7953 ± 0.0050
# 19706 (39.41%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.05, k_reg=1, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8089 ± 0.0040
# Final Average Prediction Set Size: 0.94 ± 0.01
# Final Average Coverage: 0.7966 ± 0.0062
# Final Average Real Probability: 0.7959 ± 0.0044
# 19418 (38.84%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.6, num_runs=10, alpha=0.2)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8119 ± 0.0045
# Final Average Prediction Set Size: 0.93 ± 0.01
# Final Average Coverage: 0.7988 ± 0.0059
# Final Average Real Probability: 0.7965 ± 0.0062
# 19612 (39.22%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8085 ± 0.0033
# Final Average Prediction Set Size: 0.85 ± 0.00
# Final Average Coverage: 0.7958 ± 0.0042
# Final Average Real Probability: 0.7112 ± 0.0048
# 18513 (37.03%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.2)
# Out:
# APS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8085 ± 0.0033
# Final Average Prediction Set Size: 0.85 ± 0.00
# Final Average Coverage: 0.7958 ± 0.0042
# Final Average Real Probability: 0.7112 ± 0.0048
# Peak Conditional Coverage = 1.000, with 16048 samples
#
# === Count Regions Summary ===
# 31742 (63.5%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 122 (0.2%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 9115 (18.2%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99739']
# Sample 2:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99952']
# Sample 3:
#   Predictive Probability Set: ['0.99764']
#   Real Probability Set      : ['0.93062']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.81621']
#   Real Probability Set      : ['0.05946']
# Sample 2:
#   Predictive Probability Set: ['0.98551']
#   Real Probability Set      : ['0.18852']
# Sample 3:
#   Predictive Probability Set: ['0.99882']
#   Real Probability Set      : ['0.13139']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.54622', '0.33008']
#   Real Probability Set      : ['0.11149', '0.62745']
# Sample 2:
#   Predictive Probability Set: ['0.44928', '0.37472']
#   Real Probability Set      : ['0.04071', '0.68152']
# Sample 3:
#   Predictive Probability Set: ['0.63337', '0.19734']
#   Real Probability Set      : ['0.09873', '0.30744']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.56130', '0.36474']
#   Real Probability Set      : ['0.03976', '0.95649']
# Sample 2:
#   Predictive Probability Set: ['0.76814', '0.15369']
#   Real Probability Set      : ['0.08222', '0.87685']
# Sample 3:
#   Predictive Probability Set: ['0.70980', '0.29006']
#   Real Probability Set      : ['0.11829', '0.88142']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.57742']
#   Real Probability Set      : ['0.18589']
# Sample 2:
#   Predictive Probability Set: ['0.53750']
#   Real Probability Set      : ['0.18530']
# Sample 3:
#   Predictive Probability Set: ['0.53617']
#   Real Probability Set      : ['0.16944']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.05, k_reg=1, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8103 ± 0.0032
# Final Average Prediction Set Size: 0.84 ± 0.00
# Final Average Coverage: 0.7957 ± 0.0044
# Final Average Real Probability: 0.7096 ± 0.0042
# 18425 (36.85%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.05, k_reg=1, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8103 ± 0.0032
# Final Average Prediction Set Size: 0.84 ± 0.00
# Final Average Coverage: 0.7957 ± 0.0044
# Final Average Real Probability: 0.7096 ± 0.0042
# Peak Conditional Coverage = 1.000, with 15991 samples
#
# === Count Regions Summary ===
# 31646 (63.3%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 56 (0.1%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 9385 (18.8%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99991']
# Sample 2:
#   Predictive Probability Set: ['0.99672']
#   Real Probability Set      : ['0.94672']
# Sample 3:
#   Predictive Probability Set: ['0.99969']
#   Real Probability Set      : ['0.96939']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.66227']
#   Real Probability Set      : ['0.02444']
# Sample 2:
#   Predictive Probability Set: ['0.67223']
#   Real Probability Set      : ['0.09479']
# Sample 3:
#   Predictive Probability Set: ['0.98712']
#   Real Probability Set      : ['0.05504']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.63337', '0.19734']
#   Real Probability Set      : ['0.09873', '0.30744']
# Sample 2:
#   Predictive Probability Set: ['0.72573', '0.09846']
#   Real Probability Set      : ['0.24116', '0.54328']
# Sample 3:
#   Predictive Probability Set: ['0.44928', '0.37472']
#   Real Probability Set      : ['0.04071', '0.68152']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.70836', '0.09570']
#   Real Probability Set      : ['0.11321', '0.87387']
# Sample 2:
#   Predictive Probability Set: ['0.66360', '0.33635']
#   Real Probability Set      : ['0.04289', '0.95711']
# Sample 3:
#   Predictive Probability Set: ['0.53037', '0.19862']
#   Real Probability Set      : ['0.02019', '0.87335']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.48965']
#   Real Probability Set      : ['0.14988']
# Sample 2:
#   Predictive Probability Set: ['0.57742']
#   Real Probability Set      : ['0.18589']
# Sample 3:
#   Predictive Probability Set: ['0.56461']
#   Real Probability Set      : ['0.19941']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=5.0, num_runs=10, alpha=0.2, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8139 ± 0.0047
# Final Average Prediction Set Size: 0.83 ± 0.01
# Final Average Coverage: 0.7966 ± 0.0070
# Final Average Real Probability: 0.7097 ± 0.0059
# 18526 (37.05%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=5.0, num_runs=10, alpha=0.2)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8139 ± 0.0047
# Final Average Prediction Set Size: 0.83 ± 0.01
# Final Average Coverage: 0.7966 ± 0.0070
# Final Average Real Probability: 0.7097 ± 0.0059
# Peak Conditional Coverage = 0.998, with 17081 samples
#
# === Count Regions Summary ===
# 31674 (63.3%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 3 (0.0%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 9726 (19.5%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99981']
#   Real Probability Set      : ['0.94745']
# Sample 2:
#   Predictive Probability Set: ['0.99871']
#   Real Probability Set      : ['0.94143']
# Sample 3:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99999']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99456']
#   Real Probability Set      : ['0.16190']
# Sample 2:
#   Predictive Probability Set: ['0.85157']
#   Real Probability Set      : ['0.11390']
# Sample 3:
#   Predictive Probability Set: ['0.96875']
#   Real Probability Set      : ['0.10291']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.44928', '0.37472']
#   Real Probability Set      : ['0.04071', '0.68152']
# Sample 2:
#   Predictive Probability Set: ['0.78762', '0.07940']
#   Real Probability Set      : ['0.22206', '0.43780']
# Sample 3:
#   Predictive Probability Set: ['0.44928', '0.37472']
#   Real Probability Set      : ['0.04071', '0.68152']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.56130', '0.36474']
#   Real Probability Set      : ['0.03976', '0.95649']
# Sample 2:
#   Predictive Probability Set: ['0.71276', '0.22879']
#   Real Probability Set      : ['0.03569', '0.92979']
# Sample 3:
#   Predictive Probability Set: ['0.56130', '0.36474']
#   Real Probability Set      : ['0.03976', '0.95649']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.57742']
#   Real Probability Set      : ['0.18589']
# Sample 2:
#   Predictive Probability Set: ['0.50273']
#   Real Probability Set      : ['0.13757']
# Sample 3:
#   Predictive Probability Set: ['0.40165']
#   Real Probability Set      : ['0.10511']
