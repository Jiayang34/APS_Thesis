# %% [markdown]
# # Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=5)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_5class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_5class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8990 ± 0.0033
# Final Average Prediction Set Size: 2.60 ± 0.04
# Final Average Coverage: 0.8976 ± 0.0060
# Final Average Real Probability: 0.8989 ± 0.0034
# 4762 (9.52%) samples reached the peak conditional coverage at 0.9050

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.05, k_reg=2, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9482 ± 0.0048
# Final Average Prediction Set Size: 2.57 ± 0.03
# Final Average Coverage: 0.8961 ± 0.0055
# Final Average Real Probability: 0.8967 ± 0.0029
# 4191 (8.38%) samples reached the peak conditional coverage at 0.9044

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.25, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9806 ± 0.0064
# Final Average Prediction Set Size: 2.57 ± 0.03
# Final Average Coverage: 0.8959 ± 0.0054
# Final Average Real Probability: 0.8975 ± 0.0024
# 3078 (6.16%) samples reached the peak conditional coverage at 0.9448

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8849 ± 0.0030
# Final Average Prediction Set Size: 2.15 ± 0.03
# Final Average Coverage: 0.8984 ± 0.0048
# Final Average Real Probability: 0.7736 ± 0.0056
# 1624 (3.25%) samples reached the peak conditional coverage at 0.9050

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8849 ± 0.0030
# Final Average Prediction Set Size: 2.15 ± 0.03
# Final Average Coverage: 0.8984 ± 0.0048
# Final Average Real Probability: 0.7736 ± 0.0056
# Peak Conditional Coverage = 0.921, with 1668 samples
#
# === Count Regions Summary ===
# 27399 (54.8%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 201 (0.4%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 21382 (42.8%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.69656', '0.18116']
#   Real Probability Set      : ['0.74381', '0.15758']
# Sample 2:
#   Predictive Probability Set: ['0.95349']
#   Real Probability Set      : ['0.88566']
# Sample 3:
#   Predictive Probability Set: ['0.88524']
#   Real Probability Set      : ['0.85260']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.93999']
#   Real Probability Set      : ['0.13105']
# Sample 2:
#   Predictive Probability Set: ['0.83186']
#   Real Probability Set      : ['0.15587']
# Sample 3:
#   Predictive Probability Set: ['0.73034']
#   Real Probability Set      : ['0.06650']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.63560', '0.12659', '0.11018']
#   Real Probability Set      : ['0.25942', '0.29530', '0.23882']
# Sample 2:
#   Predictive Probability Set: ['0.78102', '0.09513']
#   Real Probability Set      : ['0.23179', '0.46641']
# Sample 3:
#   Predictive Probability Set: ['0.65357', '0.13769', '0.09001']
#   Real Probability Set      : ['0.20479', '0.39364', '0.04507']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.35346', '0.27261', '0.15887', '0.14278']
#   Real Probability Set      : ['0.06627', '0.81460', '0.01962', '0.07876']
# Sample 2:
#   Predictive Probability Set: ['0.76056', '0.23102']
#   Real Probability Set      : ['0.18782', '0.70103']
# Sample 3:
#   Predictive Probability Set: ['0.76056', '0.23102']
#   Real Probability Set      : ['0.18782', '0.70103']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.47773']
#   Real Probability Set      : ['0.18738']
# Sample 2:
#   Predictive Probability Set: ['0.53757']
#   Real Probability Set      : ['0.18973']
# Sample 3:
#   Predictive Probability Set: ['0.53757']
#   Real Probability Set      : ['0.18973']

# %%
raps_synthetic_data_hist(model, dataset, device, lambda_=0.03, k_reg=2, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9029 ± 0.0032
# Final Average Prediction Set Size: 2.09 ± 0.02
# Final Average Coverage: 0.8987 ± 0.0046
# Final Average Real Probability: 0.7717 ± 0.0043
# 1682 (3.36%) samples reached the peak conditional coverage at 0.8642

# %%
raps_synthetic_data_scatter(model, dataset, device, lambda_=0.03, k_reg=2, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9029 ± 0.0032
# Final Average Prediction Set Size: 2.09 ± 0.02
# Final Average Coverage: 0.8987 ± 0.0046
# Final Average Real Probability: 0.7717 ± 0.0043
# Peak Conditional Coverage = 0.871, with 1655 samples
#
# === Count Regions Summary ===
# 26445 (52.9%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 183 (0.4%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 22637 (45.3%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.96927']
#   Real Probability Set      : ['0.87072']
# Sample 2:
#   Predictive Probability Set: ['0.94974']
#   Real Probability Set      : ['0.87312']
# Sample 3:
#   Predictive Probability Set: ['0.44682', '0.28110', '0.12437']
#   Real Probability Set      : ['0.53602', '0.33148', '0.10119']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.84580', '0.06581']
#   Real Probability Set      : ['0.09511', '0.05464']
# Sample 2:
#   Predictive Probability Set: ['0.86154']
#   Real Probability Set      : ['0.16802']
# Sample 3:
#   Predictive Probability Set: ['0.90789']
#   Real Probability Set      : ['0.12394']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.80939', '0.09838']
#   Real Probability Set      : ['0.36755', '0.28888']
# Sample 2:
#   Predictive Probability Set: ['0.63722', '0.16043', '0.12403']
#   Real Probability Set      : ['0.16787', '0.11025', '0.45012']
# Sample 3:
#   Predictive Probability Set: ['0.55391', '0.14442', '0.11189', '0.10711']
#   Real Probability Set      : ['0.12442', '0.52430', '0.02973', '0.06002']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.67151', '0.20897']
#   Real Probability Set      : ['0.15989', '0.70692']
# Sample 2:
#   Predictive Probability Set: ['0.81146', '0.17973']
#   Real Probability Set      : ['0.20496', '0.78456']
# Sample 3:
#   Predictive Probability Set: ['0.77889', '0.21857']
#   Real Probability Set      : ['0.10128', '0.88589']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.51282']
#   Real Probability Set      : ['0.18810']
# Sample 2:
#   Predictive Probability Set: ['0.53757']
#   Real Probability Set      : ['0.18973']
# Sample 3:
#   Predictive Probability Set: ['0.53757']
#   Real Probability Set      : ['0.18973']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.3, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9909 ± 0.0094
# Final Average Prediction Set Size: 1.99 ± 0.04
# Final Average Coverage: 0.8988 ± 0.0052
# Final Average Real Probability: 0.7655 ± 0.0060
# 1565 (3.13%) samples reached the peak conditional coverage at 0.8642

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.3, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9909 ± 0.0094
# Final Average Prediction Set Size: 1.99 ± 0.04
# Final Average Coverage: 0.8988 ± 0.0052
# Final Average Real Probability: 0.7655 ± 0.0060
# Peak Conditional Coverage = 0.869, with 1612 samples
#
# === Count Regions Summary ===
# 24663 (49.3%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 159 (0.3%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 25126 (50.3%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99297']
#   Real Probability Set      : ['0.84322']
# Sample 2:
#   Predictive Probability Set: ['0.77348', '0.07341']
#   Real Probability Set      : ['0.76427', '0.05508']
# Sample 3:
#   Predictive Probability Set: ['0.98098']
#   Real Probability Set      : ['0.89861']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.87924']
#   Real Probability Set      : ['0.19192']
# Sample 2:
#   Predictive Probability Set: ['0.82429']
#   Real Probability Set      : ['0.17946']
# Sample 3:
#   Predictive Probability Set: ['0.84580', '0.06581']
#   Real Probability Set      : ['0.09511', '0.05464']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.69486', '0.14143']
#   Real Probability Set      : ['0.15709', '0.45424']
# Sample 2:
#   Predictive Probability Set: ['0.57175', '0.16010']
#   Real Probability Set      : ['0.27359', '0.46734']
# Sample 3:
#   Predictive Probability Set: ['0.83637', '0.11871']
#   Real Probability Set      : ['0.40234', '0.29236']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.64463', '0.14494']
#   Real Probability Set      : ['0.16577', '0.68139']
# Sample 2:
#   Predictive Probability Set: ['0.86353', '0.10723']
#   Real Probability Set      : ['0.24918', '0.65614']
# Sample 3:
#   Predictive Probability Set: ['0.70202', '0.25546']
#   Real Probability Set      : ['0.15986', '0.80074']
#
# --- Region 5: low TVD, low Coverage ---
# No points are found in this region.
