# %% [markdown]
# # Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=5)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_5class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_5class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8990 ± 0.0033
# Final Average Prediction Set Size: 2.60 ± 0.04
# Final Average Coverage: 0.8976 ± 0.0060
# Final Average Real Probability: 0.8989 ± 0.0034
# 4762 (9.52%) samples reached the peak conditional coverage at 0.9050

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.05, k_reg=2, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9482 ± 0.0048
# Final Average Prediction Set Size: 2.57 ± 0.03
# Final Average Coverage: 0.8961 ± 0.0055
# Final Average Real Probability: 0.8967 ± 0.0029
# 4191 (8.38%) samples reached the peak conditional coverage at 0.9044

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.25, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9806 ± 0.0064
# Final Average Prediction Set Size: 2.57 ± 0.03
# Final Average Coverage: 0.8959 ± 0.0054
# Final Average Real Probability: 0.8975 ± 0.0024
# 3078 (6.16%) samples reached the peak conditional coverage at 0.9448

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8849 ± 0.0030
# Final Average Prediction Set Size: 2.15 ± 0.03
# Final Average Coverage: 0.8984 ± 0.0048
# Final Average Real Probability: 0.7736 ± 0.0056
# 1624 (3.25%) samples reached the peak conditional coverage at 0.9050

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8849 ± 0.0030
# Final Average Prediction Set Size: 2.15 ± 0.03
# Final Average Coverage: 0.8984 ± 0.0048
# Final Average Real Probability: 0.7736 ± 0.0056
# Peak Conditional Coverage = 0.921, with 1668 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.93773']
#   Real Probability Set      : ['0.82030']
# Sample 2:
#   Predictive Probability Set: ['0.99551']
#   Real Probability Set      : ['0.89993']
# Sample 3:
#   Predictive Probability Set: ['0.94842']
#   Real Probability Set      : ['0.80745']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.81063']
#   Real Probability Set      : ['0.19122']
# Sample 2:
#   Predictive Probability Set: ['0.73124']
#   Real Probability Set      : ['0.09606']
# Sample 3:
#   Predictive Probability Set: ['0.86722']
#   Real Probability Set      : ['0.17519']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.81802', '0.06967']
#   Real Probability Set      : ['0.41621', '0.31703']
# Sample 2:
#   Predictive Probability Set: ['0.69286', '0.17272']
#   Real Probability Set      : ['0.30142', '0.46792']
# Sample 3:
#   Predictive Probability Set: ['0.83780', '0.06339']
#   Real Probability Set      : ['0.42220', '0.34225']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.78818', '0.21114']
#   Real Probability Set      : ['0.15190', '0.84700']
# Sample 2:
#   Predictive Probability Set: ['0.83750', '0.12972']
#   Real Probability Set      : ['0.13411', '0.78295']
# Sample 3:
#   Predictive Probability Set: ['0.69278', '0.09019', '0.08297', '0.06988']
#   Real Probability Set      : ['0.14044', '0.27768', '0.35739', '0.18272']

# %%
raps_synthetic_data_hist(model, dataset, device, lambda_=0.03, k_reg=2, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9029 ± 0.0032
# Final Average Prediction Set Size: 2.09 ± 0.02
# Final Average Coverage: 0.8987 ± 0.0046
# Final Average Real Probability: 0.7717 ± 0.0043
# 1682 (3.36%) samples reached the peak conditional coverage at 0.8642

# %%
raps_synthetic_data_scatter(model, dataset, device, lambda_=0.03, k_reg=2, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9029 ± 0.0032
# Final Average Prediction Set Size: 2.09 ± 0.02
# Final Average Coverage: 0.8987 ± 0.0046
# Final Average Real Probability: 0.7717 ± 0.0043
# Peak Conditional Coverage = 0.871, with 1655 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99769']
#   Real Probability Set      : ['0.80648']
# Sample 2:
#   Predictive Probability Set: ['0.72022', '0.15921']
#   Real Probability Set      : ['0.75384', '0.14117']
# Sample 3:
#   Predictive Probability Set: ['0.48110', '0.44450']
#   Real Probability Set      : ['0.52483', '0.34706']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.73156', '0.08437']
#   Real Probability Set      : ['0.18125', '0.00787']
# Sample 2:
#   Predictive Probability Set: ['0.93999']
#   Real Probability Set      : ['0.13105']
# Sample 3:
#   Predictive Probability Set: ['0.79869']
#   Real Probability Set      : ['0.19838']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.75042', '0.15693']
#   Real Probability Set      : ['0.35459', '0.43550']
# Sample 2:
#   Predictive Probability Set: ['0.67389', '0.16838']
#   Real Probability Set      : ['0.22462', '0.34062']
# Sample 3:
#   Predictive Probability Set: ['0.68197', '0.16691', '0.05617']
#   Real Probability Set      : ['0.34191', '0.39724', '0.02315']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.82429', '0.16258']
#   Real Probability Set      : ['0.17946', '0.65784']
# Sample 2:
#   Predictive Probability Set: ['0.82429', '0.16258']
#   Real Probability Set      : ['0.17946', '0.65784']
# Sample 3:
#   Predictive Probability Set: ['0.64463', '0.14494', '0.09336']
#   Real Probability Set      : ['0.16577', '0.68139', '0.09162']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.2, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9055 ± 0.0056
# Final Average Prediction Set Size: 2.10 ± 0.03
# Final Average Coverage: 0.8993 ± 0.0048
# Final Average Real Probability: 0.7698 ± 0.0052
# 1567 (3.13%) samples reached the peak conditional coverage at 0.9250

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.2, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9055 ± 0.0056
# Final Average Prediction Set Size: 2.10 ± 0.03
# Final Average Coverage: 0.8993 ± 0.0048
# Final Average Real Probability: 0.7698 ± 0.0052
# Peak Conditional Coverage = 0.959, with 1538 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.98688']
#   Real Probability Set      : ['0.90179']
# Sample 2:
#   Predictive Probability Set: ['0.99922']
#   Real Probability Set      : ['0.90434']
# Sample 3:
#   Predictive Probability Set: ['0.87666']
#   Real Probability Set      : ['0.91669']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.93676']
#   Real Probability Set      : ['0.17077']
# Sample 2:
#   Predictive Probability Set: ['0.81063']
#   Real Probability Set      : ['0.19122']
# Sample 3:
#   Predictive Probability Set: ['0.89475']
#   Real Probability Set      : ['0.14378']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.77381', '0.07877']
#   Real Probability Set      : ['0.24268', '0.17171']
# Sample 2:
#   Predictive Probability Set: ['0.72034', '0.21769']
#   Real Probability Set      : ['0.11380', '0.48722']
# Sample 3:
#   Predictive Probability Set: ['0.73593', '0.10449']
#   Real Probability Set      : ['0.23959', '0.31394']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.59937', '0.33243']
#   Real Probability Set      : ['0.08781', '0.82348']
# Sample 2:
#   Predictive Probability Set: ['0.76079', '0.17032']
#   Real Probability Set      : ['0.18896', '0.66788']
# Sample 3:
#   Predictive Probability Set: ['0.67723', '0.18553']
#   Real Probability Set      : ['0.19646', '0.78632']
