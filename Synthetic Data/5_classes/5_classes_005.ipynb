# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=5)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_5class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_5class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9496 ± 0.0026
# Final Average Prediction Set Size: 3.19 ± 0.04
# Final Average Coverage: 0.9485 ± 0.0051
# Final Average Real Probability: 0.9496 ± 0.0027
# 8050 (16.10%) samples reached the peak conditional coverage at 0.9550

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_= 0.01, k_reg=5, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9496 ± 0.0026
# Final Average Prediction Set Size: 3.19 ± 0.04
# Final Average Coverage: 0.9485 ± 0.0051
# Final Average Real Probability: 0.9496 ± 0.0027
# 8050 (16.10%) samples reached the peak conditional coverage at 0.9550

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.2, num_runs=10, alpha=0.05)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.0402 ± 0.0103
# Final Average Prediction Set Size: 3.27 ± 0.06
# Final Average Coverage: 0.9481 ± 0.0048
# Final Average Real Probability: 0.9499 ± 0.0029
# 4708 (9.42%) samples reached the peak conditional coverage at 0.9988

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model, dataset, device, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9448 ± 0.0022
# Final Average Prediction Set Size: 2.77 ± 0.04
# Final Average Coverage: 0.9492 ± 0.0045
# Final Average Real Probability: 0.8624 ± 0.0043
# 4793 (9.59%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model, dataset, device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9448 ± 0.0022
# Final Average Prediction Set Size: 2.77 ± 0.04
# Final Average Coverage: 0.9492 ± 0.0045
# Final Average Real Probability: 0.8624 ± 0.0043
# Peak Conditional Coverage = 1.005, with 3129 samples
#
# === Count Regions Summary ===
# 36511 (73.0%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 520 (1.0%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 11272 (22.5%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.62040', '0.24825', '0.05692']
#   Real Probability Set      : ['0.56526', '0.21295', '0.03581']
# Sample 2:
#   Predictive Probability Set: ['0.78697', '0.11899']
#   Real Probability Set      : ['0.70569', '0.13939']
# Sample 3:
#   Predictive Probability Set: ['0.99463']
#   Real Probability Set      : ['0.91063']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.90789']
#   Real Probability Set      : ['0.12394']
# Sample 2:
#   Predictive Probability Set: ['0.86154']
#   Real Probability Set      : ['0.16802']
# Sample 3:
#   Predictive Probability Set: ['0.62909']
#   Real Probability Set      : ['0.13125']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.54214', '0.27125', '0.09265']
#   Real Probability Set      : ['0.15181', '0.19774', '0.24244']
# Sample 2:
#   Predictive Probability Set: ['0.72541', '0.18772']
#   Real Probability Set      : ['0.10654', '0.41646']
# Sample 3:
#   Predictive Probability Set: ['0.85059', '0.07225', '0.03588']
#   Real Probability Set      : ['0.43135', '0.01961', '0.31527']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.27276', '0.21964', '0.20868', '0.17500']
#   Real Probability Set      : ['0.83796', '0.02880', '0.06522', '0.02698']
# Sample 2:
#   Predictive Probability Set: ['0.88319', '0.03795', '0.03516']
#   Real Probability Set      : ['0.35480', '0.53637', '0.06496']
# Sample 3:
#   Predictive Probability Set: ['0.37022', '0.24053', '0.18845', '0.10776']
#   Real Probability Set      : ['0.08758', '0.09499', '0.73963', '0.04688']
#
# --- Region 5: low TVD, low Coverage ---
# No points are found in this region.

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_= 0.01, k_reg=3, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9499 ± 0.0024
# Final Average Prediction Set Size: 2.76 ± 0.04
# Final Average Coverage: 0.9493 ± 0.0043
# Final Average Real Probability: 0.8634 ± 0.0048
# 3287 (6.57%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_= 0.01, k_reg=3, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9499 ± 0.0024
# Final Average Prediction Set Size: 2.76 ± 0.04
# Final Average Coverage: 0.9493 ± 0.0043
# Final Average Real Probability: 0.8634 ± 0.0048
# Peak Conditional Coverage = 0.975, with 2677 samples
#
# === Count Regions Summary ===
# 37566 (75.1%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 558 (1.1%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 10889 (21.8%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.50906', '0.15083', '0.14391', '0.10994']
#   Real Probability Set      : ['0.55931', '0.13330', '0.12682', '0.10686']
# Sample 2:
#   Predictive Probability Set: ['0.99116']
#   Real Probability Set      : ['0.87324']
# Sample 3:
#   Predictive Probability Set: ['0.92901', '0.03745']
#   Real Probability Set      : ['0.87543', '0.01267']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.76056']
#   Real Probability Set      : ['0.18782']
# Sample 2:
#   Predictive Probability Set: ['0.93676']
#   Real Probability Set      : ['0.17077']
# Sample 3:
#   Predictive Probability Set: ['0.63132']
#   Real Probability Set      : ['0.16581']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.76904', '0.17206']
#   Real Probability Set      : ['0.10283', '0.39351']
# Sample 2:
#   Predictive Probability Set: ['0.73086', '0.10510', '0.08409']
#   Real Probability Set      : ['0.29043', '0.14098', '0.35336']
# Sample 3:
#   Predictive Probability Set: ['0.75571', '0.14906', '0.04746']
#   Real Probability Set      : ['0.18629', '0.45670', '0.13275']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.72541', '0.18772', '0.03875']
#   Real Probability Set      : ['0.10654', '0.41646', '0.44504']
# Sample 2:
#   Predictive Probability Set: ['0.76079', '0.17032', '0.03061']
#   Real Probability Set      : ['0.18896', '0.66788', '0.03169']
# Sample 3:
#   Predictive Probability Set: ['0.60732', '0.14454', '0.14256', '0.06566']
#   Real Probability Set      : ['0.06015', '0.49138', '0.30726', '0.12089']
#
# --- Region 5: low TVD, low Coverage ---
# No points are found in this region.

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.2, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.0361 ± 0.0067
# Final Average Prediction Set Size: 2.71 ± 0.04
# Final Average Coverage: 0.9495 ± 0.0032
# Final Average Real Probability: 0.8540 ± 0.0038
# 4415 (8.83%) samples reached the peak conditional coverage at 0.9955

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.2, num_runs=10, alpha=0.05)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.0361 ± 0.0067
# Final Average Prediction Set Size: 2.71 ± 0.04
# Final Average Coverage: 0.9495 ± 0.0032
# Final Average Real Probability: 0.8540 ± 0.0038
# Peak Conditional Coverage = 1.005, with 2639 samples
#
# === Count Regions Summary ===
# 34842 (69.7%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 369 (0.7%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 13561 (27.1%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.34686', '0.24069', '0.14978', '0.14679', '0.11588']
#   Real Probability Set      : ['0.34146', '0.17578', '0.15225', '0.23374', '0.09677']
# Sample 2:
#   Predictive Probability Set: ['0.51267', '0.13714', '0.13431']
#   Real Probability Set      : ['0.59531', '0.10338', '0.12694']
# Sample 3:
#   Predictive Probability Set: ['0.74811', '0.19883']
#   Real Probability Set      : ['0.79578', '0.15992']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.97735']
#   Real Probability Set      : ['0.10633']
# Sample 2:
#   Predictive Probability Set: ['0.62224', '0.11789', '0.10732']
#   Real Probability Set      : ['0.06786', '0.00627', '0.11995']
# Sample 3:
#   Predictive Probability Set: ['0.79040', '0.06553']
#   Real Probability Set      : ['0.12854', '0.07131']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.79740', '0.07338']
#   Real Probability Set      : ['0.31059', '0.23612']
# Sample 2:
#   Predictive Probability Set: ['0.92600', '0.03553']
#   Real Probability Set      : ['0.33643', '0.21080']
# Sample 3:
#   Predictive Probability Set: ['0.86109', '0.09057']
#   Real Probability Set      : ['0.34800', '0.41858']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.89923', '0.06696']
#   Real Probability Set      : ['0.35835', '0.56579']
# Sample 2:
#   Predictive Probability Set: ['0.59937', '0.33243', '0.04342']
#   Real Probability Set      : ['0.08781', '0.82348', '0.08295']
# Sample 3:
#   Predictive Probability Set: ['0.43502', '0.31892', '0.08779', '0.08708']
#   Real Probability Set      : ['0.08818', '0.23750', '0.64171', '0.01664']
#
# --- Region 5: low TVD, low Coverage ---
# No points are found in this region.
