# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=5)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_5class_NoTemp_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_5class_NoTemp_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9476 ± 0.0025
# Final Average Prediction Set Size: 1.30 ± 0.01
# Final Average Coverage: 0.9450 ± 0.0050
# Final Average Real Probability: 0.9459 ± 0.0040
# 29045 (58.09%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_= 0.05, k_reg=2, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9517 ± 0.0024
# Final Average Prediction Set Size: 1.28 ± 0.01
# Final Average Coverage: 0.9451 ± 0.0049
# Final Average Real Probability: 0.9469 ± 0.0036
# 28680 (57.36%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.3, num_runs=10, alpha=0.05)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9624 ± 0.0032
# Final Average Prediction Set Size: 1.25 ± 0.01
# Final Average Coverage: 0.9496 ± 0.0044
# Final Average Real Probability: 0.9501 ± 0.0036
# 28063 (56.13%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9595 ± 0.0022
# Final Average Prediction Set Size: 1.07 ± 0.01
# Final Average Coverage: 0.9475 ± 0.0052
# Final Average Real Probability: 0.8624 ± 0.0051
# 23415 (46.83%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.05)
# Out:
# APS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9595 ± 0.0022
# Final Average Prediction Set Size: 1.07 ± 0.01
# Final Average Coverage: 0.9475 ± 0.0052
# Final Average Real Probability: 0.8624 ± 0.0051
# Peak Conditional Coverage = 1.000, with 20285 samples
#
# === Count Regions Summary ===
# 38840 (77.7%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 889 (1.8%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 8363 (16.7%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['1.00000']
# Sample 2:
#   Predictive Probability Set: ['0.99994']
#   Real Probability Set      : ['0.97651']
# Sample 3:
#   Predictive Probability Set: ['0.99960']
#   Real Probability Set      : ['0.98436']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.98849']
#   Real Probability Set      : ['0.08506']
# Sample 2:
#   Predictive Probability Set: ['0.99997']
#   Real Probability Set      : ['0.02246']
# Sample 3:
#   Predictive Probability Set: ['0.98788']
#   Real Probability Set      : ['0.10479']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.89693', '0.08990']
#   Real Probability Set      : ['0.33484', '0.31244']
# Sample 2:
#   Predictive Probability Set: ['0.68335', '0.22618', '0.05556']
#   Real Probability Set      : ['0.10404', '0.29649', '0.06064']
# Sample 3:
#   Predictive Probability Set: ['0.50385', '0.26509', '0.19222']
#   Real Probability Set      : ['0.10121', '0.56568', '0.08548']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.77494', '0.22302']
#   Real Probability Set      : ['0.14707', '0.84548']
# Sample 2:
#   Predictive Probability Set: ['0.81779', '0.12816', '0.03104']
#   Real Probability Set      : ['0.17768', '0.66822', '0.07805']
# Sample 3:
#   Predictive Probability Set: ['0.94450', '0.03642']
#   Real Probability Set      : ['0.35827', '0.52914']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.53750']
#   Real Probability Set      : ['0.18530']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_= 0.05, k_reg=2, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9612 ± 0.0021
# Final Average Prediction Set Size: 1.05 ± 0.01
# Final Average Coverage: 0.9480 ± 0.0056
# Final Average Real Probability: 0.8619 ± 0.0052
# 23011 (46.02%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_= 0.05, k_reg=2, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9612 ± 0.0021
# Final Average Prediction Set Size: 1.05 ± 0.01
# Final Average Coverage: 0.9480 ± 0.0056
# Final Average Real Probability: 0.8619 ± 0.0052
# Peak Conditional Coverage = 1.000, with 19903 samples
#
# === Count Regions Summary ===
# 38834 (77.7%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 787 (1.6%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 8558 (17.1%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99560']
# Sample 2:
#   Predictive Probability Set: ['0.99671']
#   Real Probability Set      : ['0.91718']
# Sample 3:
#   Predictive Probability Set: ['0.99998']
#   Real Probability Set      : ['0.95096']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99540']
#   Real Probability Set      : ['0.11857']
# Sample 2:
#   Predictive Probability Set: ['0.93013']
#   Real Probability Set      : ['0.05629']
# Sample 3:
#   Predictive Probability Set: ['0.93013']
#   Real Probability Set      : ['0.05629']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.57077', '0.26159']
#   Real Probability Set      : ['0.14925', '0.47766']
# Sample 2:
#   Predictive Probability Set: ['0.94383', '0.03604']
#   Real Probability Set      : ['0.25653', '0.23968']
# Sample 3:
#   Predictive Probability Set: ['0.80653', '0.09019']
#   Real Probability Set      : ['0.40269', '0.36814']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.87423', '0.12554']
#   Real Probability Set      : ['0.20559', '0.79204']
# Sample 2:
#   Predictive Probability Set: ['0.92856', '0.06404']
#   Real Probability Set      : ['0.38059', '0.60966']
# Sample 3:
#   Predictive Probability Set: ['0.88839', '0.10933']
#   Real Probability Set      : ['0.33004', '0.66736']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.53750']
#   Real Probability Set      : ['0.18530']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.3, num_runs=10, alpha=0.05, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9642 ± 0.0024
# Final Average Prediction Set Size: 1.02 ± 0.00
# Final Average Coverage: 0.9484 ± 0.0038
# Final Average Real Probability: 0.8547 ± 0.0041
# 22720 (45.44%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.3, num_runs=10, alpha=0.05)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9642 ± 0.0024
# Final Average Prediction Set Size: 1.02 ± 0.00
# Final Average Coverage: 0.9484 ± 0.0038
# Final Average Real Probability: 0.8547 ± 0.0041
# Peak Conditional Coverage = 1.000, with 19723 samples
#
# === Count Regions Summary ===
# 38454 (76.9%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 391 (0.8%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 9556 (19.1%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.98631']
#   Real Probability Set      : ['0.82963']
# Sample 2:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99999']
# Sample 3:
#   Predictive Probability Set: ['0.99999']
#   Real Probability Set      : ['0.87885']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99548']
#   Real Probability Set      : ['0.17085']
# Sample 2:
#   Predictive Probability Set: ['0.99972']
#   Real Probability Set      : ['0.07370']
# Sample 3:
#   Predictive Probability Set: ['0.98712']
#   Real Probability Set      : ['0.05504']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.76774', '0.12993']
#   Real Probability Set      : ['0.19425', '0.51242']
# Sample 2:
#   Predictive Probability Set: ['0.72573', '0.09846']
#   Real Probability Set      : ['0.24116', '0.54328']
# Sample 3:
#   Predictive Probability Set: ['0.68335', '0.22618']
#   Real Probability Set      : ['0.10404', '0.29649']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.70714', '0.29045']
#   Real Probability Set      : ['0.07785', '0.92015']
# Sample 2:
#   Predictive Probability Set: ['0.63724', '0.35589']
#   Real Probability Set      : ['0.09904', '0.88399']
# Sample 3:
#   Predictive Probability Set: ['0.79648', '0.20062']
#   Real Probability Set      : ['0.05321', '0.94113']
#
# --- Region 5: low TVD, low Coverage ---
# No points are found in this region.
