# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=5)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_5class_NoTemp_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_5class_NoTemp_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8985 ± 0.0030
# Final Average Prediction Set Size: 1.15 ± 0.01
# Final Average Coverage: 0.8955 ± 0.0057
# Final Average Real Probability: 0.8964 ± 0.0039
# 24620 (49.24%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=2, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9007 ± 0.0028
# Final Average Prediction Set Size: 1.14 ± 0.01
# Final Average Coverage: 0.8953 ± 0.0062
# Final Average Real Probability: 0.8961 ± 0.0039
# 24407 (48.81%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.35, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9066 ± 0.0047
# Final Average Prediction Set Size: 1.12 ± 0.01
# Final Average Coverage: 0.8988 ± 0.0055
# Final Average Real Probability: 0.8985 ± 0.0044
# 24342 (48.68%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9089 ± 0.0025
# Final Average Prediction Set Size: 0.98 ± 0.01
# Final Average Coverage: 0.8953 ± 0.0048
# Final Average Real Probability: 0.8069 ± 0.0049
# 21278 (42.56%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9089 ± 0.0025
# Final Average Prediction Set Size: 0.98 ± 0.01
# Final Average Coverage: 0.8953 ± 0.0048
# Final Average Real Probability: 0.8069 ± 0.0049
# Peak Conditional Coverage = 1.000, with 18450 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.98710']
# Sample 2:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.97296']
# Sample 3:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99978']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99358']
#   Real Probability Set      : ['0.15580']
# Sample 2:
#   Predictive Probability Set: ['0.94345']
#   Real Probability Set      : ['0.13322']
# Sample 3:
#   Predictive Probability Set: ['0.98788']
#   Real Probability Set      : ['0.10479']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.76774', '0.12993']
#   Real Probability Set      : ['0.19425', '0.51242']
# Sample 2:
#   Predictive Probability Set: ['0.87810', '0.11702']
#   Real Probability Set      : ['0.27139', '0.49618']
# Sample 3:
#   Predictive Probability Set: ['0.77515', '0.09819', '0.06510']
#   Real Probability Set      : ['0.33623', '0.28126', '0.12678']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.55520', '0.15160', '0.11458', '0.09417']
#   Real Probability Set      : ['0.07845', '0.65810', '0.12702', '0.13378']
# Sample 2:
#   Predictive Probability Set: ['0.81621', '0.08346', '0.04908']
#   Real Probability Set      : ['0.05946', '0.34064', '0.46502']
# Sample 3:
#   Predictive Probability Set: ['0.71919', '0.14089', '0.06727']
#   Real Probability Set      : ['0.03941', '0.11990', '0.80974']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=1, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9150 ± 0.0029
# Final Average Prediction Set Size: 0.95 ± 0.01
# Final Average Coverage: 0.8953 ± 0.0042
# Final Average Real Probability: 0.8008 ± 0.0052
# 20901 (41.80%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.1, k_reg=1, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9150 ± 0.0029
# Final Average Prediction Set Size: 0.95 ± 0.01
# Final Average Coverage: 0.8953 ± 0.0042
# Final Average Real Probability: 0.8008 ± 0.0052
# Peak Conditional Coverage = 1.000, with 18155 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['1.00000']
# Sample 2:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99632']
# Sample 3:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.98652']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.96686']
#   Real Probability Set      : ['0.16424']
# Sample 2:
#   Predictive Probability Set: ['0.94163']
#   Real Probability Set      : ['0.12155']
# Sample 3:
#   Predictive Probability Set: ['0.97869']
#   Real Probability Set      : ['0.07701']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.72573', '0.09846']
#   Real Probability Set      : ['0.24116', '0.54328']
# Sample 2:
#   Predictive Probability Set: ['0.78012', '0.21970']
#   Real Probability Set      : ['0.15547', '0.39769']
# Sample 3:
#   Predictive Probability Set: ['0.72573', '0.09846']
#   Real Probability Set      : ['0.24116', '0.54328']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.72284', '0.18004']
#   Real Probability Set      : ['0.03066', '0.89505']
# Sample 2:
#   Predictive Probability Set: ['0.67223', '0.32690']
#   Real Probability Set      : ['0.09479', '0.90092']
# Sample 3:
#   Predictive Probability Set: ['0.60981', '0.38398']
#   Real Probability Set      : ['0.06353', '0.92578']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.25, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8936 ± 0.0039
# Final Average Prediction Set Size: 0.95 ± 0.00
# Final Average Coverage: 0.8822 ± 0.0041
# Final Average Real Probability: 0.7917 ± 0.0041
# 20913 (41.83%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.25, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8936 ± 0.0039
# Final Average Prediction Set Size: 0.95 ± 0.00
# Final Average Coverage: 0.8822 ± 0.0041
# Final Average Real Probability: 0.7917 ± 0.0041
# Peak Conditional Coverage = 1.000, with 18149 samples
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.99994']
#   Real Probability Set      : ['0.99619']
# Sample 2:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99998']
# Sample 3:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99760']
#
# --- Region 2: high TVD, low coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.91020']
#   Real Probability Set      : ['0.18139']
# Sample 2:
#   Predictive Probability Set: ['0.99890']
#   Real Probability Set      : ['0.13446']
# Sample 3:
#   Predictive Probability Set: ['0.97184']
#   Real Probability Set      : ['0.11811']
#
# --- Region 3: medium TVD, medium coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.60554', '0.24370', '0.09224']
#   Real Probability Set      : ['0.33722', '0.03318', '0.38212']
# Sample 2:
#   Predictive Probability Set: ['0.50385', '0.26509', '0.19222']
#   Real Probability Set      : ['0.10121', '0.56568', '0.08548']
# Sample 3:
#   Predictive Probability Set: ['0.42088', '0.25398', '0.19686']
#   Real Probability Set      : ['0.01868', '0.34946', '0.04590']
#
# --- Region 4: high TVD, high coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.63724', '0.35589']
#   Real Probability Set      : ['0.09904', '0.88399']
# Sample 2:
#   Predictive Probability Set: ['0.70980', '0.29006']
#   Real Probability Set      : ['0.11829', '0.88142']
# Sample 3:
#   Predictive Probability Set: ['0.70230', '0.12429']
#   Real Probability Set      : ['0.23082', '0.74712']
