# %% [markdown]
# ## Ground Truth Test

# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, aps_synthetic_data_hist, raps_synthetic_data_hist, saps_synthetic_data_hist, aps_synthetic_data_scatter, raps_synthetic_data_scatter, saps_synthetic_data_scatter
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=5)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_5class_NoTemp_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_5class_NoTemp_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8985 ± 0.0030
# Final Average Prediction Set Size: 1.15 ± 0.01
# Final Average Coverage: 0.8955 ± 0.0057
# Final Average Real Probability: 0.8964 ± 0.0039
# 24620 (49.24%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=2, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9007 ± 0.0028
# Final Average Prediction Set Size: 1.14 ± 0.01
# Final Average Coverage: 0.8953 ± 0.0062
# Final Average Real Probability: 0.8961 ± 0.0039
# 24407 (48.81%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.35, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9066 ± 0.0047
# Final Average Prediction Set Size: 1.12 ± 0.01
# Final Average Coverage: 0.8988 ± 0.0055
# Final Average Real Probability: 0.8985 ± 0.0044
# 24342 (48.68%) samples reached the peak conditional coverage at 0.9950

# %% [markdown]
# ## Model Test

# %%
aps_synthetic_data_hist(model,dataset,device, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9089 ± 0.0025
# Final Average Prediction Set Size: 0.98 ± 0.01
# Final Average Coverage: 0.8953 ± 0.0048
# Final Average Real Probability: 0.8069 ± 0.0049
# 21278 (42.56%) samples reached the peak conditional coverage at 0.9950

# %%
aps_synthetic_data_scatter(model,dataset,device, num_runs=10, alpha=0.1)
# Out:
# APS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9089 ± 0.0025
# Final Average Prediction Set Size: 0.98 ± 0.01
# Final Average Coverage: 0.8953 ± 0.0048
# Final Average Real Probability: 0.8069 ± 0.0049
# Peak Conditional Coverage = 1.000, with 18450 samples
#
# === Count Regions Summary ===
# 36200 (72.4%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 458 (0.9%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 9082 (18.2%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.96945']
# Sample 2:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['1.00000']
# Sample 3:
#   Predictive Probability Set: ['0.99127']
#   Real Probability Set      : ['0.95030']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.97825']
#   Real Probability Set      : ['0.15768']
# Sample 2:
#   Predictive Probability Set: ['0.87886']
#   Real Probability Set      : ['0.02877']
# Sample 3:
#   Predictive Probability Set: ['0.99994']
#   Real Probability Set      : ['0.09778']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.80653', '0.09019']
#   Real Probability Set      : ['0.40269', '0.36814']
# Sample 2:
#   Predictive Probability Set: ['0.79127', '0.12017']
#   Real Probability Set      : ['0.17597', '0.35270']
# Sample 3:
#   Predictive Probability Set: ['0.76781', '0.11097']
#   Real Probability Set      : ['0.24022', '0.47528']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.81779', '0.12816']
#   Real Probability Set      : ['0.17768', '0.66822']
# Sample 2:
#   Predictive Probability Set: ['0.35002', '0.34254', '0.15207', '0.09033']
#   Real Probability Set      : ['0.02453', '0.04469', '0.53859', '0.39218']
# Sample 3:
#   Predictive Probability Set: ['0.56130', '0.36474']
#   Real Probability Set      : ['0.03976', '0.95649']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.53750']
#   Real Probability Set      : ['0.18530']
# Sample 2:
#   Predictive Probability Set: ['0.53617']
#   Real Probability Set      : ['0.16944']
# Sample 3:
#   Predictive Probability Set: ['0.56461']
#   Real Probability Set      : ['0.19941']

# %%
raps_synthetic_data_hist(model,dataset,device, lambda_=0.1, k_reg=1, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9150 ± 0.0029
# Final Average Prediction Set Size: 0.95 ± 0.01
# Final Average Coverage: 0.8953 ± 0.0042
# Final Average Real Probability: 0.8008 ± 0.0052
# 20901 (41.80%) samples reached the peak conditional coverage at 0.9950

# %%
raps_synthetic_data_scatter(model,dataset,device, lambda_=0.1, k_reg=1, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9150 ± 0.0029
# Final Average Prediction Set Size: 0.95 ± 0.01
# Final Average Coverage: 0.8953 ± 0.0042
# Final Average Real Probability: 0.8008 ± 0.0052
# Peak Conditional Coverage = 1.000, with 18155 samples
#
# === Count Regions Summary ===
# 35871 (71.7%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 117 (0.2%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 10060 (20.1%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99996']
# Sample 2:
#   Predictive Probability Set: ['0.99748']
#   Real Probability Set      : ['0.96240']
# Sample 3:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['1.00000']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.84028']
#   Real Probability Set      : ['0.18820']
# Sample 2:
#   Predictive Probability Set: ['0.99208']
#   Real Probability Set      : ['0.16204']
# Sample 3:
#   Predictive Probability Set: ['0.99471']
#   Real Probability Set      : ['0.03772']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.55802', '0.43479']
#   Real Probability Set      : ['0.14852', '0.64700']
# Sample 2:
#   Predictive Probability Set: ['0.50385', '0.26509']
#   Real Probability Set      : ['0.10121', '0.56568']
# Sample 3:
#   Predictive Probability Set: ['0.44928', '0.37472']
#   Real Probability Set      : ['0.04071', '0.68152']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.56130', '0.36474']
#   Real Probability Set      : ['0.03976', '0.95649']
# Sample 2:
#   Predictive Probability Set: ['0.72284', '0.18004']
#   Real Probability Set      : ['0.03066', '0.89505']
# Sample 3:
#   Predictive Probability Set: ['0.66227', '0.26333']
#   Real Probability Set      : ['0.02444', '0.97493']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.57742']
#   Real Probability Set      : ['0.18589']
# Sample 2:
#   Predictive Probability Set: ['0.57742']
#   Real Probability Set      : ['0.18589']
# Sample 3:
#   Predictive Probability Set: ['0.56461']
#   Real Probability Set      : ['0.19941']

# %%
saps_synthetic_data_hist(model,dataset,device, lambda_=0.7, num_runs=10, alpha=0.1, is_ground_truth=False)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9177 ± 0.0038
# Final Average Prediction Set Size: 0.94 ± 0.00
# Final Average Coverage: 0.8981 ± 0.0048
# Final Average Real Probability: 0.8034 ± 0.0045
# 21094 (42.19%) samples reached the peak conditional coverage at 0.9950

# %%
saps_synthetic_data_scatter(model,dataset,device, lambda_=0.7, num_runs=10, alpha=0.1)
# Out:
# SAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9177 ± 0.0038
# Final Average Prediction Set Size: 0.94 ± 0.00
# Final Average Coverage: 0.8981 ± 0.0048
# Final Average Real Probability: 0.8034 ± 0.0045
# Peak Conditional Coverage = 0.998, with 19473 samples
#
# === Count Regions Summary ===
# 35993 (72.0%) samples in Count Region 1 [x:0-0.5, y:0.8-1.0]
# 109 (0.2%) samples in Count Region 2 [x:0.5-1.0, y:0.8-1.0]
# 10186 (20.4%) samples in Count Region 3 [x:0-0.5, y:0-0.8]
#
# === Sample Points in Specific Regions ===
#
# --- Region 1: low TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['1.00000']
# Sample 2:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['1.00000']
# Sample 3:
#   Predictive Probability Set: ['1.00000']
#   Real Probability Set      : ['0.99792']
#
# --- Region 2: high TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.72694']
#   Real Probability Set      : ['0.19279']
# Sample 2:
#   Predictive Probability Set: ['0.81877']
#   Real Probability Set      : ['0.18844']
# Sample 3:
#   Predictive Probability Set: ['0.87886']
#   Real Probability Set      : ['0.02877']
#
# --- Region 3: medium TVD, medium Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.49393', '0.21449']
#   Real Probability Set      : ['0.19620', '0.59014']
# Sample 2:
#   Predictive Probability Set: ['0.49253', '0.26500']
#   Real Probability Set      : ['0.04244', '0.71378']
# Sample 3:
#   Predictive Probability Set: ['0.55802', '0.43479']
#   Real Probability Set      : ['0.14852', '0.64700']
#
# --- Region 4: high TVD, high Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.86022', '0.11132']
#   Real Probability Set      : ['0.21885', '0.64906']
# Sample 2:
#   Predictive Probability Set: ['0.77193', '0.19586']
#   Real Probability Set      : ['0.11582', '0.88132']
# Sample 3:
#   Predictive Probability Set: ['0.91073', '0.08036']
#   Real Probability Set      : ['0.15176', '0.84554']
#
# --- Region 5: low TVD, low Coverage ---
# Sample 1:
#   Predictive Probability Set: ['0.42241']
#   Real Probability Set      : ['0.16068']
# Sample 2:
#   Predictive Probability Set: ['0.49393']
#   Real Probability Set      : ['0.19620']
# Sample 3:
#   Predictive Probability Set: ['0.50273']
#   Real Probability Set      : ['0.13757']
