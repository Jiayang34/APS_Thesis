# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, raps_synthetic_data
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=5)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_5class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_5class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

raps_synthetic_data(model,dataset,device, lambda_= 0.01, k_reg=0, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9911 ± 0.0023
# Final Average Prediction Set Size: 3.85 ± 0.03
# Final Average Coverage: 0.9654 ± 0.0031
# Final Average Real Probability: 0.9460 ± 0.0022
# 1957 (3.91%) samples reached the real probability at 1-alpha = 0.9500

# %%
raps_synthetic_data(model,dataset,device, lambda_=0.5, k_reg=3, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.3632 ± 0.0094
# Final Average Prediction Set Size: 3.16 ± 0.04
# Final Average Coverage: 0.9207 ± 0.0053
# Final Average Real Probability: 0.8815 ± 0.0039
# 1723 (3.45%) samples reached the real probability at 1-alpha = 0.9000

# %%
raps_synthetic_data(model,dataset,device, lambda_=0.1, k_reg=1, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.9733 ± 0.0055
# Final Average Prediction Set Size: 2.32 ± 0.03
# Final Average Coverage: 0.8378 ± 0.0078
# Final Average Real Probability: 0.7740 ± 0.0036
# 1562 (3.12%) samples reached the real probability at 1-alpha = 0.8000
