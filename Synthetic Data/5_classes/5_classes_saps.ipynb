# %%
from src.synthetic_data import SimplePredictor, load_synthetic_data, SyntheticDataset_and_Probs, saps_synthetic_data
import torch

# load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimplePredictor(feature_dim=64, n_classes=5)
save_path_model = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\model_weights\\synthetic_5class_model.pth"
model.load_state_dict(torch.load(save_path_model, weights_only=True, map_location=device))
model.to(device)
model.eval()

# load dataset
save_path_test = "C:\\Users\\jiayang\\ipynb\\APS_Thesis\\data\\synthetic_data\\synthetic_5class_test.pkl"
x, true_labels, real_probs = load_synthetic_data(save_path_test)
dataset = SyntheticDataset_and_Probs(x, true_labels, real_probs)

saps_synthetic_data(model,dataset,device, lambda_=0.3, num_runs=10, alpha=0.05)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.05), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.3387 ± 0.0093
# Final Average Prediction Set Size: 3.77 ± 0.03
# Final Average Coverage: 0.9594 ± 0.0025
# Final Average Real Probability: 0.9362 ± 0.0019
# 2054 (4.11%) samples reached the real probability at 1-alpha = 0.9500

# %%
saps_synthetic_data(model,dataset,device, lambda_=0.5, num_runs=10, alpha=0.1)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.1), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 1.5852 ± 0.0258
# Final Average Prediction Set Size: 3.15 ± 0.06
# Final Average Coverage: 0.9181 ± 0.0056
# Final Average Real Probability: 0.8787 ± 0.0053
# 1486 (2.97%) samples reached the real probability at 1-alpha = 0.9000

# %%
saps_synthetic_data(model,dataset,device, lambda_=0.25, num_runs=10, alpha=0.2)
# Out:
# RAPS Classification on Synthetic Data(alpha=0.2), Start!
#
# Running experiment 1/10...
# Running experiment 2/10...
# Running experiment 3/10...
# Running experiment 4/10...
# Running experiment 5/10...
# Running experiment 6/10...
# Running experiment 7/10...
# Running experiment 8/10...
# Running experiment 9/10...
# Running experiment 10/10...
# Final Average q_hat: 0.8275 ± 0.0057
# Final Average Prediction Set Size: 2.28 ± 0.03
# Final Average Coverage: 0.8346 ± 0.0069
# Final Average Real Probability: 0.7691 ± 0.0043
# 1866 (3.73%) samples reached the real probability at 1-alpha = 0.8000
